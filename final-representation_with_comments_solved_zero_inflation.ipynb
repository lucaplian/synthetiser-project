# %%
# !rm metadata_.json
# !rm metadata_2.json
import os

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
# Out:
# rm: cannot remove 'metadata_.json': No such file or directory
# rm: cannot remove 'metadata_2.json': No such file or directory

# %%
# !pip install sdv
# !pip install sdmetrics
# !pip install nbformat
# Out:
# Requirement already satisfied: sdv in /usr/local/lib/python3.12/dist-packages (1.38.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /usr/local/lib/python3.12/dist-packages (from sdv) (1.43.36)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /usr/local/lib/python3.12/dist-packages (from sdv) (1.43.36)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (3.1.2)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (2.0.2)
# Requirement already satisfied: pandas<3,>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (2.3.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.12/dist-packages (from sdv) (4.67.3)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (0.14.1)
# Requirement already satisfied: ctgan>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (0.12.1)
# Requirement already satisfied: deepecho>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (0.8.1)
# Requirement already satisfied: rdt>=1.18.2 in /usr/local/lib/python3.12/dist-packages (from sdv) (1.22.0)
# Requirement already satisfied: sdmetrics>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (0.28.2)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.12/dist-packages (from sdv) (4.9.6)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from sdv) (6.0.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28->sdv) (1.1.0)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28->sdv) (0.19.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.5.0)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.12/dist-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from copulas>=0.12.1->sdv) (1.16.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from ctgan>=0.11.1->sdv) (2.10.0+cu128)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.1.1->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=2.1.1->sdv) (2026.1)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from rdt>=1.18.2->sdv) (1.6.1)
# Requirement already satisfied: Faker!=37.11.0,>=17 in /usr/local/lib/python3.12/dist-packages (from rdt>=1.18.2->sdv) (40.36.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (26.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.3.0->ctgan>=0.11.1->sdv) (3.0.3)
# Requirement already satisfied: sdmetrics in /usr/local/lib/python3.12/dist-packages (0.28.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from sdmetrics) (2.0.2)
# Requirement already satisfied: pandas<3.0.0,>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from sdmetrics) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from sdmetrics) (1.6.1)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from sdmetrics) (1.16.3)
# Requirement already satisfied: copulas>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from sdmetrics) (0.14.1)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.12/dist-packages (from sdmetrics) (4.67.3)
# Requirement already satisfied: plotly>=5.19.0 in /usr/local/lib/python3.12/dist-packages (from sdmetrics) (5.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.1->sdmetrics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.1->sdmetrics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.1->sdmetrics) (2026.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.19.0->sdmetrics) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.19.0->sdmetrics) (26.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->sdmetrics) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->sdmetrics) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.1->sdmetrics) (1.17.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat) (5.15.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)

# %%
# !pip install smartnoise-synth
# !pip install --upgrade --no-cache-dir --force-reinstall --no-deps "git+https://github.com/lucaplian/smartnoise-sdk.git#subdirectory=synth"
# Out:
# Requirement already satisfied: smartnoise-synth in /usr/local/lib/python3.12/dist-packages (1.0.8)
# Requirement already satisfied: Faker>=17.0.0 in /usr/local/lib/python3.12/dist-packages (from smartnoise-synth) (40.36.0)
# Requirement already satisfied: disjoint-set<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from smartnoise-synth) (0.9.0)
# Requirement already satisfied: mbi<2,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from smartnoise-synth) (1.1.0)
# Requirement already satisfied: opacus<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from smartnoise-synth) (0.14.0)
# Requirement already satisfied: pac-synth<0.0.9,>=0.0.8 in /usr/local/lib/python3.12/dist-packages (from smartnoise-synth) (0.0.8)
# Requirement already satisfied: smartnoise-sql>=1.0.10 in /usr/local/lib/python3.12/dist-packages (from smartnoise-synth) (1.0.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from disjoint-set<0.10.0,>=0.9.0->smartnoise-synth) (4.15.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (26.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (1.16.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (3.6.1)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (0.7.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (0.7.2)
# Requirement already satisfied: chex in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (0.1.90)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from mbi<2,>=1.1.0->smartnoise-synth) (0.2.8)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.12/dist-packages (from opacus<0.15.0,>=0.14.0->smartnoise-synth) (2.10.0+cu128)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from smartnoise-sql>=1.0.10->smartnoise-synth) (6.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /usr/local/lib/python3.12/dist-packages (from smartnoise-sql>=1.0.10->smartnoise-synth) (4.9.3)
# Requirement already satisfied: graphviz<1.0,>=0.17 in /usr/local/lib/python3.12/dist-packages (from smartnoise-sql>=1.0.10->smartnoise-synth) (0.21)
# Requirement already satisfied: opendp<0.15,>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from smartnoise-sql>=1.0.10->smartnoise-synth) (0.14.2)
# Requirement already satisfied: pandas<3.0.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from smartnoise-sql>=1.0.10->smartnoise-synth) (2.3.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from smartnoise-sql>=1.0.10->smartnoise-synth) (2.0.49)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.12/dist-packages (from opendp<0.15,>=0.14.1->smartnoise-sql>=1.0.10->smartnoise-synth) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.1->smartnoise-sql>=1.0.10->smartnoise-synth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.1->smartnoise-sql>=1.0.10->smartnoise-synth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.0.1->smartnoise-sql>=1.0.10->smartnoise-synth) (2026.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=2.0.0->smartnoise-sql>=1.0.10->smartnoise-synth) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (3.29.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (1.5.3)
# Requirement already satisfied: absl-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex->mbi<2,>=1.1.0->smartnoise-synth) (1.4.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex->mbi<2,>=1.1.0->smartnoise-synth) (0.12.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax->mbi<2,>=1.1.0->smartnoise-synth) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax->mbi<2,>=1.1.0->smartnoise-synth) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.1->smartnoise-sql>=1.0.10->smartnoise-synth) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (1.3.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->opendp<0.15,>=0.14.1->smartnoise-sql>=1.0.10->smartnoise-synth) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.3->opacus<0.15.0,>=0.14.0->smartnoise-synth) (3.0.3)
# Collecting git+https://github.com/lucaplian/smartnoise-sdk.git#subdirectory=synth
#   Cloning https://github.com/lucaplian/smartnoise-sdk.git to /tmp/pip-req-build-zlh5untp
#   Running command git clone --filter=blob:none --quiet https://github.com/lucaplian/smartnoise-sdk.git /tmp/pip-req-build-zlh5untp
#   Encountered 3 file(s) that should have been pointers, but weren't:
#         datasets/PUMS_large.csv
#         datasets/askreddit.csv.zip
#         datasets/clean_askreddit.csv
#   Resolved https://github.com/lucaplian/smartnoise-sdk.git to commit b094ec8eb7f48cb2481c60b870319fb48571db62
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: smartnoise-synth
#   Building wheel for smartnoise-synth (pyproject.toml) ... done
#   Created wheel for smartnoise-synth: filename=smartnoise_synth-1.0.8-py3-none-any.whl size=84856 sha256=2558c9a8e6a40dbfa919d8abcd3b145836fb69b0c603d68cca9ff0914dfffd1d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i74itsk8/wheels/63/41/34/c0f7d62edbaee694e0dc6fca72f59c5578ae4a2a6e9c54e6c0
# Successfully built smartnoise-synth
# Installing collected packages: smartnoise-synth
#   Attempting uninstall: smartnoise-synth
#     Found existing installation: smartnoise-synth 1.0.8
#     Uninstalling smartnoise-synth-1.0.8:
#       Successfully uninstalled smartnoise-synth-1.0.8
# Successfully installed smartnoise-synth-1.0.8

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
my_df = pd.read_csv("/kaggle/input/datasets/lucaplian/adult-data-census/adult-data-census.csv",index_col=0)

# %%
df_reset = my_df.reset_index()

# %%
import numpy as np
df_reset = df_reset.replace('^ ', '', regex=True)
df_reset = df_reset.replace('?', np.nan)

# %%
null_values = df_reset.isnull().sum(axis=1)
for i in range(3):
    null_values = list(filter(lambda x: x > i, null_values))

# %%
df_reset.columns = list(map(lambda x: x.replace(" ", ""), df_reset.columns))

# %%
df_reset.columns = list(map(lambda x: x.replace("-", "_"), df_reset.columns))

# %%
df_reset_copy = df_reset.dropna()

# %%
columns_values = df_reset_copy.columns

# %%
is_col_continuos = []
is_col_categorical = []
is_col_categorical_many_examples = []
is_col_discrete = []
is_col_ordinal = []
import math

for elements_cols in df_reset_copy.columns:
    give_exception = False
    if ".float" in str(type(df_reset_copy.at[0, elements_cols])):
        give_exception = True
        for idx in range(len(df_reset_copy[elements_cols])):
            if 'float' in str(type(df_reset_copy.loc[idx, elements_cols])) and math.isnan(df_reset_copy.loc[idx, elements_cols]):
                continue
            give_exception = df_reset_copy.loc[idx, elements_cols] == float(int(df_reset_copy.loc[idx, elements_cols]))
            if give_exception == False:
                break
        if give_exception and df_reset_copy[elements_cols].nunique() < 20:
            is_col_categorical.append(elements_cols)
        elif give_exception and df_reset_copy[elements_cols].nunique() < 50:
            is_col_categorical_many_examples.append(elements_cols)
        else:
            is_col_continuos.append(elements_cols)
    
    elif df_reset_copy[elements_cols].nunique() < 20:
        is_col_categorical.append(elements_cols)
    elif df_reset_copy[elements_cols].nunique() < 50:
        is_col_categorical_many_examples.append(elements_cols)
    elif ".int" in str(type(df_reset_copy.at[0, elements_cols])):
        is_col_discrete.append(elements_cols)
    else:
        is_col_ordinal.append(elements_cols)

# %%
df_reset_copy_ = df_reset.copy()

# %% [markdown]
# Here we try to reduce the number of unique values from categorical columns, we will replace rare values with 'Others' to reduce balance the dataset.

# %%
from collections import Counter
for col_cat in is_col_categorical_many_examples:
    frequency_el = Counter(df_reset_copy[col_cat])
    d = dict(frequency_el)
    d = dict(sorted(d.items(), key=lambda key_val: key_val[1], reverse=True))
    val_len = len(df_reset_copy[col_cat])
    val = 0
    d_new = {}
    for idx, el in enumerate(d):
        val+= d[el]
        d_new[el] = d[el]
        if val > val_len * 0.98:
            break
    
    for nationality in df_reset_copy_[col_cat].unique():
        if nationality not in d_new.keys():
            df_reset_copy_.loc[df_reset_copy_[col_cat]==nationality, col_cat] = 'Others'
            df_reset_copy_.loc[df_reset_copy_[col_cat]==nationality, col_cat] = 'Others'
    is_col_categorical_many_examples.remove(col_cat)
    is_col_categorical.append(col_cat)

# %%
cols_to_ignore = []
for cols in df_reset_copy_.columns:
    columns_filtered = list(filter(lambda x: cols in x and cols!=x, df_reset_copy_.columns)) 
    if columns_filtered == []:
        continue
    for extr_column in columns_filtered: 
        extr_column_2 = extr_column
        extr_column = extr_column.replace(cols, "")
        if "num" in extr_column or "numeric" in extr_column:
            #df_reset_copy_ = df_reset_copy_.drop(cols, axis=1)
            is_col_ordinal.append(extr_column_2)
            is_col_categorical.remove(extr_column_2)
            cols_to_ignore.append(cols)
            is_col_categorical.remove(cols)
            break

# %%
is_col_OH =is_col_categorical.copy()
for col_val in is_col_categorical:
    if ".int" in str(type(df_reset_copy_.at[0, col_val])) or ".float" in str(type(df_reset_copy_.at[0, col_val])):
        is_col_OH.remove(col_val)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse_output=False)
one_hot_encoded = encoder.fit_transform(df_reset_copy[is_col_OH])
one_hot_df = pd.DataFrame(one_hot_encoded,  columns=encoder.get_feature_names_out(is_col_OH))
df_reset_copy = pd.concat([df_reset_copy.drop(is_col_OH, axis=1), one_hot_df], axis=1)

# %% [markdown]
# !NEED TO OPTIMIZE HERE, MAYBE USE MATRIX MULTIPLICATION INSTEAD

# %%
# THESE TERMS ARE PROTECTED AND CLASSIFIED AS SENSITIVE UNDER THE US EEOC
list_of_sensitive_words = ['race', 'color', 'religion', 'sex', 'gender', 'age', 'disability', 'country', 'region', 'country_of_origin', 'native_country', 'salary']

# %%
import numpy as np 

def generate_embedings_index():
    embeddings_index = {}


    f = open('/kaggle/input/datasets/lucaplian/numberbatch-en/numberbatch-en.txt')

    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
            
    f.close()
    return embeddings_index

# %%
import numpy as np
embeddings_index =  generate_embedings_index()

# %%
# !pip install faiss-gpu-cu12
# Out:
# Requirement already satisfied: faiss-gpu-cu12 in /usr/local/lib/python3.12/dist-packages (1.14.1.post1)
# Requirement already satisfied: numpy<3,>=2 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu-cu12) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-gpu-cu12) (26.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu-cu12) (12.8.90)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from faiss-gpu-cu12) (12.8.4.1)

# %%
import faiss
list_of_sensitive_embeddings = np.array([embeddings_index[word] for word in list_of_sensitive_words], dtype=np.float32, order='C')
faiss.normalize_L2(list_of_sensitive_embeddings)

# %%
from scipy.stats import chi2_contingency
correlated_values_2 = {}
correlated_values_3 = {}

highest_corr_values = []
correlated_columns = set()
value_cosine_similarity = {}
for idx_col_cat in range(len(is_col_categorical)):

    for idx_col_cat_2 in range(idx_col_cat+1, len(is_col_categorical)):
        col_cat = is_col_categorical[idx_col_cat]
        
        col_cat_2 = is_col_categorical[idx_col_cat_2]
        
        contingency_table = pd.crosstab(df_reset_copy_[col_cat], df_reset_copy_[col_cat_2])
        chi2_statistic, p_value, dof, expected = chi2_contingency(contingency_table)
        n = contingency_table.sum().sum()
        phi2 = chi2_statistic / n
        r, k = contingency_table.shape
        if n == 1:
            v = 0
        else: 
            phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1))
            k_corr = k - (k - 1) * (k - 2) / (n - 1)
            r_corr = r - (r - 1) * (r - 2) / (n - 1)
            if k_corr == 1 and r_corr == 1:
                v = 0
            elif k_corr != 1 and r_corr==1:
                v = np.sqrt(phi2corr/(k_corr-1))
            elif r_corr != 1 and k_corr == 1:
                v = np.sqrt(phi2corr/(r_corr-1))
            else:
                v = np.sqrt(phi2corr / min(k_corr - 1, r_corr - 1))
        if col_cat not in value_cosine_similarity.keys():
            if col_cat in embeddings_index.keys():
                embedding_word = np.array([embeddings_index[col_cat]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word)
                values = np.einsum('jk,lk->jl', embedding_word, list_of_sensitive_embeddings)
            else:
                sp_word = ""
                for i in range(len(col_cat)):
                    word = list(filter(lambda x: x.startswith(col_cat[0:i]) and x.endswith(col_cat[i+1:]), embeddings_index.keys()))
                    if len(word) > 0:
                        sp_word = word[0]
                        break

                embedding_word = np.array([embeddings_index[sp_word]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word)
                values = np.einsum('jk,lk->jl', embedding_word, list_of_sensitive_embeddings)
            values = np.max(values)
            value_cosine_similarity[col_cat] = values
        else:
            values = value_cosine_similarity[col_cat]

        if col_cat_2 not in value_cosine_similarity.keys():
            if col_cat_2 in embeddings_index.keys():
                embedding_word_2 = np.array([embeddings_index[col_cat_2]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word_2)
                values_2 = np.einsum('jk,lk->jl', embedding_word_2, list_of_sensitive_embeddings)
            else:
                sp_word = ""
                for i in range(len(col_cat)):
                    word = list(filter(lambda x: x.startswith(col_cat[0:i]) and x.endswith(col_cat[i+1:]), embeddings_index.keys()))
                    if len(word) > 0:
                        sp_word = word[0]
                        break

                embedding_word = np.array([embeddings_index[sp_word]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word)
                values_2 = np.einsum('jk,lk->jl', embedding_word, list_of_sensitive_embeddings)
            values_2 = np.max(values_2)
            value_cosine_similarity[col_cat_2] = values_2
        else:
            values_2 = value_cosine_similarity[col_cat_2]

        

        if v < 0.5 and (values > 0.5 or values_2 > 0.5):
            continue

        
        if v > 0.35:
            
            if (col_cat, col_cat_2) not in correlated_columns or (col_cat_2, col_cat) not in correlated_columns:
                correlated_columns.add((col_cat, col_cat_2))
            if col_cat in correlated_values_2.keys():
                list_cat = correlated_values_2[col_cat]
                list_cat_2 = correlated_values_3[col_cat]
                list_cat.append((float(v), col_cat_2))
                list_cat_2.append(col_cat_2)
                correlated_values_2[col_cat] = list_cat
                correlated_values_3[col_cat] = list_cat_2

            else:
                correlated_values_2[col_cat] = [(float(v), col_cat_2)]
                correlated_values_3[col_cat] = [col_cat_2]
            
            if col_cat_2 in correlated_values_2.keys():
                list_cat = correlated_values_2[col_cat_2]
                list_cat_2 = correlated_values_3[col_cat_2]
                list_cat.append((float(v), col_cat))
                list_cat_2.append(col_cat)
                correlated_values_2[col_cat_2] = list_cat
                correlated_values_3[col_cat_2] = list_cat_2
            else:
                correlated_values_2[col_cat_2] = [(float(v), col_cat)]
                correlated_values_3[col_cat_2] = [col_cat]

# %%
from scipy.stats import chi2_contingency
from sklearn.preprocessing import LabelEncoder

cramer_values = {}
from scipy.stats import pearsonr
value_with_target = {}
is_col_numeric = is_col_discrete.copy()
is_col_numeric.extend(is_col_continuos)
for col_num_idx in range(len(is_col_numeric)-1):
    for col_num2_idx in range(col_num_idx+1, len(is_col_numeric)):
        col_num = is_col_numeric[col_num_idx]
        col_num2 = is_col_numeric[col_num2_idx]
        corr, _ = pearsonr(df_reset_copy_[col_num], df_reset_copy_[col_num2])
        if abs(corr) > 0.5:
            if col_num in correlated_values_3.keys():
                list_cat_2 = correlated_values_3[col_num]
                list_cat_2.append(col_num2)
                correlated_values_3[col_num] = list_cat_2

            else:
                correlated_values_3[col_num] = [col_num2]
            
            if col_num2 in correlated_values_3.keys():
                list_cat_2 = correlated_values_3[col_num2]
                list_cat_2.append(col_num)
                correlated_values_3[col_num2] = list_cat_2
            else:
                correlated_values_3[col_num2] = [col_num]

# %% [markdown]
# THERE WERE PROBLEMATIC ASSOCIATION BETWEEN SEX AND OCCUPATION, LATER FOR EXAMPLE, WE FOUND That in this dataset, there are no woman in the armed forces, but it is not an impossible situation like the "Unmarried" and "Husband" association, so we try to exclude moderate correlations associations related to sex or gender, in order to avoid bias in the dataset.

# %%
for key_ in correlated_values_2.keys():
    list_cat = correlated_values_2[key_]
    list_cat.sort(key=lambda x: x[0], reverse=True)
    correlated_values_2[key_] = list_cat

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
for col_cat in is_col_categorical:
    is_col_numeric = is_col_discrete

    for col_num in is_col_numeric:
        
        model = ols(f'{col_num} ~ {col_cat}',data = df_reset_copy_).fit()
                
        anova_result = sm.stats.anova_lm(model, typ=2)
        eta_2 = anova_result['sum_sq'][col_cat]/(anova_result['sum_sq'][col_cat] + anova_result['sum_sq']['Residual'])

        if col_cat not in value_cosine_similarity.keys():
            if col_cat in embeddings_index.keys():
                embedding_word = np.array([embeddings_index[col_cat]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word)
                values = np.einsum('jk,lk->jl', embedding_word, list_of_sensitive_embeddings)
            else:
                sp_word = ""
                for i in range(len(col_cat)):
                    word = list(filter(lambda x: x.startswith(col_cat[0:i]) and x.endswith(col_cat[i+1:]), embeddings_index.keys()))
                    if len(word) > 0:
                        sp_word = word[0]
                        break

                embedding_word = np.array([embeddings_index[sp_word]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word)
                values = np.einsum('jk,lk->jl', embedding_word, list_of_sensitive_embeddings)
            values = np.max(values)
            value_cosine_similarity[col_cat] = values
        else:
            values = value_cosine_similarity[col_cat]

        if col_cat_2 not in value_cosine_similarity.keys():
            if col_cat_2 in embeddings_index.keys():
                embedding_word_2 = np.array([embeddings_index[col_cat_2]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word_2)
                values_2 = np.einsum('jk,lk->jl', embedding_word_2, list_of_sensitive_embeddings)
            else:
                sp_word = ""
                for i in range(len(col_cat)):
                    word = list(filter(lambda x: x.startswith(col_cat[0:i]) and x.endswith(col_cat[i+1:]), embeddings_index.keys()))
                    if len(word) > 0:
                        sp_word = word[0]
                        break

                embedding_word = np.array([embeddings_index[sp_word]], dtype=np.float32, order='C')
                faiss.normalize_L2(embedding_word)
                values_2 = np.einsum('jk,lk->jl', embedding_word, list_of_sensitive_embeddings)
            values_2 = np.max(values_2)
            value_cosine_similarity[col_cat_2] = values_2
        else:
            values_2 = value_cosine_similarity[col_cat_2]


    
        if (values > 0.5 or values_2 > 0.5) and eta_2 < 0.35:
            continue

        if eta_2 > 0.16:

            if col_cat in correlated_values_3.keys():
                list_cat_2 = correlated_values_3[col_cat]
                list_cat_2.append(col_num)
                correlated_values_3[col_cat] = list_cat_2

            else:
                correlated_values_3[col_cat] = [col_num]
            
            if col_num in correlated_values_3.keys():
                list_cat_2 = correlated_values_3[col_num]
                list_cat_2.append(col_cat)
                correlated_values_3[col_num] = list_cat_2
            else:
                correlated_values_3[col_num] = [col_cat]

# %% [markdown]
# The high correlations are related to columns which do not have missing values

# %% [markdown]
# There are low correlations between the columns in the dataset, which suggests that the each feature is not correlated with the other, so the inputting must be done in a generalised manner, or through intuition. So there is no need for eliminating columns.

# %%
are_missing_values = []
for idx, values in enumerate(df_reset.isnull().sum()):
    if values > 0:
        are_missing_values.append(df_reset.columns[idx])

# %%
null_values = df_reset_copy_.isnull().sum(axis=1)
null_values = list(map(lambda x: x[0], list(filter(lambda x: x[1] > i, zip(list(null_values.index), null_values)))))

df_reset_copy_ = df_reset_copy_.drop(null_values)

# %%
import warnings
warnings.filterwarnings(
    action='ignore', category=UserWarning, message=r"Boolean Series.*"
)

# %%
RuntimeWarning
# Out:
# RuntimeWarning

# %%
correlated_dict_ = set()
current_lists = []
correlated_elements_dict = {}
missing_pair_valid = set()
for val_key in correlated_values_3.keys():
    new_list = []
    new_list.append(val_key)
    for values in correlated_values_3[val_key]:
        ok = 0
        if (val_key, values) in correlated_dict_ or (values, val_key) in correlated_dict_:
            continue
        a = len(df_reset_copy_[val_key].unique())
        b = len(df_reset_copy_[values].unique())
        use_a = False
        use_b = False
        if a > b:
            use_a = a > b
        
        for dx in df_reset_copy_[val_key].unique():
            ok = 0
            for dy in df_reset_copy_[values].unique():
                
                if len(df_reset_copy_.loc[df_reset_copy_[val_key]==dx][df_reset_copy_[values]==dy]) < 0.01 * len(df_reset_copy_.loc[df_reset_copy_[val_key]==dx if a > b else df_reset_copy_[values]==dy]):
                    ok = 1
                    idx = df_reset_copy_[df_reset_copy_[val_key]==dx][df_reset_copy_[values]==dy].index
                    if len(list(idx)) > 0 and ((val_key, values) not in missing_pair_valid and (values, val_key) not in missing_pair_valid):
                        missing_pair_valid.add((val_key, values))

                    if a > b:
                        if len(list(idx)) > 0:
                            df_reset_copy_.loc[list(idx), val_key] = [np.nan] * len(list(idx))
                        if val_key not in are_missing_values:
                            are_missing_values.append(val_key)
                        
                    else:
                        if len(list(idx)) > 0:
                            df_reset_copy_.loc[list(idx), values] = [np.nan] * len(list(idx))
                        if values not in are_missing_values:
                            are_missing_values.append(values)
    
                if ok == 1:
                    break
            if ok == 1:
                break
        if ok == 1:
            new_list.append(values)
            correlated_dict_.add((val_key, values))
    current_lists.append(new_list)

# %%
for val_key, values in list(missing_pair_valid):
    for dx in df_reset_copy_[val_key].unique():
        for dy in df_reset_copy_[values].unique():
            if len(df_reset_copy_.loc[df_reset_copy_[val_key]==dx][df_reset_copy_[values]==dy]) < 0.01 * len(df_reset_copy_.loc[df_reset_copy_[val_key]==dx if a > b else df_reset_copy_[values]==dy]):
                idx = df_reset_copy_[df_reset_copy_[val_key]==dx][df_reset_copy_[values]==dy].index
                if a > b:
                    if len(list(idx)) > 0:
                        df_reset_copy_.loc[list(idx), val_key] = [np.nan] * len(list(idx))
                    
                else:
                    if len(list(idx)) > 0:
                        df_reset_copy_.loc[list(idx), values] = [np.nan] * len(list(idx))

# %%
df_reset_copy_['relationship'][7109]
# Out:
# nan

# %%
import math
from numpy.random import choice

from collections import Counter
associate_combined_values_with_input_values = {}
set_combined_values_with_input_values = set()
for col_ in are_missing_values:
    list_val = []
    for idx in df_reset_copy_.index[df_reset_copy_[col_].isnull()]:
        if "str" in str(type(df_reset_copy_[col_][idx])):
            continue
        if math.isnan(df_reset_copy_[col_][idx]):
            combination_ = ""
            relevant_columns = ""
            if col_ in correlated_values_2.keys():
                for col_2 in correlated_values_2[col_]:
                    if ("str" in str(type(df_reset_copy_[col_2[1]][idx])) or math.isnan(df_reset_copy_[col_2[1]][idx])==False):
                        if combination_ != "":
                            combination_+=";"+str(df_reset_copy_[col_2[1]][idx])
                            relevant_columns+=";"+col_2[1]
                        else:
                            combination_=col_+";"+str(df_reset_copy_[col_2[1]][idx])
                            relevant_columns=col_2[1]

                if combination_ not in associate_combined_values_with_input_values.keys():
                    df_new = df_reset_copy_.copy()
                    for cols_split in relevant_columns.split(";"):
                        df_new_2 = df_new[df_new[cols_split]==df_new[cols_split][idx]].copy()
                        if len(df_new_2[col_].copy().dropna())!=0:
                            df_new = df_new_2
            else:
                combination_ = col_+";"
                df_new = df_reset_copy_.copy()

            if combination_ not in associate_combined_values_with_input_values.keys():
                data_last = Counter(df_new[col_].copy().dropna())

                our_value = data_last.most_common(1)[0][0]
                associate_combined_values_with_input_values[combination_] = our_value
            else:
                our_value = associate_combined_values_with_input_values[combination_]
            list_val.append(our_value)

    df_reset_copy_.loc[list(df_reset_copy_.index[df_reset_copy_[col_].isnull()]), col_] = list_val

# %%
for curr_list_idx in range(len(current_lists)-1):
    for curr_list_idx_2 in range(curr_list_idx+1, len(current_lists)):
        common_lists_1 = current_lists[curr_list_idx]
        common_lists_2 = current_lists[curr_list_idx_2]

        common_lists_1.extend(common_lists_2)
        if len(set(common_lists_1)) != len(common_lists_1):
            current_lists[curr_list_idx] = list(set(common_lists_1))
            current_lists[curr_list_idx_2] = []

# %%
current_lists = list(filter(lambda x: len(x) > 1, current_lists))

# %%
for cols in cols_to_ignore:
    df_reset_copy_ = df_reset_copy_.drop(cols, axis=1)

# %%
df_reset_copy_['capital_net'] = df_reset_copy_['capital_gain']-df_reset_copy_['capital_loss']
df_reset_copy_ = df_reset_copy_.drop('capital_gain', axis=1)
df_reset_copy_ = df_reset_copy_.drop('capital_loss', axis=1)

# %%
#import math
#df_reset_copy_['capital_net_log'] = np.sign(df_reset_copy_['capital_net']) * np.log2(abs(df_reset_copy_['capital_net'])+1)

# %%
df_reset_copy_2 = df_reset_copy_.copy()
#df_reset_copy_2 = df_reset_copy_2.drop(['capital_net', 'fnlwgt'], axis=1)
df_reset_copy_2 = df_reset_copy_2.drop(['fnlwgt'], axis=1)

# %%
df_reset_copy_3 = df_reset_copy_.copy()

for idx, merged_lists in enumerate(current_lists):
    df_reset_copy_2[f"merged_list_{idx}"] = df_reset_copy_2[merged_lists].agg(';'.join, axis=1)

flat_list = [
    x
    for xs in current_lists
    for x in xs
]
df_reset_copy_2=df_reset_copy_2.drop(flat_list, axis=1)

# %%
# !rm adult-data-census-complete2.csv

# %%
df_reset_copy_2.to_csv("adult-data-census-complete2.csv", index=False)

# %%
from sdv.io.local import CSVHandler

connector = CSVHandler()

# %%
import pandas as pd
import math
from snsynth import Synthesizer

pums = pd.read_csv("adult-data-census-complete2.csv")

synth = Synthesizer.create("dpctgan", epsilon=3000000, epochs=1800, batch_size=2000, verbose=True)
synth.fit(pums, preprocessor_eps=900000)
# Out:
# before TableTransformer.create
# after it
# /usr/local/lib/python3.12/dist-packages/snsql/sql/odometer.py:79: RuntimeWarning: overflow encountered in exp
#   optimal_left_side = np.sum([((np.exp(eps) - 1) * eps) / ((np.exp(eps) + 1)) for eps, _ in self.steps])
# /usr/local/lib/python3.12/dist-packages/snsql/sql/odometer.py:79: RuntimeWarning: invalid value encountered in scalar divide
#   optimal_left_side = np.sum([((np.exp(eps) - 1) * eps) / ((np.exp(eps) + 1)) for eps, _ in self.steps])
# Spent 900000.0 epsilon on preprocessor, leaving 2100000.0 for training
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:638: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:229: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1867: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Epoch 1, Loss G: 0.7144, Loss D: 1.3800
# epsilon is 0.1685669340063301, alpha is 63.0
# Epoch 2, Loss G: 0.7044, Loss D: 1.3769
# epsilon is 0.35087099872193805, alpha is 59.0
# Epoch 3, Loss G: 0.6918, Loss D: 1.3818
# epsilon is 0.4932741420837069, alpha is 45.0
# Epoch 4, Loss G: 0.6855, Loss D: 1.3852
# epsilon is 0.6042796523846699, alpha is 38.0
# Epoch 5, Loss G: 0.6823, Loss D: 1.3890
# epsilon is 0.6988118744717009, alpha is 33.0
# Epoch 6, Loss G: 0.6829, Loss D: 1.3899
# epsilon is 0.7828014761953501, alpha is 30.0
# Epoch 7, Loss G: 0.6847, Loss D: 1.3928
# epsilon is 0.8592371022659602, alpha is 28.0
# Epoch 8, Loss G: 0.6894, Loss D: 1.3910
# epsilon is 0.9299480108802527, alpha is 26.0
# Epoch 9, Loss G: 0.6974, Loss D: 1.3884
# epsilon is 0.9962382906342205, alpha is 25.0
# Epoch 10, Loss G: 0.6987, Loss D: 1.3893
# epsilon is 1.0586989652469627, alpha is 23.0
# Epoch 11, Loss G: 0.6999, Loss D: 1.3893
# epsilon is 1.1179585973940969, alpha is 22.0
# Epoch 12, Loss G: 0.7020, Loss D: 1.3878
# epsilon is 1.174699139378363, alpha is 21.0
# Epoch 13, Loss G: 0.7005, Loss D: 1.3864
# epsilon is 1.2289173335166175, alpha is 21.0
# Epoch 14, Loss G: 0.6975, Loss D: 1.3871
# epsilon is 1.2809208093175959, alpha is 20.0
# Epoch 15, Loss G: 0.6943, Loss D: 1.3891
# epsilon is 1.3315140806404386, alpha is 19.0
# Epoch 16, Loss G: 0.6924, Loss D: 1.3904
# epsilon is 1.3803180354630415, alpha is 19.0
# Epoch 17, Loss G: 0.6933, Loss D: 1.3890
# epsilon is 1.427546585910209, alpha is 18.0
# Epoch 18, Loss G: 0.6970, Loss D: 1.3847
# epsilon is 1.4736644203050084, alpha is 18.0
# Epoch 19, Loss G: 0.6981, Loss D: 1.3834
# epsilon is 1.5184630389181348, alpha is 17.0
# Epoch 20, Loss G: 0.6963, Loss D: 1.3861
# epsilon is 1.5619085601596139, alpha is 17.0
# Epoch 21, Loss G: 0.6937, Loss D: 1.3893
# epsilon is 1.605354081401093, alpha is 17.0
# Epoch 22, Loss G: 0.6975, Loss D: 1.3864
# epsilon is 1.6462336398603987, alpha is 16.0
# Epoch 23, Loss G: 0.6967, Loss D: 1.3877
# epsilon is 1.6870205139522907, alpha is 16.0
# Epoch 24, Loss G: 0.6963, Loss D: 1.3876
# epsilon is 1.7278073880441827, alpha is 16.0
# Epoch 25, Loss G: 0.6951, Loss D: 1.3888
# epsilon is 1.7662846225051718, alpha is 15.0
# Epoch 26, Loss G: 0.6989, Loss D: 1.3863
# epsilon is 1.8044263764299593, alpha is 15.0
# Epoch 27, Loss G: 0.7020, Loss D: 1.3843
# epsilon is 1.8425681303547468, alpha is 15.0
# Epoch 28, Loss G: 0.7013, Loss D: 1.3853
# epsilon is 1.8806048635571693, alpha is 14.0
# Epoch 29, Loss G: 0.6987, Loss D: 1.3866
# epsilon is 1.916114887476239, alpha is 14.0
# Epoch 30, Loss G: 0.6987, Loss D: 1.3861
# epsilon is 1.951624911395309, alpha is 14.0
# Epoch 31, Loss G: 0.6999, Loss D: 1.3839
# epsilon is 1.9871349353143788, alpha is 14.0
# Epoch 32, Loss G: 0.6993, Loss D: 1.3825
# epsilon is 2.022644959233449, alpha is 14.0
# Epoch 33, Loss G: 0.6963, Loss D: 1.3862
# epsilon is 2.05759991004724, alpha is 13.0
# Epoch 34, Loss G: 0.6952, Loss D: 1.3877
# epsilon is 2.0904914594530926, alpha is 13.0
# Epoch 35, Loss G: 0.6960, Loss D: 1.3859
# epsilon is 2.1233830088589456, alpha is 13.0
# Epoch 36, Loss G: 0.6944, Loss D: 1.3847
# epsilon is 2.1562745582647986, alpha is 13.0
# Epoch 37, Loss G: 0.6944, Loss D: 1.3846
# epsilon is 2.1891661076706512, alpha is 13.0
# Epoch 38, Loss G: 0.6934, Loss D: 1.3855
# epsilon is 2.2220576570765043, alpha is 13.0
# Epoch 39, Loss G: 0.6949, Loss D: 1.3840
# epsilon is 2.2549004264655568, alpha is 12.0
# Epoch 40, Loss G: 0.6930, Loss D: 1.3855
# epsilon is 2.2851866242874026, alpha is 12.0
# Epoch 41, Loss G: 0.6915, Loss D: 1.3890
# epsilon is 2.315472822109249, alpha is 12.0
# Epoch 42, Loss G: 0.6924, Loss D: 1.3866
# epsilon is 2.345759019931095, alpha is 12.0
# Epoch 43, Loss G: 0.6932, Loss D: 1.3809
# epsilon is 2.376045217752941, alpha is 12.0
# Epoch 44, Loss G: 0.6854, Loss D: 1.3869
# epsilon is 2.4063314155747872, alpha is 12.0
# Epoch 45, Loss G: 0.6823, Loss D: 1.3876
# epsilon is 2.4366176133966335, alpha is 12.0
# Epoch 46, Loss G: 0.6851, Loss D: 1.3837
# epsilon is 2.46690381121848, alpha is 12.0
# Epoch 47, Loss G: 0.6832, Loss D: 1.3830
# epsilon is 2.497190009040326, alpha is 12.0
# Epoch 48, Loss G: 0.6799, Loss D: 1.3866
# epsilon is 2.5263168016153785, alpha is 10.9
# Epoch 49, Loss G: 0.6814, Loss D: 1.3872
# epsilon is 2.5537521139830988, alpha is 10.9
# Epoch 50, Loss G: 0.6826, Loss D: 1.3875
# epsilon is 2.5811874263508185, alpha is 10.9
# Epoch 51, Loss G: 0.6848, Loss D: 1.3853
# epsilon is 2.6086227387185383, alpha is 10.9
# Epoch 52, Loss G: 0.6852, Loss D: 1.3856
# epsilon is 2.636058051086258, alpha is 10.9
# Epoch 53, Loss G: 0.6864, Loss D: 1.3868
# epsilon is 2.663493363453978, alpha is 10.9
# Epoch 54, Loss G: 0.6881, Loss D: 1.3862
# epsilon is 2.690841261537267, alpha is 10.8
# Epoch 55, Loss G: 0.6895, Loss D: 1.3855
# epsilon is 2.7179696081212437, alpha is 10.7
# Epoch 56, Loss G: 0.6898, Loss D: 1.3869
# epsilon is 2.744888048010825, alpha is 10.6
# Epoch 57, Loss G: 0.6923, Loss D: 1.3857
# epsilon is 2.771548552043293, alpha is 10.6
# Epoch 58, Loss G: 0.6932, Loss D: 1.3848
# epsilon is 2.798009112586759, alpha is 10.5
# Epoch 59, Loss G: 0.6905, Loss D: 1.3871
# epsilon is 2.8242803920411794, alpha is 10.4
# Epoch 60, Loss G: 0.6909, Loss D: 1.3875
# epsilon is 2.850373287078834, alpha is 10.3
# Epoch 61, Loss G: 0.6933, Loss D: 1.3842
# epsilon is 2.876260135941629, alpha is 10.3
# Epoch 62, Loss G: 0.6915, Loss D: 1.3831
# epsilon is 2.90192837759987, alpha is 10.2
# Epoch 63, Loss G: 0.6856, Loss D: 1.3870
# epsilon is 2.927441572865636, alpha is 10.1
# Epoch 64, Loss G: 0.6829, Loss D: 1.3885
# epsilon is 2.9528120886699463, alpha is 10.0
# Epoch 65, Loss G: 0.6842, Loss D: 1.3876
# epsilon is 2.977926432115591, alpha is 10.0
# Epoch 66, Loss G: 0.6861, Loss D: 1.3860
# epsilon is 3.0029099349849817, alpha is 9.9
# Epoch 67, Loss G: 0.6878, Loss D: 1.3841
# epsilon is 3.0277670315378344, alpha is 9.9
# Epoch 68, Loss G: 0.6905, Loss D: 1.3834
# epsilon is 3.0523772672955767, alpha is 9.8
# Epoch 69, Loss G: 0.6920, Loss D: 1.3843
# epsilon is 3.076885585451035, alpha is 9.7
# Epoch 70, Loss G: 0.6946, Loss D: 1.3835
# epsilon is 3.101228569834663, alpha is 9.7
# Epoch 71, Loss G: 0.6943, Loss D: 1.3846
# epsilon is 3.125392854980874, alpha is 9.6
# Epoch 72, Loss G: 0.6905, Loss D: 1.3850
# epsilon is 3.1494789738378324, alpha is 9.6
# Epoch 73, Loss G: 0.6882, Loss D: 1.3856
# epsilon is 3.1733149158871004, alpha is 9.5
# Epoch 74, Loss G: 0.6865, Loss D: 1.3800
# epsilon is 3.1970955436626145, alpha is 9.4
# Epoch 75, Loss G: 0.6866, Loss D: 1.3786
# epsilon is 3.2206683119577266, alpha is 9.4
# Epoch 76, Loss G: 0.6831, Loss D: 1.3805
# epsilon is 3.2441540751631064, alpha is 9.3
# Epoch 77, Loss G: 0.6804, Loss D: 1.3869
# epsilon is 3.2674703581738855, alpha is 9.3
# Epoch 78, Loss G: 0.6784, Loss D: 1.3906
# epsilon is 3.290679264105437, alpha is 9.2
# Epoch 79, Loss G: 0.6800, Loss D: 1.3878
# epsilon is 3.313739188330479, alpha is 9.2
# Epoch 80, Loss G: 0.6815, Loss D: 1.3824
# epsilon is 3.336690114378751, alpha is 9.1
# Epoch 81, Loss G: 0.6793, Loss D: 1.3812
# epsilon is 3.3594938061925768, alpha is 9.1
# Epoch 82, Loss G: 0.6776, Loss D: 1.3865
# epsilon is 3.382206554869948, alpha is 9.0
# Epoch 83, Loss G: 0.6776, Loss D: 1.3856
# epsilon is 3.404754140523163, alpha is 9.0
# Epoch 84, Loss G: 0.6796, Loss D: 1.3873
# epsilon is 3.427249498712797, alpha is 8.9
# Epoch 85, Loss G: 0.6843, Loss D: 1.3826
# epsilon is 3.449541104332288, alpha is 8.9
# Epoch 86, Loss G: 0.6830, Loss D: 1.3864
# epsilon is 3.471832709951779, alpha is 8.9
# Epoch 87, Loss G: 0.6837, Loss D: 1.3860
# epsilon is 3.493876658719311, alpha is 8.8
# Epoch 88, Loss G: 0.6825, Loss D: 1.3847
# epsilon is 3.5159124103084323, alpha is 8.8
# Epoch 89, Loss G: 0.6803, Loss D: 1.3829
# epsilon is 3.537783881730258, alpha is 8.7
# Epoch 90, Loss G: 0.6795, Loss D: 1.3827
# epsilon is 3.5595639051689933, alpha is 8.7
# Epoch 91, Loss G: 0.6775, Loss D: 1.3859
# epsilon is 3.581287042708072, alpha is 8.6
# Epoch 92, Loss G: 0.6772, Loss D: 1.3885
# epsilon is 3.602811463753288, alpha is 8.6
# Epoch 93, Loss G: 0.6810, Loss D: 1.3874
# epsilon is 3.6243358847985045, alpha is 8.6
# Epoch 94, Loss G: 0.6840, Loss D: 1.3842
# epsilon is 3.645680626908752, alpha is 8.5
# Epoch 95, Loss G: 0.6854, Loss D: 1.3831
# epsilon is 3.666949571194349, alpha is 8.5
# Epoch 96, Loss G: 0.6872, Loss D: 1.3830
# epsilon is 3.6881982940192723, alpha is 8.4
# Epoch 97, Loss G: 0.6891, Loss D: 1.3831
# epsilon is 3.7092118870563393, alpha is 8.4
# Epoch 98, Loss G: 0.6892, Loss D: 1.3845
# epsilon is 3.7302254800934067, alpha is 8.4
# Epoch 99, Loss G: 0.6919, Loss D: 1.3820
# epsilon is 3.751151184300197, alpha is 8.3
# Epoch 100, Loss G: 0.6934, Loss D: 1.3829
# epsilon is 3.7719095514772483, alpha is 8.3
# Epoch 101, Loss G: 0.6920, Loss D: 1.3821
# epsilon is 3.7926679186542995, alpha is 8.3
# Epoch 102, Loss G: 0.6856, Loss D: 1.3882
# epsilon is 3.8133006360942163, alpha is 8.2
# Epoch 103, Loss G: 0.6833, Loss D: 1.3876
# epsilon is 3.833803902677374, alpha is 8.2
# Epoch 104, Loss G: 0.6834, Loss D: 1.3841
# epsilon is 3.8543071692605317, alpha is 8.2
# Epoch 105, Loss G: 0.6809, Loss D: 1.3835
# epsilon is 3.8746785969179984, alpha is 8.1
# Epoch 106, Loss G: 0.6780, Loss D: 1.3827
# epsilon is 3.8949268880511423, alpha is 8.1
# Epoch 107, Loss G: 0.6735, Loss D: 1.3860
# epsilon is 3.915175179184287, alpha is 8.1
# Epoch 108, Loss G: 0.6709, Loss D: 1.3864
# epsilon is 3.93531879946293, alpha is 8.0
# Epoch 109, Loss G: 0.6726, Loss D: 1.3869
# epsilon is 3.955312240167908, alpha is 8.0
# Epoch 110, Loss G: 0.6730, Loss D: 1.3872
# epsilon is 3.9753056808728857, alpha is 8.0
# Epoch 111, Loss G: 0.6774, Loss D: 1.3843
# epsilon is 3.995256892418794, alpha is 7.9
# Epoch 112, Loss G: 0.6798, Loss D: 1.3848
# epsilon is 4.0149956075956075, alpha is 7.9
# Epoch 113, Loss G: 0.6844, Loss D: 1.3819
# epsilon is 4.03473432277242, alpha is 7.9
# Epoch 114, Loss G: 0.6876, Loss D: 1.3801
# epsilon is 4.054473037949233, alpha is 7.9
# Epoch 115, Loss G: 0.6864, Loss D: 1.3798
# epsilon is 4.074014697368749, alpha is 7.8
# Epoch 116, Loss G: 0.6853, Loss D: 1.3816
# epsilon is 4.093498811795776, alpha is 7.8
# Epoch 117, Loss G: 0.6848, Loss D: 1.3790
# epsilon is 4.112982926222803, alpha is 7.8
# Epoch 118, Loss G: 0.6843, Loss D: 1.3781
# epsilon is 4.132409430296347, alpha is 7.7
# Epoch 119, Loss G: 0.6780, Loss D: 1.3856
# epsilon is 4.1516390686304225, alpha is 7.7
# Epoch 120, Loss G: 0.6754, Loss D: 1.3927
# epsilon is 4.170868706964498, alpha is 7.7
# Epoch 121, Loss G: 0.6804, Loss D: 1.3872
# epsilon is 4.1900983452985745, alpha is 7.7
# Epoch 122, Loss G: 0.6870, Loss D: 1.3769
# epsilon is 4.2091973973237, alpha is 7.6
# Epoch 123, Loss G: 0.6876, Loss D: 1.3728
# epsilon is 4.22817268410041, alpha is 7.6
# Epoch 124, Loss G: 0.6843, Loss D: 1.3719
# epsilon is 4.24714797087712, alpha is 7.6
# Epoch 125, Loss G: 0.6807, Loss D: 1.3737
# epsilon is 4.26612325765383, alpha is 7.6
# Epoch 126, Loss G: 0.6686, Loss D: 1.3859
# epsilon is 4.284939730235111, alpha is 7.5
# Epoch 127, Loss G: 0.6635, Loss D: 1.3918
# epsilon is 4.303660789868922, alpha is 7.5
# Epoch 128, Loss G: 0.6676, Loss D: 1.3851
# epsilon is 4.322381849502734, alpha is 7.5
# Epoch 129, Loss G: 0.6660, Loss D: 1.3851
# epsilon is 4.341102909136544, alpha is 7.5
# Epoch 130, Loss G: 0.6632, Loss D: 1.3902
# epsilon is 4.3596844462933735, alpha is 7.4
# Epoch 131, Loss G: 0.6647, Loss D: 1.3883
# epsilon is 4.3781514030778075, alpha is 7.4
# Epoch 132, Loss G: 0.6651, Loss D: 1.3882
# epsilon is 4.396618359862242, alpha is 7.4
# Epoch 133, Loss G: 0.6682, Loss D: 1.3821
# epsilon is 4.415085316646677, alpha is 7.4
# Epoch 134, Loss G: 0.6721, Loss D: 1.3794
# epsilon is 4.433482556148069, alpha is 7.3
# Epoch 135, Loss G: 0.6749, Loss D: 1.3800
# epsilon is 4.451695534255948, alpha is 7.3
# Epoch 136, Loss G: 0.6811, Loss D: 1.3761
# epsilon is 4.469908512363827, alpha is 7.3
# Epoch 137, Loss G: 0.6872, Loss D: 1.3710
# epsilon is 4.488121490471706, alpha is 7.3
# Epoch 138, Loss G: 0.6791, Loss D: 1.3750
# epsilon is 4.506334468579586, alpha is 7.3
# Epoch 139, Loss G: 0.6691, Loss D: 1.3886
# epsilon is 4.5243474313128065, alpha is 7.2
# Epoch 140, Loss G: 0.6649, Loss D: 1.3875
# epsilon is 4.5423065547963475, alpha is 7.2
# Epoch 141, Loss G: 0.6643, Loss D: 1.3839
# epsilon is 4.5602656782798885, alpha is 7.2
# Epoch 142, Loss G: 0.6667, Loss D: 1.3761
# epsilon is 4.57822480176343, alpha is 7.2
# Epoch 143, Loss G: 0.6650, Loss D: 1.3745
# epsilon is 4.596164847761873, alpha is 7.1
# Epoch 144, Loss G: 0.6566, Loss D: 1.3827
# epsilon is 4.613870240552944, alpha is 7.1
# Epoch 145, Loss G: 0.6546, Loss D: 1.3864
# epsilon is 4.631575633344015, alpha is 7.1
# Epoch 146, Loss G: 0.6561, Loss D: 1.3845
# epsilon is 4.649281026135087, alpha is 7.1
# Epoch 147, Loss G: 0.6556, Loss D: 1.3859
# epsilon is 4.666986418926159, alpha is 7.1
# Epoch 148, Loss G: 0.6573, Loss D: 1.3823
# epsilon is 4.6846611238487155, alpha is 7.0
# Epoch 149, Loss G: 0.6559, Loss D: 1.3848
# epsilon is 4.7021129097589744, alpha is 7.0
# Epoch 150, Loss G: 0.6577, Loss D: 1.3830
# epsilon is 4.719564695669232, alpha is 7.0
# Epoch 151, Loss G: 0.6607, Loss D: 1.3816
# epsilon is 4.737016481579491, alpha is 7.0
# Epoch 152, Loss G: 0.6606, Loss D: 1.3829
# epsilon is 4.754468267489749, alpha is 7.0
# Epoch 153, Loss G: 0.6654, Loss D: 1.3815
# epsilon is 4.771920053400007, alpha is 7.0
# Epoch 154, Loss G: 0.6717, Loss D: 1.3737
# epsilon is 4.789141490661682, alpha is 6.9
# Epoch 155, Loss G: 0.6774, Loss D: 1.3684
# epsilon is 4.806339793382767, alpha is 6.9
# Epoch 156, Loss G: 0.6684, Loss D: 1.3733
# epsilon is 4.823538096103853, alpha is 6.9
# Epoch 157, Loss G: 0.6522, Loss D: 1.3869
# epsilon is 4.840736398824938, alpha is 6.9
# Epoch 158, Loss G: 0.6431, Loss D: 1.4037
# epsilon is 4.857934701546023, alpha is 6.9
# Epoch 159, Loss G: 0.6348, Loss D: 1.4015
# epsilon is 4.8750265202647896, alpha is 6.8
# Epoch 160, Loss G: 0.6425, Loss D: 1.3853
# epsilon is 4.891971463368573, alpha is 6.8
# Epoch 161, Loss G: 0.6498, Loss D: 1.3679
# epsilon is 4.908916406472355, alpha is 6.8
# Epoch 162, Loss G: 0.6426, Loss D: 1.3743
# epsilon is 4.925861349576139, alpha is 6.8
# Epoch 163, Loss G: 0.6310, Loss D: 1.3822
# epsilon is 4.942806292679921, alpha is 6.8
# Epoch 164, Loss G: 0.6163, Loss D: 1.3988
# epsilon is 4.959751235783704, alpha is 6.8
# Epoch 165, Loss G: 0.6089, Loss D: 1.4156
# epsilon is 4.976535125295454, alpha is 6.7
# Epoch 166, Loss G: 0.6202, Loss D: 1.4065
# epsilon is 4.993226832234038, alpha is 6.7
# Epoch 167, Loss G: 0.6317, Loss D: 1.3932
# epsilon is 5.009918539172624, alpha is 6.7
# Epoch 168, Loss G: 0.6377, Loss D: 1.3914
# epsilon is 5.026610246111209, alpha is 6.7
# Epoch 169, Loss G: 0.6403, Loss D: 1.3898
# epsilon is 5.043301953049793, alpha is 6.7
# Epoch 170, Loss G: 0.6504, Loss D: 1.3844
# epsilon is 5.059993659988379, alpha is 6.7
# Epoch 171, Loss G: 0.6579, Loss D: 1.3784
# epsilon is 5.07655011624841, alpha is 6.6
# Epoch 172, Loss G: 0.6585, Loss D: 1.3820
# epsilon is 5.0929887103544935, alpha is 6.6
# Epoch 173, Loss G: 0.6567, Loss D: 1.3800
# epsilon is 5.109427304460577, alpha is 6.6
# Epoch 174, Loss G: 0.6559, Loss D: 1.3754
# epsilon is 5.125865898566659, alpha is 6.6
# Epoch 175, Loss G: 0.6538, Loss D: 1.3651
# epsilon is 5.142304492672744, alpha is 6.6
# Epoch 176, Loss G: 0.6386, Loss D: 1.3786
# epsilon is 5.158743086778826, alpha is 6.6
# Epoch 177, Loss G: 0.6297, Loss D: 1.3870
# epsilon is 5.175158418024588, alpha is 6.5
# Epoch 178, Loss G: 0.6322, Loss D: 1.3859
# epsilon is 5.191344022511594, alpha is 6.5
# Epoch 179, Loss G: 0.6207, Loss D: 1.3992
# epsilon is 5.207529626998599, alpha is 6.5
# Epoch 180, Loss G: 0.6172, Loss D: 1.3991
# epsilon is 5.2237152314856035, alpha is 6.5
# Epoch 181, Loss G: 0.6162, Loss D: 1.3959
# epsilon is 5.239900835972609, alpha is 6.5
# Epoch 182, Loss G: 0.6267, Loss D: 1.3800
# epsilon is 5.256086440459614, alpha is 6.5
# Epoch 183, Loss G: 0.6283, Loss D: 1.3754
# epsilon is 5.272272044946619, alpha is 6.5
# Epoch 184, Loss G: 0.6215, Loss D: 1.3774
# epsilon is 5.288386048788823, alpha is 6.4
# Epoch 185, Loss G: 0.6105, Loss D: 1.3888
# epsilon is 5.304318786751034, alpha is 6.4
# Epoch 186, Loss G: 0.6057, Loss D: 1.3887
# epsilon is 5.320251524713245, alpha is 6.4
# Epoch 187, Loss G: 0.6043, Loss D: 1.3911
# epsilon is 5.336184262675456, alpha is 6.4
# Epoch 188, Loss G: 0.6039, Loss D: 1.4016
# epsilon is 5.3521170006376675, alpha is 6.4
# Epoch 189, Loss G: 0.6105, Loss D: 1.3962
# epsilon is 5.368049738599879, alpha is 6.4
# Epoch 190, Loss G: 0.6309, Loss D: 1.3754
# epsilon is 5.38398247656209, alpha is 6.4
# Epoch 191, Loss G: 0.6469, Loss D: 1.3613
# epsilon is 5.399895024620336, alpha is 6.3
# Epoch 192, Loss G: 0.6442, Loss D: 1.3587
# epsilon is 5.415575019033117, alpha is 6.3
# Epoch 193, Loss G: 0.6367, Loss D: 1.3702
# epsilon is 5.431255013445899, alpha is 6.3
# Epoch 194, Loss G: 0.6368, Loss D: 1.3661
# epsilon is 5.44693500785868, alpha is 6.3
# Epoch 195, Loss G: 0.6287, Loss D: 1.3757
# epsilon is 5.462615002271461, alpha is 6.3
# Epoch 196, Loss G: 0.6304, Loss D: 1.3698
# epsilon is 5.478294996684243, alpha is 6.3
# Epoch 197, Loss G: 0.6298, Loss D: 1.3677
# epsilon is 5.493974991097024, alpha is 6.3
# Epoch 198, Loss G: 0.6227, Loss D: 1.3745
# epsilon is 5.509654985509805, alpha is 6.3
# Epoch 199, Loss G: 0.6096, Loss D: 1.3822
# epsilon is 5.525220965896252, alpha is 6.2
# Epoch 200, Loss G: 0.5916, Loss D: 1.3972
# epsilon is 5.5406483396162, alpha is 6.2
# Epoch 201, Loss G: 0.5912, Loss D: 1.3917
# epsilon is 5.556075713336148, alpha is 6.2
# Epoch 202, Loss G: 0.5990, Loss D: 1.3884
# epsilon is 5.571503087056098, alpha is 6.2
# Epoch 203, Loss G: 0.6130, Loss D: 1.3673
# epsilon is 5.586930460776046, alpha is 6.2
# Epoch 204, Loss G: 0.6049, Loss D: 1.3777
# epsilon is 5.602357834495995, alpha is 6.2
# Epoch 205, Loss G: 0.6009, Loss D: 1.3822
# epsilon is 5.6177852082159445, alpha is 6.2
# Epoch 206, Loss G: 0.5963, Loss D: 1.3853
# epsilon is 5.633212581935893, alpha is 6.2
# Epoch 207, Loss G: 0.6000, Loss D: 1.3725
# epsilon is 5.648548142271484, alpha is 6.1
# Epoch 208, Loss G: 0.5944, Loss D: 1.3793
# epsilon is 5.663723018036657, alpha is 6.1
# Epoch 209, Loss G: 0.5884, Loss D: 1.3810
# epsilon is 5.678897893801829, alpha is 6.1
# Epoch 210, Loss G: 0.5897, Loss D: 1.3719
# epsilon is 5.6940727695670015, alpha is 6.1
# Epoch 211, Loss G: 0.5944, Loss D: 1.3717
# epsilon is 5.709247645332174, alpha is 6.1
# Epoch 212, Loss G: 0.6064, Loss D: 1.3565
# epsilon is 5.724422521097346, alpha is 6.1
# Epoch 213, Loss G: 0.6043, Loss D: 1.3634
# epsilon is 5.739597396862519, alpha is 6.1
# Epoch 214, Loss G: 0.5947, Loss D: 1.3782
# epsilon is 5.754772272627692, alpha is 6.1
# Epoch 215, Loss G: 0.5687, Loss D: 1.4151
# epsilon is 5.769947148392864, alpha is 6.1
# Epoch 216, Loss G: 0.5630, Loss D: 1.4184
# epsilon is 5.78492530146477, alpha is 6.0
# Epoch 217, Loss G: 0.5596, Loss D: 1.4058
# epsilon is 5.799847801894778, alpha is 6.0
# Epoch 218, Loss G: 0.5599, Loss D: 1.3975
# epsilon is 5.814770302324785, alpha is 6.0
# Epoch 219, Loss G: 0.5606, Loss D: 1.3951
# epsilon is 5.829692802754793, alpha is 6.0
# Epoch 220, Loss G: 0.5443, Loss D: 1.4092
# epsilon is 5.844615303184801, alpha is 6.0
# Epoch 221, Loss G: 0.5396, Loss D: 1.4131
# epsilon is 5.859537803614808, alpha is 6.0
# Epoch 222, Loss G: 0.5487, Loss D: 1.3979
# epsilon is 5.874460304044817, alpha is 6.0
# Epoch 223, Loss G: 0.5491, Loss D: 1.3885
# epsilon is 5.889382804474824, alpha is 6.0
# Epoch 224, Loss G: 0.5480, Loss D: 1.4019
# epsilon is 5.904305304904832, alpha is 6.0
# Epoch 225, Loss G: 0.5568, Loss D: 1.3843
# epsilon is 5.919061876461148, alpha is 5.9
# Epoch 226, Loss G: 0.5719, Loss D: 1.3634
# epsilon is 5.933732124057452, alpha is 5.9
# Epoch 227, Loss G: 0.5782, Loss D: 1.3591
# epsilon is 5.948402371653757, alpha is 5.9
# Epoch 228, Loss G: 0.5692, Loss D: 1.3715
# epsilon is 5.963072619250062, alpha is 5.9
# Epoch 229, Loss G: 0.5687, Loss D: 1.3750
# epsilon is 5.977742866846366, alpha is 5.9
# Epoch 230, Loss G: 0.5807, Loss D: 1.3684
# epsilon is 5.99241311444267, alpha is 5.9
# Epoch 231, Loss G: 0.5820, Loss D: 1.3646
# epsilon is 6.007083362038975, alpha is 5.9
# Epoch 232, Loss G: 0.5827, Loss D: 1.3591
# epsilon is 6.02175360963528, alpha is 5.9
# Epoch 233, Loss G: 0.5631, Loss D: 1.3901
# epsilon is 6.036423857231585, alpha is 5.9
# Epoch 234, Loss G: 0.5381, Loss D: 1.4174
# epsilon is 6.0510941048278895, alpha is 5.9
# Epoch 235, Loss G: 0.5101, Loss D: 1.4410
# epsilon is 6.065524054322086, alpha is 5.8
# Epoch 236, Loss G: 0.5071, Loss D: 1.4489
# epsilon is 6.079942171468009, alpha is 5.8
# Epoch 237, Loss G: 0.5101, Loss D: 1.4368
# epsilon is 6.094360288613931, alpha is 5.8
# Epoch 238, Loss G: 0.5193, Loss D: 1.4083
# epsilon is 6.108778405759853, alpha is 5.8
# Epoch 239, Loss G: 0.5178, Loss D: 1.3968
# epsilon is 6.123196522905776, alpha is 5.8
# Epoch 240, Loss G: 0.5061, Loss D: 1.3975
# epsilon is 6.137614640051698, alpha is 5.8
# Epoch 241, Loss G: 0.5038, Loss D: 1.4113
# epsilon is 6.15203275719762, alpha is 5.8
# Epoch 242, Loss G: 0.5049, Loss D: 1.4223
# epsilon is 6.166450874343543, alpha is 5.8
# Epoch 243, Loss G: 0.5112, Loss D: 1.4165
# epsilon is 6.180868991489465, alpha is 5.8
# Epoch 244, Loss G: 0.5174, Loss D: 1.4034
# epsilon is 6.195287108635387, alpha is 5.8
# Epoch 245, Loss G: 0.5094, Loss D: 1.4142
# epsilon is 6.209550244519505, alpha is 5.7
# Epoch 246, Loss G: 0.5013, Loss D: 1.4272
# epsilon is 6.223716353480619, alpha is 5.7
# Epoch 247, Loss G: 0.5121, Loss D: 1.4189
# epsilon is 6.237882462441731, alpha is 5.7
# Epoch 248, Loss G: 0.5438, Loss D: 1.3643
# epsilon is 6.2520485714028435, alpha is 5.7
# Epoch 249, Loss G: 0.5688, Loss D: 1.3237
# epsilon is 6.266214680363957, alpha is 5.7
# Epoch 250, Loss G: 0.5483, Loss D: 1.3532
# epsilon is 6.2803807893250685, alpha is 5.7
# Epoch 251, Loss G: 0.5263, Loss D: 1.3913
# epsilon is 6.294546898286182, alpha is 5.7
# Epoch 252, Loss G: 0.5272, Loss D: 1.3900
# epsilon is 6.308713007247294, alpha is 5.7
# Epoch 253, Loss G: 0.5265, Loss D: 1.3941
# epsilon is 6.322879116208407, alpha is 5.7
# Epoch 254, Loss G: 0.5083, Loss D: 1.4291
# epsilon is 6.337045225169519, alpha is 5.7
# Epoch 255, Loss G: 0.5027, Loss D: 1.4156
# epsilon is 6.351211334130632, alpha is 5.7
# Epoch 256, Loss G: 0.5167, Loss D: 1.3645
# epsilon is 6.365229421079683, alpha is 5.6
# Epoch 257, Loss G: 0.5109, Loss D: 1.3686
# epsilon is 6.37914364400379, alpha is 5.6
# Epoch 258, Loss G: 0.4943, Loss D: 1.3809
# epsilon is 6.3930578669278955, alpha is 5.6
# Epoch 259, Loss G: 0.5010, Loss D: 1.3887
# epsilon is 6.406972089852001, alpha is 5.6
# Epoch 260, Loss G: 0.4975, Loss D: 1.3994
# epsilon is 6.420886312776107, alpha is 5.6
# Epoch 261, Loss G: 0.4925, Loss D: 1.4193
# epsilon is 6.434800535700212, alpha is 5.6
# Epoch 262, Loss G: 0.4877, Loss D: 1.4291
# epsilon is 6.448714758624319, alpha is 5.6
# Epoch 263, Loss G: 0.4978, Loss D: 1.4153
# epsilon is 6.462628981548424, alpha is 5.6
# Epoch 264, Loss G: 0.5259, Loss D: 1.3754
# epsilon is 6.476543204472531, alpha is 5.6
# Epoch 265, Loss G: 0.5488, Loss D: 1.3318
# epsilon is 6.4904574273966364, alpha is 5.6
# Epoch 266, Loss G: 0.5322, Loss D: 1.3564
# epsilon is 6.504371650320742, alpha is 5.6
# Epoch 267, Loss G: 0.5305, Loss D: 1.3515
# epsilon is 6.518285873244848, alpha is 5.6
# Epoch 268, Loss G: 0.5361, Loss D: 1.3364
# epsilon is 6.531996436836314, alpha is 5.5
# Epoch 269, Loss G: 0.5159, Loss D: 1.3654
# epsilon is 6.545658895753766, alpha is 5.5
# Epoch 270, Loss G: 0.4681, Loss D: 1.4548
# epsilon is 6.5593213546712175, alpha is 5.5
# Epoch 271, Loss G: 0.4283, Loss D: 1.5092
# epsilon is 6.572983813588669, alpha is 5.5
# Epoch 272, Loss G: 0.4335, Loss D: 1.4894
# epsilon is 6.586646272506121, alpha is 5.5
# Epoch 273, Loss G: 0.4453, Loss D: 1.4323
# epsilon is 6.600308731423572, alpha is 5.5
# Epoch 274, Loss G: 0.4071, Loss D: 1.5039
# epsilon is 6.613971190341024, alpha is 5.5
# Epoch 275, Loss G: 0.3466, Loss D: 1.6335
# epsilon is 6.627633649258476, alpha is 5.5
# Epoch 276, Loss G: 0.3134, Loss D: 1.7194
# epsilon is 6.641296108175927, alpha is 5.5
# Epoch 277, Loss G: 0.3040, Loss D: 1.7227
# epsilon is 6.654958567093379, alpha is 5.5
# Epoch 278, Loss G: 0.3201, Loss D: 1.6908
# epsilon is 6.668621026010831, alpha is 5.5
# Epoch 279, Loss G: 0.3291, Loss D: 1.6613
# epsilon is 6.682283484928282, alpha is 5.5
# Epoch 280, Loss G: 0.3422, Loss D: 1.6458
# epsilon is 6.695893218609144, alpha is 5.4
# Epoch 281, Loss G: 0.3723, Loss D: 1.5691
# epsilon is 6.70930403543289, alpha is 5.4
# Epoch 282, Loss G: 0.4028, Loss D: 1.4975
# epsilon is 6.722714852256635, alpha is 5.4
# Epoch 283, Loss G: 0.4106, Loss D: 1.4737
# epsilon is 6.73612566908038, alpha is 5.4
# Epoch 284, Loss G: 0.4170, Loss D: 1.4615
# epsilon is 6.749536485904125, alpha is 5.4
# Epoch 285, Loss G: 0.4300, Loss D: 1.4538
# epsilon is 6.76294730272787, alpha is 5.4
# Epoch 286, Loss G: 0.4129, Loss D: 1.4737
# epsilon is 6.776358119551615, alpha is 5.4
# Epoch 287, Loss G: 0.4137, Loss D: 1.4601
# epsilon is 6.78976893637536, alpha is 5.4
# Epoch 288, Loss G: 0.4287, Loss D: 1.4289
# epsilon is 6.803179753199105, alpha is 5.4
# Epoch 289, Loss G: 0.4284, Loss D: 1.4195
# epsilon is 6.816590570022851, alpha is 5.4
# Epoch 290, Loss G: 0.4199, Loss D: 1.4225
# epsilon is 6.830001386846596, alpha is 5.4
# Epoch 291, Loss G: 0.4183, Loss D: 1.4134
# epsilon is 6.843412203670341, alpha is 5.4
# Epoch 292, Loss G: 0.4268, Loss D: 1.3783
# epsilon is 6.856823020494087, alpha is 5.4
# Epoch 293, Loss G: 0.4009, Loss D: 1.4335
# epsilon is 6.870233837317832, alpha is 5.4
# Epoch 294, Loss G: 0.3544, Loss D: 1.5571
# epsilon is 6.883465567416405, alpha is 5.3
# Epoch 295, Loss G: 0.3543, Loss D: 1.5724
# epsilon is 6.896624863942301, alpha is 5.3
# Epoch 296, Loss G: 0.3370, Loss D: 1.5985
# epsilon is 6.909784160468198, alpha is 5.3
# Epoch 297, Loss G: 0.3343, Loss D: 1.6143
# epsilon is 6.922943456994095, alpha is 5.3
# Epoch 298, Loss G: 0.3356, Loss D: 1.5865
# epsilon is 6.936102753519991, alpha is 5.3
# Epoch 299, Loss G: 0.3114, Loss D: 1.6652
# epsilon is 6.9492620500458875, alpha is 5.3
# Epoch 300, Loss G: 0.2890, Loss D: 1.7407
# epsilon is 6.962421346571785, alpha is 5.3
# Epoch 301, Loss G: 0.2841, Loss D: 1.7603
# epsilon is 6.975580643097681, alpha is 5.3
# Epoch 302, Loss G: 0.3113, Loss D: 1.6841
# epsilon is 6.988739939623577, alpha is 5.3
# Epoch 303, Loss G: 0.3621, Loss D: 1.5375
# epsilon is 7.001899236149474, alpha is 5.3
# Epoch 304, Loss G: 0.3993, Loss D: 1.4386
# epsilon is 7.01505853267537, alpha is 5.3
# Epoch 305, Loss G: 0.4048, Loss D: 1.4137
# epsilon is 7.028217829201267, alpha is 5.3
# Epoch 306, Loss G: 0.3443, Loss D: 1.5697
# epsilon is 7.041377125727164, alpha is 5.3
# Epoch 307, Loss G: 0.2929, Loss D: 1.7351
# epsilon is 7.05453642225306, alpha is 5.3
# Epoch 308, Loss G: 0.2751, Loss D: 1.7461
# epsilon is 7.067637979185311, alpha is 5.2
# Epoch 309, Loss G: 0.2799, Loss D: 1.7338
# epsilon is 7.080545877092209, alpha is 5.2
# Epoch 310, Loss G: 0.3163, Loss D: 1.6372
# epsilon is 7.093453774999107, alpha is 5.2
# Epoch 311, Loss G: 0.3340, Loss D: 1.5700
# epsilon is 7.106361672906004, alpha is 5.2
# Epoch 312, Loss G: 0.3321, Loss D: 1.5929
# epsilon is 7.119269570812904, alpha is 5.2
# Epoch 313, Loss G: 0.3485, Loss D: 1.5643
# epsilon is 7.132177468719801, alpha is 5.2
# Epoch 314, Loss G: 0.3933, Loss D: 1.4633
# epsilon is 7.145085366626699, alpha is 5.2
# Epoch 315, Loss G: 0.3915, Loss D: 1.4843
# epsilon is 7.157993264533596, alpha is 5.2
# Epoch 316, Loss G: 0.3708, Loss D: 1.5276
# epsilon is 7.1709011624404955, alpha is 5.2
# Epoch 317, Loss G: 0.3848, Loss D: 1.4983
# epsilon is 7.183809060347393, alpha is 5.2
# Epoch 318, Loss G: 0.3886, Loss D: 1.4443
# epsilon is 7.1967169582542905, alpha is 5.2
# Epoch 319, Loss G: 0.3811, Loss D: 1.4995
# epsilon is 7.209624856161188, alpha is 5.2
# Epoch 320, Loss G: 0.3851, Loss D: 1.4937
# epsilon is 7.2225327540680855, alpha is 5.2
# Epoch 321, Loss G: 0.4312, Loss D: 1.4126
# epsilon is 7.235440651974985, alpha is 5.2
# Epoch 322, Loss G: 0.4427, Loss D: 1.4008
# epsilon is 7.248348549881882, alpha is 5.2
# Epoch 323, Loss G: 0.3968, Loss D: 1.4651
# epsilon is 7.26125644778878, alpha is 5.2
# Epoch 324, Loss G: 0.3712, Loss D: 1.5268
# epsilon is 7.273997226681814, alpha is 5.1
# Epoch 325, Loss G: 0.3835, Loss D: 1.5001
# epsilon is 7.286653847531731, alpha is 5.1
# Epoch 326, Loss G: 0.3935, Loss D: 1.4632
# epsilon is 7.299310468381647, alpha is 5.1
# Epoch 327, Loss G: 0.3820, Loss D: 1.5290
# epsilon is 7.3119670892315645, alpha is 5.1
# Epoch 328, Loss G: 0.3756, Loss D: 1.5497
# epsilon is 7.324623710081481, alpha is 5.1
# Epoch 329, Loss G: 0.3615, Loss D: 1.5882
# epsilon is 7.337280330931397, alpha is 5.1
# Epoch 330, Loss G: 0.3710, Loss D: 1.6202
# epsilon is 7.349936951781314, alpha is 5.1
# Epoch 331, Loss G: 0.3814, Loss D: 1.5944
# epsilon is 7.36259357263123, alpha is 5.1
# Epoch 332, Loss G: 0.4001, Loss D: 1.5218
# epsilon is 7.375250193481147, alpha is 5.1
# Epoch 333, Loss G: 0.4487, Loss D: 1.4146
# epsilon is 7.387906814331063, alpha is 5.1
# Epoch 334, Loss G: 0.5277, Loss D: 1.2727
# epsilon is 7.40056343518098, alpha is 5.1
# Epoch 335, Loss G: 0.6175, Loss D: 1.1630
# epsilon is 7.413220056030896, alpha is 5.1
# Epoch 336, Loss G: 0.6348, Loss D: 1.1385
# epsilon is 7.425876676880812, alpha is 5.1
# Epoch 337, Loss G: 0.6573, Loss D: 1.1245
# epsilon is 7.4385332977307295, alpha is 5.1
# Epoch 338, Loss G: 0.6569, Loss D: 1.1494
# epsilon is 7.451189918580646, alpha is 5.1
# Epoch 339, Loss G: 0.6146, Loss D: 1.2329
# epsilon is 7.463846539430563, alpha is 5.1
# Epoch 340, Loss G: 0.5753, Loss D: 1.2895
# epsilon is 7.476503160280479, alpha is 5.1
# Epoch 341, Loss G: 0.5946, Loss D: 1.2887
# epsilon is 7.488931601194812, alpha is 5.0
# Epoch 342, Loss G: 0.5804, Loss D: 1.3177
# epsilon is 7.501337066433199, alpha is 5.0
# Epoch 343, Loss G: 0.5238, Loss D: 1.3648
# epsilon is 7.5137425316715865, alpha is 5.0
# Epoch 344, Loss G: 0.5370, Loss D: 1.3410
# epsilon is 7.526147996909974, alpha is 5.0
# Epoch 345, Loss G: 0.5772, Loss D: 1.2838
# epsilon is 7.538553462148362, alpha is 5.0
# Epoch 346, Loss G: 0.6228, Loss D: 1.2166
# epsilon is 7.550958927386748, alpha is 5.0
# Epoch 347, Loss G: 0.6175, Loss D: 1.2292
# epsilon is 7.563364392625136, alpha is 5.0
# Epoch 348, Loss G: 0.5865, Loss D: 1.2934
# epsilon is 7.5757698578635235, alpha is 5.0
# Epoch 349, Loss G: 0.5992, Loss D: 1.3179
# epsilon is 7.588175323101911, alpha is 5.0
# Epoch 350, Loss G: 0.6685, Loss D: 1.2861
# epsilon is 7.600580788340298, alpha is 5.0
# Epoch 351, Loss G: 0.7341, Loss D: 1.1982
# epsilon is 7.612986253578685, alpha is 5.0
# Epoch 352, Loss G: 0.8146, Loss D: 1.1303
# epsilon is 7.625391718817073, alpha is 5.0
# Epoch 353, Loss G: 0.9456, Loss D: 1.0573
# epsilon is 7.637797184055461, alpha is 5.0
# Epoch 354, Loss G: 1.0825, Loss D: 0.9711
# epsilon is 7.650202649293848, alpha is 5.0
# Epoch 355, Loss G: 1.2008, Loss D: 0.9224
# epsilon is 7.662608114532235, alpha is 5.0
# Epoch 356, Loss G: 1.2368, Loss D: 0.9014
# epsilon is 7.6750135797706225, alpha is 5.0
# Epoch 357, Loss G: 1.1580, Loss D: 1.0012
# epsilon is 7.68741904500901, alpha is 5.0
# Epoch 358, Loss G: 1.0915, Loss D: 1.0139
# epsilon is 7.699824510247398, alpha is 5.0
# Epoch 359, Loss G: 1.0298, Loss D: 1.0606
# epsilon is 7.712020089972648, alpha is 4.9
# Epoch 360, Loss G: 1.0947, Loss D: 1.0432
# epsilon is 7.724174520928437, alpha is 4.9
# Epoch 361, Loss G: 1.1726, Loss D: 1.0108
# epsilon is 7.736328951884226, alpha is 4.9
# Epoch 362, Loss G: 1.1385, Loss D: 1.0233
# epsilon is 7.748483382840013, alpha is 4.9
# Epoch 363, Loss G: 1.1380, Loss D: 1.0828
# epsilon is 7.760637813795802, alpha is 4.9
# Epoch 364, Loss G: 1.2543, Loss D: 1.0418
# epsilon is 7.772792244751591, alpha is 4.9
# Epoch 365, Loss G: 1.3214, Loss D: 1.0675
# epsilon is 7.78494667570738, alpha is 4.9
# Epoch 366, Loss G: 1.2788, Loss D: 1.1255
# epsilon is 7.7971011066631695, alpha is 4.9
# Epoch 367, Loss G: 1.3735, Loss D: 1.0849
# epsilon is 7.8092555376189585, alpha is 4.9
# Epoch 368, Loss G: 1.5936, Loss D: 1.0011
# epsilon is 7.821409968574748, alpha is 4.9
# Epoch 369, Loss G: 1.6805, Loss D: 0.9651
# epsilon is 7.833564399530537, alpha is 4.9
# Epoch 370, Loss G: 1.6996, Loss D: 0.9604
# epsilon is 7.845718830486324, alpha is 4.9
# Epoch 371, Loss G: 1.7287, Loss D: 0.9843
# epsilon is 7.857873261442113, alpha is 4.9
# Epoch 372, Loss G: 1.7509, Loss D: 1.0314
# epsilon is 7.870027692397902, alpha is 4.9
# Epoch 373, Loss G: 1.8189, Loss D: 1.1117
# epsilon is 7.882182123353691, alpha is 4.9
# Epoch 374, Loss G: 1.7456, Loss D: 1.1563
# epsilon is 7.89433655430948, alpha is 4.9
# Epoch 375, Loss G: 1.6833, Loss D: 1.2505
# epsilon is 7.906490985265269, alpha is 4.9
# Epoch 376, Loss G: 1.7515, Loss D: 1.2537
# epsilon is 7.918645416221058, alpha is 4.9
# Epoch 377, Loss G: 1.8204, Loss D: 1.3041
# epsilon is 7.930799847176847, alpha is 4.9
# Epoch 378, Loss G: 1.8058, Loss D: 1.2706
# epsilon is 7.942877149780529, alpha is 4.8
# Epoch 379, Loss G: 1.8511, Loss D: 1.2637
# epsilon is 7.954780667666405, alpha is 4.8
# Epoch 380, Loss G: 1.9431, Loss D: 1.2349
# epsilon is 7.96668418555228, alpha is 4.8
# Epoch 381, Loss G: 2.1577, Loss D: 1.2373
# epsilon is 7.978587703438157, alpha is 4.8
# Epoch 382, Loss G: 2.3447, Loss D: 1.1878
# epsilon is 7.990491221324033, alpha is 4.8
# Epoch 383, Loss G: 2.4786, Loss D: 1.1226
# epsilon is 8.00239473920991, alpha is 4.8
# Epoch 384, Loss G: 2.4265, Loss D: 1.1418
# epsilon is 8.014298257095785, alpha is 4.8
# Epoch 385, Loss G: 2.2716, Loss D: 1.1959
# epsilon is 8.026201774981661, alpha is 4.8
# Epoch 386, Loss G: 2.3463, Loss D: 1.1693
# epsilon is 8.038105292867538, alpha is 4.8
# Epoch 387, Loss G: 2.4625, Loss D: 1.1436
# epsilon is 8.050008810753415, alpha is 4.8
# Epoch 388, Loss G: 2.5433, Loss D: 1.1479
# epsilon is 8.06191232863929, alpha is 4.8
# Epoch 389, Loss G: 2.5692, Loss D: 1.2877
# epsilon is 8.073815846525166, alpha is 4.8
# Epoch 390, Loss G: 2.6307, Loss D: 1.3285
# epsilon is 8.085719364411043, alpha is 4.8
# Epoch 391, Loss G: 2.7316, Loss D: 1.3547
# epsilon is 8.09762288229692, alpha is 4.8
# Epoch 392, Loss G: 2.8842, Loss D: 1.3600
# epsilon is 8.109526400182794, alpha is 4.8
# Epoch 393, Loss G: 2.9842, Loss D: 1.2655
# epsilon is 8.12142991806867, alpha is 4.8
# Epoch 394, Loss G: 2.8952, Loss D: 1.3001
# epsilon is 8.133333435954547, alpha is 4.8
# Epoch 395, Loss G: 2.6601, Loss D: 1.3628
# epsilon is 8.145236953840424, alpha is 4.8
# Epoch 396, Loss G: 2.7455, Loss D: 1.4090
# epsilon is 8.157140471726299, alpha is 4.8
# Epoch 397, Loss G: 2.8560, Loss D: 1.2652
# epsilon is 8.169043989612176, alpha is 4.8
# Epoch 398, Loss G: 2.9006, Loss D: 1.2986
# epsilon is 8.180947507498052, alpha is 4.8
# Epoch 399, Loss G: 2.9800, Loss D: 1.2268
# epsilon is 8.19281016722832, alpha is 4.7
# Epoch 400, Loss G: 3.0412, Loss D: 1.1177
# epsilon is 8.204462893140814, alpha is 4.7
# Epoch 401, Loss G: 2.9697, Loss D: 1.1848
# epsilon is 8.21611561905331, alpha is 4.7
# Epoch 402, Loss G: 2.8175, Loss D: 1.3332
# epsilon is 8.227768344965806, alpha is 4.7
# Epoch 403, Loss G: 2.8983, Loss D: 1.3669
# epsilon is 8.2394210708783, alpha is 4.7
# Epoch 404, Loss G: 2.9730, Loss D: 1.3065
# epsilon is 8.251073796790797, alpha is 4.7
# Epoch 405, Loss G: 3.0026, Loss D: 1.4134
# epsilon is 8.262726522703293, alpha is 4.7
# Epoch 406, Loss G: 2.9911, Loss D: 1.3447
# epsilon is 8.274379248615787, alpha is 4.7
# Epoch 407, Loss G: 2.9339, Loss D: 1.3973
# epsilon is 8.286031974528283, alpha is 4.7
# Epoch 408, Loss G: 2.9555, Loss D: 1.4384
# epsilon is 8.29768470044078, alpha is 4.7
# Epoch 409, Loss G: 3.1084, Loss D: 1.4186
# epsilon is 8.309337426353274, alpha is 4.7
# Epoch 410, Loss G: 3.4022, Loss D: 1.3052
# epsilon is 8.320990152265772, alpha is 4.7
# Epoch 411, Loss G: 3.5337, Loss D: 1.2470
# epsilon is 8.332642878178266, alpha is 4.7
# Epoch 412, Loss G: 3.3222, Loss D: 1.2146
# epsilon is 8.344295604090762, alpha is 4.7
# Epoch 413, Loss G: 3.2738, Loss D: 1.2550
# epsilon is 8.355948330003258, alpha is 4.7
# Epoch 414, Loss G: 3.2698, Loss D: 1.3526
# epsilon is 8.367601055915753, alpha is 4.7
# Epoch 415, Loss G: 3.1532, Loss D: 1.3496
# epsilon is 8.379253781828249, alpha is 4.7
# Epoch 416, Loss G: 3.1999, Loss D: 1.4166
# epsilon is 8.390906507740745, alpha is 4.7
# Epoch 417, Loss G: 3.2327, Loss D: 1.4227
# epsilon is 8.402559233653239, alpha is 4.7
# Epoch 418, Loss G: 3.4236, Loss D: 1.4086
# epsilon is 8.414211959565735, alpha is 4.7
# Epoch 419, Loss G: 3.4602, Loss D: 1.3773
# epsilon is 8.425864685478231, alpha is 4.7
# Epoch 420, Loss G: 3.2603, Loss D: 1.4184
# epsilon is 8.437517411390726, alpha is 4.7
# Epoch 421, Loss G: 3.3540, Loss D: 1.3598
# epsilon is 8.449170137303222, alpha is 4.7
# Epoch 422, Loss G: 3.5353, Loss D: 1.2710
# epsilon is 8.460767522836367, alpha is 4.6
# Epoch 423, Loss G: 3.4720, Loss D: 1.2278
# epsilon is 8.472169577756109, alpha is 4.6
# Epoch 424, Loss G: 3.3459, Loss D: 1.3420
# epsilon is 8.48357163267585, alpha is 4.6
# Epoch 425, Loss G: 3.3135, Loss D: 1.4169
# epsilon is 8.494973687595595, alpha is 4.6
# Epoch 426, Loss G: 3.5273, Loss D: 1.4535
# epsilon is 8.506375742515337, alpha is 4.6
# Epoch 427, Loss G: 3.7898, Loss D: 1.4910
# epsilon is 8.517777797435079, alpha is 4.6
# Epoch 428, Loss G: 3.7498, Loss D: 1.4701
# epsilon is 8.529179852354822, alpha is 4.6
# Epoch 429, Loss G: 3.8064, Loss D: 1.3734
# epsilon is 8.540581907274564, alpha is 4.6
# Epoch 430, Loss G: 3.7616, Loss D: 1.3292
# epsilon is 8.551983962194306, alpha is 4.6
# Epoch 431, Loss G: 3.8104, Loss D: 1.3881
# epsilon is 8.563386017114048, alpha is 4.6
# Epoch 432, Loss G: 3.7828, Loss D: 1.3705
# epsilon is 8.57478807203379, alpha is 4.6
# Epoch 433, Loss G: 3.5839, Loss D: 1.3682
# epsilon is 8.586190126953532, alpha is 4.6
# Epoch 434, Loss G: 3.6858, Loss D: 1.3958
# epsilon is 8.597592181873274, alpha is 4.6
# Epoch 435, Loss G: 3.8544, Loss D: 1.3059
# epsilon is 8.608994236793016, alpha is 4.6
# Epoch 436, Loss G: 3.4368, Loss D: 1.4089
# epsilon is 8.620396291712758, alpha is 4.6
# Epoch 437, Loss G: 3.3738, Loss D: 1.4530
# epsilon is 8.6317983466325, alpha is 4.6
# Epoch 438, Loss G: 3.5752, Loss D: 1.5000
# epsilon is 8.643200401552242, alpha is 4.6
# Epoch 439, Loss G: 3.7268, Loss D: 1.3459
# epsilon is 8.654602456471986, alpha is 4.6
# Epoch 440, Loss G: 3.8297, Loss D: 1.2807
# epsilon is 8.666004511391728, alpha is 4.6
# Epoch 441, Loss G: 3.8310, Loss D: 1.2161
# epsilon is 8.67740656631147, alpha is 4.6
# Epoch 442, Loss G: 3.7775, Loss D: 1.3755
# epsilon is 8.688808621231214, alpha is 4.6
# Epoch 443, Loss G: 3.7598, Loss D: 1.3927
# epsilon is 8.700210676150956, alpha is 4.6
# Epoch 444, Loss G: 3.8566, Loss D: 1.4214
# epsilon is 8.711612731070698, alpha is 4.6
# Epoch 445, Loss G: 3.8080, Loss D: 1.5141
# epsilon is 8.72301478599044, alpha is 4.6
# Epoch 446, Loss G: 3.8637, Loss D: 1.5688
# epsilon is 8.734416840910182, alpha is 4.6
# Epoch 447, Loss G: 4.0538, Loss D: 1.5260
# epsilon is 8.745750537880525, alpha is 4.5
# Epoch 448, Loss G: 3.9763, Loss D: 1.4457
# epsilon is 8.756902042672374, alpha is 4.5
# Epoch 449, Loss G: 4.0936, Loss D: 1.4461
# epsilon is 8.768053547464223, alpha is 4.5
# Epoch 450, Loss G: 4.1737, Loss D: 1.4792
# epsilon is 8.779205052256074, alpha is 4.5
# Epoch 451, Loss G: 4.1649, Loss D: 1.4045
# epsilon is 8.790356557047925, alpha is 4.5
# Epoch 452, Loss G: 4.0553, Loss D: 1.4808
# epsilon is 8.801508061839774, alpha is 4.5
# Epoch 453, Loss G: 4.0740, Loss D: 1.4272
# epsilon is 8.812659566631623, alpha is 4.5
# Epoch 454, Loss G: 4.1152, Loss D: 1.3760
# epsilon is 8.823811071423474, alpha is 4.5
# Epoch 455, Loss G: 4.0403, Loss D: 1.3505
# epsilon is 8.834962576215325, alpha is 4.5
# Epoch 456, Loss G: 4.0309, Loss D: 1.4902
# epsilon is 8.846114081007174, alpha is 4.5
# Epoch 457, Loss G: 3.6909, Loss D: 1.5841
# epsilon is 8.857265585799023, alpha is 4.5
# Epoch 458, Loss G: 3.7658, Loss D: 1.5805
# epsilon is 8.868417090590874, alpha is 4.5
# Epoch 459, Loss G: 3.7367, Loss D: 1.6935
# epsilon is 8.879568595382725, alpha is 4.5
# Epoch 460, Loss G: 3.9138, Loss D: 1.5677
# epsilon is 8.890720100174576, alpha is 4.5
# Epoch 461, Loss G: 4.1653, Loss D: 1.5079
# epsilon is 8.901871604966425, alpha is 4.5
# Epoch 462, Loss G: 4.2529, Loss D: 1.3747
# epsilon is 8.913023109758274, alpha is 4.5
# Epoch 463, Loss G: 4.2071, Loss D: 1.3265
# epsilon is 8.924174614550125, alpha is 4.5
# Epoch 464, Loss G: 4.1376, Loss D: 1.2725
# epsilon is 8.935326119341976, alpha is 4.5
# Epoch 465, Loss G: 4.1650, Loss D: 1.2675
# epsilon is 8.946477624133825, alpha is 4.5
# Epoch 466, Loss G: 4.0916, Loss D: 1.3165
# epsilon is 8.957629128925674, alpha is 4.5
# Epoch 467, Loss G: 4.1386, Loss D: 1.4499
# epsilon is 8.968780633717525, alpha is 4.5
# Epoch 468, Loss G: 4.1507, Loss D: 1.4940
# epsilon is 8.979932138509376, alpha is 4.5
# Epoch 469, Loss G: 4.0353, Loss D: 1.4904
# epsilon is 8.991083643301225, alpha is 4.5
# Epoch 470, Loss G: 4.1355, Loss D: 1.4969
# epsilon is 9.002235148093074, alpha is 4.5
# Epoch 471, Loss G: 4.2384, Loss D: 1.4185
# epsilon is 9.013386652884925, alpha is 4.5
# Epoch 472, Loss G: 4.4264, Loss D: 1.4891
# epsilon is 9.024538157676776, alpha is 4.5
# Epoch 473, Loss G: 4.4182, Loss D: 1.3793
# epsilon is 9.035689662468625, alpha is 4.5
# Epoch 474, Loss G: 4.3867, Loss D: 1.3803
# epsilon is 9.046821107407622, alpha is 4.4
# Epoch 475, Loss G: 4.3124, Loss D: 1.3663
# epsilon is 9.057722182820802, alpha is 4.4
# Epoch 476, Loss G: 4.3933, Loss D: 1.4233
# epsilon is 9.068623258233979, alpha is 4.4
# Epoch 477, Loss G: 4.3355, Loss D: 1.3501
# epsilon is 9.079524333647159, alpha is 4.4
# Epoch 478, Loss G: 4.4096, Loss D: 1.3481
# epsilon is 9.090425409060337, alpha is 4.4
# Epoch 479, Loss G: 4.3364, Loss D: 1.4214
# epsilon is 9.101326484473516, alpha is 4.4
# Epoch 480, Loss G: 4.3199, Loss D: 1.3759
# epsilon is 9.112227559886694, alpha is 4.4
# Epoch 481, Loss G: 4.3087, Loss D: 1.4747
# epsilon is 9.123128635299873, alpha is 4.4
# Epoch 482, Loss G: 4.1425, Loss D: 1.4771
# epsilon is 9.134029710713053, alpha is 4.4
# Epoch 483, Loss G: 4.1218, Loss D: 1.5765
# epsilon is 9.14493078612623, alpha is 4.4
# Epoch 484, Loss G: 4.2004, Loss D: 1.5864
# epsilon is 9.15583186153941, alpha is 4.4
# Epoch 485, Loss G: 4.0279, Loss D: 1.6129
# epsilon is 9.166732936952586, alpha is 4.4
# Epoch 486, Loss G: 4.0560, Loss D: 1.5873
# epsilon is 9.177634012365766, alpha is 4.4
# Epoch 487, Loss G: 4.1272, Loss D: 1.5609
# epsilon is 9.188535087778945, alpha is 4.4
# Epoch 488, Loss G: 4.3307, Loss D: 1.5288
# epsilon is 9.199436163192123, alpha is 4.4
# Epoch 489, Loss G: 4.3553, Loss D: 1.5185
# epsilon is 9.210337238605304, alpha is 4.4
# Epoch 490, Loss G: 4.3189, Loss D: 1.4385
# epsilon is 9.22123831401848, alpha is 4.4
# Epoch 491, Loss G: 4.2960, Loss D: 1.3647
# epsilon is 9.23213938943166, alpha is 4.4
# Epoch 492, Loss G: 4.2020, Loss D: 1.4036
# epsilon is 9.243040464844837, alpha is 4.4
# Epoch 493, Loss G: 4.2200, Loss D: 1.3998
# epsilon is 9.253941540258017, alpha is 4.4
# Epoch 494, Loss G: 4.3848, Loss D: 1.3695
# epsilon is 9.264842615671196, alpha is 4.4
# Epoch 495, Loss G: 4.3536, Loss D: 1.4353
# epsilon is 9.275743691084374, alpha is 4.4
# Epoch 496, Loss G: 4.3820, Loss D: 1.5230
# epsilon is 9.286644766497552, alpha is 4.4
# Epoch 497, Loss G: 4.4029, Loss D: 1.5748
# epsilon is 9.29754584191073, alpha is 4.4
# Epoch 498, Loss G: 4.3956, Loss D: 1.4921
# epsilon is 9.308446917323911, alpha is 4.4
# Epoch 499, Loss G: 4.3788, Loss D: 1.4865
# epsilon is 9.319347992737088, alpha is 4.4
# Epoch 500, Loss G: 4.4996, Loss D: 1.4892
# epsilon is 9.330249068150268, alpha is 4.4
# Epoch 501, Loss G: 4.5112, Loss D: 1.3519
# epsilon is 9.341150143563446, alpha is 4.4
# Epoch 502, Loss G: 4.4873, Loss D: 1.4309
# epsilon is 9.352051218976625, alpha is 4.4
# Epoch 503, Loss G: 4.5457, Loss D: 1.4348
# epsilon is 9.362952294389803, alpha is 4.4
# Epoch 504, Loss G: 4.4570, Loss D: 1.3817
# epsilon is 9.373761496800668, alpha is 4.3
# Epoch 505, Loss G: 4.2443, Loss D: 1.4858
# epsilon is 9.384412263469038, alpha is 4.3
# Epoch 506, Loss G: 4.3483, Loss D: 1.4889
# epsilon is 9.395063030137408, alpha is 4.3
# Epoch 507, Loss G: 4.4375, Loss D: 1.5343
# epsilon is 9.40571379680578, alpha is 4.3
# Epoch 508, Loss G: 4.4006, Loss D: 1.4536
# epsilon is 9.416364563474149, alpha is 4.3
# Epoch 509, Loss G: 4.4825, Loss D: 1.4200
# epsilon is 9.42701533014252, alpha is 4.3
# Epoch 510, Loss G: 4.3744, Loss D: 1.4140
# epsilon is 9.43766609681089, alpha is 4.3
# Epoch 511, Loss G: 4.4077, Loss D: 1.5481
# epsilon is 9.44831686347926, alpha is 4.3
# Epoch 512, Loss G: 4.4817, Loss D: 1.4043
# epsilon is 9.45896763014763, alpha is 4.3
# Epoch 513, Loss G: 4.5985, Loss D: 1.5310
# epsilon is 9.469618396816, alpha is 4.3
# Epoch 514, Loss G: 4.5212, Loss D: 1.4247
# epsilon is 9.48026916348437, alpha is 4.3
# Epoch 515, Loss G: 4.5446, Loss D: 1.4435
# epsilon is 9.49091993015274, alpha is 4.3
# Epoch 516, Loss G: 4.5629, Loss D: 1.4242
# epsilon is 9.501570696821112, alpha is 4.3
# Epoch 517, Loss G: 4.5606, Loss D: 1.5014
# epsilon is 9.512221463489482, alpha is 4.3
# Epoch 518, Loss G: 4.5837, Loss D: 1.4936
# epsilon is 9.522872230157851, alpha is 4.3
# Epoch 519, Loss G: 4.6254, Loss D: 1.4185
# epsilon is 9.533522996826221, alpha is 4.3
# Epoch 520, Loss G: 4.5770, Loss D: 1.4465
# epsilon is 9.544173763494591, alpha is 4.3
# Epoch 521, Loss G: 4.5851, Loss D: 1.5159
# epsilon is 9.55482453016296, alpha is 4.3
# Epoch 522, Loss G: 4.6103, Loss D: 1.4665
# epsilon is 9.565475296831332, alpha is 4.3
# Epoch 523, Loss G: 4.5603, Loss D: 1.4793
# epsilon is 9.576126063499704, alpha is 4.3
# Epoch 524, Loss G: 4.6313, Loss D: 1.4139
# epsilon is 9.586776830168073, alpha is 4.3
# Epoch 525, Loss G: 4.6007, Loss D: 1.3925
# epsilon is 9.597427596836443, alpha is 4.3
# Epoch 526, Loss G: 4.3934, Loss D: 1.3820
# epsilon is 9.608078363504813, alpha is 4.3
# Epoch 527, Loss G: 4.3728, Loss D: 1.3796
# epsilon is 9.618729130173183, alpha is 4.3
# Epoch 528, Loss G: 4.5068, Loss D: 1.3871
# epsilon is 9.629379896841552, alpha is 4.3
# Epoch 529, Loss G: 4.4908, Loss D: 1.4476
# epsilon is 9.640030663509924, alpha is 4.3
# Epoch 530, Loss G: 4.4409, Loss D: 1.4253
# epsilon is 9.650681430178295, alpha is 4.3
# Epoch 531, Loss G: 4.5283, Loss D: 1.4375
# epsilon is 9.661332196846665, alpha is 4.3
# Epoch 532, Loss G: 4.5653, Loss D: 1.4469
# epsilon is 9.671982963515035, alpha is 4.3
# Epoch 533, Loss G: 4.5127, Loss D: 1.4103
# epsilon is 9.682633730183404, alpha is 4.3
# Epoch 534, Loss G: 4.5825, Loss D: 1.4573
# epsilon is 9.693284496851774, alpha is 4.3
# Epoch 535, Loss G: 4.6087, Loss D: 1.4883
# epsilon is 9.703935263520144, alpha is 4.3
# Epoch 536, Loss G: 4.5547, Loss D: 1.4983
# epsilon is 9.714586030188515, alpha is 4.3
# Epoch 537, Loss G: 4.5468, Loss D: 1.6061
# epsilon is 9.725032977329269, alpha is 4.2
# Epoch 538, Loss G: 4.7785, Loss D: 1.5233
# epsilon is 9.735433555771449, alpha is 4.2
# Epoch 539, Loss G: 4.7888, Loss D: 1.3725
# epsilon is 9.745834134213629, alpha is 4.2
# Epoch 540, Loss G: 4.7049, Loss D: 1.4000
# epsilon is 9.756234712655809, alpha is 4.2
# Epoch 541, Loss G: 4.7547, Loss D: 1.4316
# epsilon is 9.76663529109799, alpha is 4.2
# Epoch 542, Loss G: 4.7735, Loss D: 1.3649
# epsilon is 9.77703586954017, alpha is 4.2
# Epoch 543, Loss G: 4.7219, Loss D: 1.3882
# epsilon is 9.78743644798235, alpha is 4.2
# Epoch 544, Loss G: 4.6630, Loss D: 1.4870
# epsilon is 9.79783702642453, alpha is 4.2
# Epoch 545, Loss G: 4.6138, Loss D: 1.4590
# epsilon is 9.80823760486671, alpha is 4.2
# Epoch 546, Loss G: 4.6402, Loss D: 1.4140
# epsilon is 9.81863818330889, alpha is 4.2
# Epoch 547, Loss G: 4.4534, Loss D: 1.5051
# epsilon is 9.82903876175107, alpha is 4.2
# ...
# epsilon is 18.78194812199539, alpha is 2.9
# Epoch 1617, Loss G: 4.9744, Loss D: 1.3087
# epsilon is 18.789107168561166, alpha is 2.9
# Epoch 1618, Loss G: 4.9973, Loss D: 1.2682
# epsilon is 18.79626621512694, alpha is 2.9
# Epoch 1619, Loss G: 5.0080, Loss D: 1.3431
# epsilon is 18.803425261692716, alpha is 2.9
# Epoch 1620, Loss G: 5.0056, Loss D: 1.4242
# epsilon is 18.81058430825849, alpha is 2.9
# Epoch 1621, Loss G: 4.9677, Loss D: 1.3205
# epsilon is 18.817743354824266, alpha is 2.9
# Epoch 1622, Loss G: 4.9958, Loss D: 1.3198
# epsilon is 18.82490240139004, alpha is 2.9
# Epoch 1623, Loss G: 5.0087, Loss D: 1.3462
# epsilon is 18.832061447955812, alpha is 2.9
# Epoch 1624, Loss G: 5.0003, Loss D: 1.3493
# epsilon is 18.839220494521587, alpha is 2.9
# Epoch 1625, Loss G: 5.0243, Loss D: 1.3940
# epsilon is 18.846379541087362, alpha is 2.9
# Epoch 1626, Loss G: 4.9268, Loss D: 1.2993
# epsilon is 18.853538587653134, alpha is 2.9
# Epoch 1627, Loss G: 5.0550, Loss D: 1.3132
# epsilon is 18.86069763421891, alpha is 2.9
# Epoch 1628, Loss G: 5.0580, Loss D: 1.3067
# epsilon is 18.867856680784683, alpha is 2.9
# Epoch 1629, Loss G: 5.0181, Loss D: 1.3673
# epsilon is 18.87501572735046, alpha is 2.9
# Epoch 1630, Loss G: 4.9744, Loss D: 1.4074
# epsilon is 18.882174773916233, alpha is 2.9
# Epoch 1631, Loss G: 4.9828, Loss D: 1.3162
# epsilon is 18.88933382048201, alpha is 2.9
# Epoch 1632, Loss G: 5.0166, Loss D: 1.2855
# epsilon is 18.896492867047783, alpha is 2.9
# Epoch 1633, Loss G: 5.0047, Loss D: 1.2515
# epsilon is 18.903651913613558, alpha is 2.9
# Epoch 1634, Loss G: 5.0158, Loss D: 1.2550
# epsilon is 18.91081096017933, alpha is 2.9
# Epoch 1635, Loss G: 5.0149, Loss D: 1.3029
# epsilon is 18.917970006745104, alpha is 2.9
# Epoch 1636, Loss G: 4.9260, Loss D: 1.2412
# epsilon is 18.92512905331088, alpha is 2.9
# Epoch 1637, Loss G: 4.9845, Loss D: 1.3715
# epsilon is 18.93228809987665, alpha is 2.9
# Epoch 1638, Loss G: 4.9740, Loss D: 1.3334
# epsilon is 18.939447146442426, alpha is 2.9
# Epoch 1639, Loss G: 4.9622, Loss D: 1.2692
# epsilon is 18.9466061930082, alpha is 2.9
# Epoch 1640, Loss G: 4.9760, Loss D: 1.3398
# epsilon is 18.953765239573976, alpha is 2.9
# Epoch 1641, Loss G: 4.9047, Loss D: 1.3135
# epsilon is 18.96092428613975, alpha is 2.9
# Epoch 1642, Loss G: 4.9339, Loss D: 1.2853
# epsilon is 18.968083332705525, alpha is 2.9
# Epoch 1643, Loss G: 4.9524, Loss D: 1.2306
# epsilon is 18.9752423792713, alpha is 2.9
# Epoch 1644, Loss G: 4.8925, Loss D: 1.3483
# epsilon is 18.982401425837075, alpha is 2.9
# Epoch 1645, Loss G: 4.9553, Loss D: 1.3301
# epsilon is 18.989560472402847, alpha is 2.9
# Epoch 1646, Loss G: 4.9734, Loss D: 1.3737
# epsilon is 18.99671951896862, alpha is 2.9
# Epoch 1647, Loss G: 4.9610, Loss D: 1.3743
# epsilon is 19.003878565534396, alpha is 2.9
# Epoch 1648, Loss G: 4.9304, Loss D: 1.3117
# epsilon is 19.011037612100168, alpha is 2.9
# Epoch 1649, Loss G: 4.9651, Loss D: 1.3880
# epsilon is 19.018196658665943, alpha is 2.9
# Epoch 1650, Loss G: 5.0040, Loss D: 1.2729
# epsilon is 19.025355705231718, alpha is 2.9
# Epoch 1651, Loss G: 4.9584, Loss D: 1.3237
# epsilon is 19.032514751797493, alpha is 2.9
# Epoch 1652, Loss G: 5.0153, Loss D: 1.2926
# epsilon is 19.039673798363268, alpha is 2.9
# Epoch 1653, Loss G: 4.9906, Loss D: 1.3067
# epsilon is 19.046832844929042, alpha is 2.9
# Epoch 1654, Loss G: 5.0150, Loss D: 1.3521
# epsilon is 19.053991891494817, alpha is 2.9
# Epoch 1655, Loss G: 5.0025, Loss D: 1.3400
# epsilon is 19.061150938060592, alpha is 2.9
# Epoch 1656, Loss G: 4.9804, Loss D: 1.3766
# epsilon is 19.068309984626364, alpha is 2.9
# Epoch 1657, Loss G: 4.9604, Loss D: 1.3691
# epsilon is 19.07546903119214, alpha is 2.9
# Epoch 1658, Loss G: 4.9550, Loss D: 1.3463
# epsilon is 19.082628077757914, alpha is 2.9
# Epoch 1659, Loss G: 4.9961, Loss D: 1.3796
# epsilon is 19.089787124323685, alpha is 2.9
# Epoch 1660, Loss G: 4.9622, Loss D: 1.2899
# epsilon is 19.09694617088946, alpha is 2.9
# Epoch 1661, Loss G: 4.9801, Loss D: 1.2661
# epsilon is 19.104105217455235, alpha is 2.9
# Epoch 1662, Loss G: 4.9346, Loss D: 1.3373
# epsilon is 19.11126426402101, alpha is 2.9
# Epoch 1663, Loss G: 4.9638, Loss D: 1.3862
# epsilon is 19.118423310586785, alpha is 2.9
# Epoch 1664, Loss G: 5.0014, Loss D: 1.3216
# epsilon is 19.12558235715256, alpha is 2.9
# Epoch 1665, Loss G: 5.0037, Loss D: 1.4281
# epsilon is 19.132741403718335, alpha is 2.9
# Epoch 1666, Loss G: 5.0231, Loss D: 1.3580
# epsilon is 19.13990045028411, alpha is 2.9
# Epoch 1667, Loss G: 5.0091, Loss D: 1.2272
# epsilon is 19.14705949684988, alpha is 2.9
# Epoch 1668, Loss G: 5.0359, Loss D: 1.2626
# epsilon is 19.154218543415656, alpha is 2.9
# Epoch 1669, Loss G: 4.9594, Loss D: 1.3676
# epsilon is 19.16137758998143, alpha is 2.9
# Epoch 1670, Loss G: 4.9640, Loss D: 1.3591
# epsilon is 19.168536636547202, alpha is 2.9
# Epoch 1671, Loss G: 4.9544, Loss D: 1.3772
# epsilon is 19.175695683112977, alpha is 2.9
# Epoch 1672, Loss G: 4.9186, Loss D: 1.3223
# epsilon is 19.182854729678752, alpha is 2.9
# Epoch 1673, Loss G: 4.9828, Loss D: 1.2794
# epsilon is 19.190013776244527, alpha is 2.9
# Epoch 1674, Loss G: 4.9929, Loss D: 1.2237
# epsilon is 19.197172822810302, alpha is 2.9
# Epoch 1675, Loss G: 5.0302, Loss D: 1.3519
# epsilon is 19.204331869376077, alpha is 2.9
# Epoch 1676, Loss G: 5.0009, Loss D: 1.4153
# epsilon is 19.21149091594185, alpha is 2.9
# Epoch 1677, Loss G: 4.9870, Loss D: 1.3576
# epsilon is 19.218649962507627, alpha is 2.9
# Epoch 1678, Loss G: 4.9985, Loss D: 1.3419
# epsilon is 19.225809009073398, alpha is 2.9
# Epoch 1679, Loss G: 4.9991, Loss D: 1.3136
# epsilon is 19.232968055639173, alpha is 2.9
# Epoch 1680, Loss G: 5.0207, Loss D: 1.3130
# epsilon is 19.240127102204948, alpha is 2.9
# Epoch 1681, Loss G: 4.9849, Loss D: 1.2968
# epsilon is 19.24728614877072, alpha is 2.9
# Epoch 1682, Loss G: 5.0045, Loss D: 1.3592
# epsilon is 19.254445195336494, alpha is 2.9
# Epoch 1683, Loss G: 5.0011, Loss D: 1.3102
# epsilon is 19.26160424190227, alpha is 2.9
# Epoch 1684, Loss G: 5.0208, Loss D: 1.2477
# epsilon is 19.268763288468044, alpha is 2.9
# Epoch 1685, Loss G: 5.0124, Loss D: 1.3097
# epsilon is 19.27592233503382, alpha is 2.9
# Epoch 1686, Loss G: 5.0062, Loss D: 1.3962
# epsilon is 19.283081381599594, alpha is 2.9
# Epoch 1687, Loss G: 4.9709, Loss D: 1.3003
# epsilon is 19.29024042816537, alpha is 2.9
# Epoch 1688, Loss G: 5.0101, Loss D: 1.3695
# epsilon is 19.297399474731144, alpha is 2.9
# Epoch 1689, Loss G: 5.0533, Loss D: 1.2939
# epsilon is 19.304558521296915, alpha is 2.9
# Epoch 1690, Loss G: 4.9992, Loss D: 1.3474
# epsilon is 19.31171756786269, alpha is 2.9
# Epoch 1691, Loss G: 5.0565, Loss D: 1.2780
# epsilon is 19.318876614428465, alpha is 2.9
# Epoch 1692, Loss G: 5.0038, Loss D: 1.3289
# epsilon is 19.326035660994236, alpha is 2.9
# Epoch 1693, Loss G: 5.0110, Loss D: 1.2851
# epsilon is 19.33319470756001, alpha is 2.9
# Epoch 1694, Loss G: 5.0108, Loss D: 1.4126
# epsilon is 19.340353754125786, alpha is 2.9
# Epoch 1695, Loss G: 5.0039, Loss D: 1.2797
# epsilon is 19.34751280069156, alpha is 2.9
# Epoch 1696, Loss G: 4.9345, Loss D: 1.4238
# epsilon is 19.354671847257336, alpha is 2.9
# Epoch 1697, Loss G: 4.9294, Loss D: 1.3905
# epsilon is 19.36183089382311, alpha is 2.9
# Epoch 1698, Loss G: 4.9599, Loss D: 1.2011
# epsilon is 19.368989940388886, alpha is 2.9
# Epoch 1699, Loss G: 4.9725, Loss D: 1.3832
# epsilon is 19.37614898695466, alpha is 2.9
# Epoch 1700, Loss G: 4.9900, Loss D: 1.3324
# epsilon is 19.383308033520432, alpha is 2.9
# Epoch 1701, Loss G: 4.9674, Loss D: 1.3233
# epsilon is 19.390467080086207, alpha is 2.9
# Epoch 1702, Loss G: 4.9492, Loss D: 1.3138
# epsilon is 19.397626126651982, alpha is 2.9
# Epoch 1703, Loss G: 5.0013, Loss D: 1.4479
# epsilon is 19.404785173217753, alpha is 2.9
# Epoch 1704, Loss G: 5.0070, Loss D: 1.3288
# epsilon is 19.41194421978353, alpha is 2.9
# Epoch 1705, Loss G: 4.9715, Loss D: 1.3360
# epsilon is 19.419103266349303, alpha is 2.9
# Epoch 1706, Loss G: 4.9733, Loss D: 1.3174
# epsilon is 19.426262312915078, alpha is 2.9
# Epoch 1707, Loss G: 4.9620, Loss D: 1.3516
# epsilon is 19.433421359480853, alpha is 2.9
# Epoch 1708, Loss G: 4.9014, Loss D: 1.3123
# epsilon is 19.440580406046628, alpha is 2.9
# Epoch 1709, Loss G: 4.9303, Loss D: 1.3335
# epsilon is 19.447739452612403, alpha is 2.9
# Epoch 1710, Loss G: 4.9662, Loss D: 1.3463
# epsilon is 19.454898499178178, alpha is 2.9
# Epoch 1711, Loss G: 5.0175, Loss D: 1.3753
# epsilon is 19.46205754574395, alpha is 2.9
# Epoch 1712, Loss G: 4.9591, Loss D: 1.2771
# epsilon is 19.46913821679639, alpha is 2.8
# Epoch 1713, Loss G: 4.9533, Loss D: 1.3658
# epsilon is 19.47604875039054, alpha is 2.8
# Epoch 1714, Loss G: 4.9172, Loss D: 1.3462
# epsilon is 19.482959283984684, alpha is 2.8
# Epoch 1715, Loss G: 4.9239, Loss D: 1.3604
# epsilon is 19.489869817578832, alpha is 2.8
# Epoch 1716, Loss G: 4.9608, Loss D: 1.3341
# epsilon is 19.49678035117298, alpha is 2.8
# Epoch 1717, Loss G: 5.0706, Loss D: 1.3580
# epsilon is 19.503690884767124, alpha is 2.8
# Epoch 1718, Loss G: 5.0359, Loss D: 1.3504
# epsilon is 19.510601418361272, alpha is 2.8
# Epoch 1719, Loss G: 4.9694, Loss D: 1.3206
# epsilon is 19.51751195195542, alpha is 2.8
# Epoch 1720, Loss G: 4.9521, Loss D: 1.3331
# epsilon is 19.524422485549564, alpha is 2.8
# Epoch 1721, Loss G: 4.9214, Loss D: 1.2686
# epsilon is 19.531333019143712, alpha is 2.8
# Epoch 1722, Loss G: 5.0048, Loss D: 1.3562
# epsilon is 19.53824355273786, alpha is 2.8
# Epoch 1723, Loss G: 4.9987, Loss D: 1.3697
# epsilon is 19.545154086332005, alpha is 2.8
# Epoch 1724, Loss G: 4.9521, Loss D: 1.2942
# epsilon is 19.552064619926156, alpha is 2.8
# Epoch 1725, Loss G: 4.9968, Loss D: 1.2624
# epsilon is 19.5589751535203, alpha is 2.8
# Epoch 1726, Loss G: 4.9818, Loss D: 1.3871
# epsilon is 19.565885687114445, alpha is 2.8
# Epoch 1727, Loss G: 5.0057, Loss D: 1.3061
# epsilon is 19.572796220708597, alpha is 2.8
# Epoch 1728, Loss G: 5.0217, Loss D: 1.4473
# epsilon is 19.57970675430274, alpha is 2.8
# Epoch 1729, Loss G: 4.9868, Loss D: 1.2875
# epsilon is 19.58661728789689, alpha is 2.8
# Epoch 1730, Loss G: 5.0164, Loss D: 1.3160
# epsilon is 19.593527821491037, alpha is 2.8
# Epoch 1731, Loss G: 4.9707, Loss D: 1.3759
# epsilon is 19.60043835508518, alpha is 2.8
# Epoch 1732, Loss G: 4.9508, Loss D: 1.3116
# epsilon is 19.60734888867933, alpha is 2.8
# Epoch 1733, Loss G: 4.9074, Loss D: 1.3703
# epsilon is 19.614259422273477, alpha is 2.8
# Epoch 1734, Loss G: 4.9815, Loss D: 1.3334
# epsilon is 19.62116995586762, alpha is 2.8
# Epoch 1735, Loss G: 5.0199, Loss D: 1.2843
# epsilon is 19.62808048946177, alpha is 2.8
# Epoch 1736, Loss G: 4.9870, Loss D: 1.2890
# epsilon is 19.634991023055917, alpha is 2.8
# Epoch 1737, Loss G: 4.9912, Loss D: 1.3756
# epsilon is 19.641901556650062, alpha is 2.8
# Epoch 1738, Loss G: 5.0256, Loss D: 1.3346
# epsilon is 19.64881209024421, alpha is 2.8
# Epoch 1739, Loss G: 4.9342, Loss D: 1.2686
# epsilon is 19.655722623838358, alpha is 2.8
# Epoch 1740, Loss G: 4.9622, Loss D: 1.2755
# epsilon is 19.662633157432502, alpha is 2.8
# Epoch 1741, Loss G: 4.9762, Loss D: 1.3161
# epsilon is 19.66954369102665, alpha is 2.8
# Epoch 1742, Loss G: 4.9626, Loss D: 1.3538
# epsilon is 19.676454224620798, alpha is 2.8
# Epoch 1743, Loss G: 4.9577, Loss D: 1.3252
# epsilon is 19.683364758214942, alpha is 2.8
# Epoch 1744, Loss G: 4.9641, Loss D: 1.3310
# epsilon is 19.690275291809094, alpha is 2.8
# Epoch 1745, Loss G: 4.9490, Loss D: 1.3095
# epsilon is 19.69718582540324, alpha is 2.8
# Epoch 1746, Loss G: 4.9706, Loss D: 1.2742
# epsilon is 19.704096358997383, alpha is 2.8
# Epoch 1747, Loss G: 4.9621, Loss D: 1.3490
# epsilon is 19.711006892591534, alpha is 2.8
# Epoch 1748, Loss G: 5.0052, Loss D: 1.3221
# epsilon is 19.71791742618568, alpha is 2.8
# Epoch 1749, Loss G: 4.9751, Loss D: 1.3600
# epsilon is 19.724827959779827, alpha is 2.8
# Epoch 1750, Loss G: 4.9702, Loss D: 1.3635
# epsilon is 19.731738493373975, alpha is 2.8
# Epoch 1751, Loss G: 4.9780, Loss D: 1.3444
# epsilon is 19.73864902696812, alpha is 2.8
# Epoch 1752, Loss G: 4.9947, Loss D: 1.2706
# epsilon is 19.745559560562267, alpha is 2.8
# Epoch 1753, Loss G: 4.9783, Loss D: 1.3595
# epsilon is 19.752470094156415, alpha is 2.8
# Epoch 1754, Loss G: 4.9696, Loss D: 1.2329
# epsilon is 19.75938062775056, alpha is 2.8
# Epoch 1755, Loss G: 4.9546, Loss D: 1.2683
# epsilon is 19.766291161344707, alpha is 2.8
# Epoch 1756, Loss G: 4.9616, Loss D: 1.3623
# epsilon is 19.773201694938855, alpha is 2.8
# Epoch 1757, Loss G: 4.9842, Loss D: 1.3414
# epsilon is 19.780112228533, alpha is 2.8
# Epoch 1758, Loss G: 4.9237, Loss D: 1.4135
# epsilon is 19.787022762127148, alpha is 2.8
# Epoch 1759, Loss G: 4.9677, Loss D: 1.3697
# epsilon is 19.793933295721295, alpha is 2.8
# Epoch 1760, Loss G: 4.9391, Loss D: 1.4199
# epsilon is 19.80084382931544, alpha is 2.8
# Epoch 1761, Loss G: 4.9539, Loss D: 1.2812
# epsilon is 19.807754362909588, alpha is 2.8
# Epoch 1762, Loss G: 4.9350, Loss D: 1.2977
# epsilon is 19.814664896503736, alpha is 2.8
# Epoch 1763, Loss G: 4.9589, Loss D: 1.3941
# epsilon is 19.82157543009788, alpha is 2.8
# Epoch 1764, Loss G: 4.9175, Loss D: 1.3385
# epsilon is 19.82848596369203, alpha is 2.8
# Epoch 1765, Loss G: 4.9063, Loss D: 1.3967
# epsilon is 19.835396497286176, alpha is 2.8
# Epoch 1766, Loss G: 4.9746, Loss D: 1.3139
# epsilon is 19.84230703088032, alpha is 2.8
# Epoch 1767, Loss G: 4.9602, Loss D: 1.3287
# epsilon is 19.849217564474472, alpha is 2.8
# Epoch 1768, Loss G: 4.9441, Loss D: 1.3296
# epsilon is 19.856128098068616, alpha is 2.8
# Epoch 1769, Loss G: 4.9905, Loss D: 1.2993
# epsilon is 19.863038631662764, alpha is 2.8
# Epoch 1770, Loss G: 4.9728, Loss D: 1.3208
# epsilon is 19.869949165256912, alpha is 2.8
# Epoch 1771, Loss G: 4.9379, Loss D: 1.4055
# epsilon is 19.876859698851057, alpha is 2.8
# Epoch 1772, Loss G: 4.9678, Loss D: 1.2317
# epsilon is 19.883770232445205, alpha is 2.8
# Epoch 1773, Loss G: 4.9788, Loss D: 1.2803
# epsilon is 19.890680766039353, alpha is 2.8
# Epoch 1774, Loss G: 4.9587, Loss D: 1.4085
# epsilon is 19.897591299633497, alpha is 2.8
# Epoch 1775, Loss G: 4.9796, Loss D: 1.3385
# epsilon is 19.904501833227645, alpha is 2.8
# Epoch 1776, Loss G: 4.9525, Loss D: 1.3378
# epsilon is 19.911412366821793, alpha is 2.8
# Epoch 1777, Loss G: 4.9673, Loss D: 1.2992
# epsilon is 19.918322900415937, alpha is 2.8
# Epoch 1778, Loss G: 4.9459, Loss D: 1.4105
# epsilon is 19.925233434010085, alpha is 2.8
# Epoch 1779, Loss G: 4.9693, Loss D: 1.4431
# epsilon is 19.932143967604233, alpha is 2.8
# Epoch 1780, Loss G: 4.9728, Loss D: 1.2870
# epsilon is 19.939054501198378, alpha is 2.8
# Epoch 1781, Loss G: 4.9419, Loss D: 1.3403
# epsilon is 19.945965034792525, alpha is 2.8
# Epoch 1782, Loss G: 4.9293, Loss D: 1.2964
# epsilon is 19.952875568386673, alpha is 2.8
# Epoch 1783, Loss G: 4.9654, Loss D: 1.3808
# epsilon is 19.959786101980818, alpha is 2.8
# Epoch 1784, Loss G: 4.9520, Loss D: 1.3816
# epsilon is 19.96669663557497, alpha is 2.8
# Epoch 1785, Loss G: 4.9090, Loss D: 1.3358
# epsilon is 19.973607169169114, alpha is 2.8
# Epoch 1786, Loss G: 4.8918, Loss D: 1.3175
# epsilon is 19.980517702763258, alpha is 2.8
# Epoch 1787, Loss G: 4.9401, Loss D: 1.2648
# epsilon is 19.98742823635741, alpha is 2.8
# Epoch 1788, Loss G: 4.9401, Loss D: 1.3259
# epsilon is 19.994338769951554, alpha is 2.8
# Epoch 1789, Loss G: 4.9636, Loss D: 1.3445
# epsilon is 20.001249303545702, alpha is 2.8
# Epoch 1790, Loss G: 4.9663, Loss D: 1.3387
# epsilon is 20.00815983713985, alpha is 2.8
# Epoch 1791, Loss G: 4.9381, Loss D: 1.2412
# epsilon is 20.015070370733994, alpha is 2.8
# Epoch 1792, Loss G: 4.9648, Loss D: 1.3701
# epsilon is 20.021980904328142, alpha is 2.8
# Epoch 1793, Loss G: 4.9611, Loss D: 1.3086
# epsilon is 20.02889143792229, alpha is 2.8
# Epoch 1794, Loss G: 4.9997, Loss D: 1.3152
# epsilon is 20.035801971516435, alpha is 2.8
# Epoch 1795, Loss G: 5.0015, Loss D: 1.3864
# epsilon is 20.042712505110583, alpha is 2.8
# Epoch 1796, Loss G: 4.9908, Loss D: 1.3210
# epsilon is 20.04962303870473, alpha is 2.8
# Epoch 1797, Loss G: 4.9520, Loss D: 1.3410
# epsilon is 20.056533572298875, alpha is 2.8
# Epoch 1798, Loss G: 4.9721, Loss D: 1.3111
# epsilon is 20.063444105893023, alpha is 2.8
# Epoch 1799, Loss G: 4.9439, Loss D: 1.3365
# epsilon is 20.07035463948717, alpha is 2.8
# Epoch 1800, Loss G: 4.9064, Loss D: 1.3397
# epsilon is 20.077265173081315, alpha is 2.8

# %%
synthetic_data_ = synth.sample(len(df_reset_copy_2))

# %%
synthetic_data_2 = synthetic_data_.copy()

# %%
#synthetic_data_['capital_net_log'] = synthetic_data_['capital_net_log'].clip(upper=max(df_reset_copy_2['capital_net_log']), lower=min(df_reset_copy_2['capital_net_log']))

# %%
import seaborn as sns

sns.displot(synthetic_data_, x="capital_net", kind="kde")

# %%
import seaborn as sns

sns.displot(df_reset_copy_2, x="capital_net", kind="kde")

# %%
synthetic_data_3 = synthetic_data_.copy()

# %%
df_reset_copy_2 = df_reset_copy.copy()
for idx, merged_lists in enumerate(current_lists):
    cols = synthetic_data_[f"merged_list_{idx}"].str.split(';', expand=True)
    synthetic_data_[merged_lists] = cols
    synthetic_data_ = synthetic_data_.drop(f"merged_list_{idx}", axis=1)

# %%
# !rm /kaggle/working/adult-data-census-complete2.csv

# %%
df_reset_copy_4 = df_reset_copy_.copy()
df_reset_copy_4 = df_reset_copy_4.drop(['fnlwgt'], axis=1)

# %%
df_reset_copy_4.to_csv("adult-data-census-complete2.csv", index=False)

# %%
data = connector.read(
    folder_name='',
    file_names=['adult-data-census-complete2.csv'],
    read_csv_parameters={
        'parse_dates': False,
        'encoding':'latin-1'
    }
)

# %%
from sdv.metadata import Metadata

metadata = Metadata.detect_from_dataframes(data)

metadata.visualize()
metadata.update_column(
    column_name='education_num',
    sdtype='numerical',
    table_name='adult-data-census-complete2'
)

metadata.validate()

# %%
metadata_dict = metadata.to_dict()
metadata_dict['columns'] = metadata_dict['tables']['adult-data-census-complete2']['columns']

# %%
df_reset_copy_6 = df_reset_copy_.copy()
df_reset_copy_ = df_reset_copy_.drop("fnlwgt", axis=1)
# Out:
#        age         workclass  fnlwgt  education_num      marital_status  \
# 0       39         State-gov   77516             13       Never-married
# 1       50  Self-emp-not-inc   83311             13  Married-civ-spouse
# 2       38           Private  215646              9            Divorced
# 3       53           Private  234721              7  Married-civ-spouse
# 4       28           Private  338409             13  Married-civ-spouse
# ...    ...               ...     ...            ...                 ...
# 32556   27           Private  257302             12  Married-civ-spouse
# 32557   40           Private  154374              9  Married-civ-spouse
# 32558   58           Private  151910              9             Widowed
# 32559   22           Private  201490              9       Never-married
# 32560   52      Self-emp-inc  287927              9  Married-civ-spouse
#
#               occupation   relationship   race     sex  hours_per_week  \
# 0           Adm-clerical  Not-in-family  White    Male              40
# 1        Exec-managerial        Husband  White    Male              13
# 2      Handlers-cleaners  Not-in-family  White    Male              40
# 3      Handlers-cleaners        Husband  Black    Male              40
# 4         Prof-specialty           Wife  Black  Female              40
# ...                  ...            ...    ...     ...             ...
# 32556       Tech-support           Wife  White  Female              38
# 32557  Machine-op-inspct        Husband  White    Male              40
# 32558       Adm-clerical      Unmarried  White  Female              40
# 32559       Adm-clerical      Own-child  White    Male              20
# 32560    Exec-managerial           Wife  White  Female              40
#
#       native_country income  capital_net
# 0      United-States  <=50K         2174
# 1      United-States  <=50K            0
# 2      United-States  <=50K            0
# 3      United-States  <=50K            0
# 4               Cuba  <=50K            0
# ...              ...    ...          ...
# 32556  United-States  <=50K            0
# 32557  United-States   >50K            0
# 32558  United-States  <=50K            0
# 32559  United-States  <=50K            0
# 32560  United-States   >50K        15024
#
# [32561 rows x 13 columns]

# %%
df_reset_copy_.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education_num', 'marital_status',
#        'occupation', 'relationship', 'race', 'sex', 'hours_per_week',
#        'native_country', 'income', 'capital_net'],
#       dtype='object')

# %%
from sdmetrics.reports.single_table import QualityReport

report = QualityReport()

report.generate(df_reset_copy_4, synthetic_data_, metadata_dict)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 65.97it/s]|
# Column Shapes Score: 88.21%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 67.33it/s]|
# Column Pair Trends Score: 70.94%
#
# Overall Score (Average): 79.57%

# %%
report.get_score()
# Out:
# np.float64(0.7957222248590756)

# %%
column_shapes = report.get_details(property_name='Column Shapes')
print(column_shapes)
# Out:
#             Column        Metric     Score
# 0              age  KSComplement  0.591474
# 1        workclass  TVComplement  0.875833
# 2    education_num  KSComplement  0.900310
# 3   marital_status  TVComplement  0.870643
# 4       occupation  TVComplement  0.784988
# 5     relationship  TVComplement  0.851847
# 6             race  TVComplement  0.950401
# 7              sex  TVComplement  0.993428
# 8   hours_per_week  KSComplement  0.889008
# 9   native_country  TVComplement  0.915942
# 10          income  TVComplement  0.981358
# 11     capital_net  KSComplement  0.979853

# %%
#synthetic_data_['capital_net'] = round(np.sign(synthetic_data_['capital_net_log']) * (np.exp2(abs(synthetic_data_['capital_net_log']))+1)).astype(int)

# %%
synthetic_data_['capital_net'] = synthetic_data_['capital_net'].clip(upper=max(df_reset_copy_['capital_net']), lower=min(df_reset_copy_['capital_net']))

# %%
for values in [100, 500, 1000, 2500, 5000, 10000, 50000, 99999]:
    x = -values
    y = values
    print("Synthetic data: ", len(synthetic_data_[synthetic_data_['capital_net']<=y][synthetic_data_['capital_net']>=x])/len(synthetic_data_), f"values range: [{x}, {y}]")
    print("Real data: ", len(df_reset_copy_[df_reset_copy_['capital_net']<=y][df_reset_copy_['capital_net']>=x])/len(df_reset_copy_), f"values range: [{x}, {y}]")
# Out:
# Synthetic data:  0.8888240533153159 values range: [-100, 100]
# Real data:  0.8700592733638401 values range: [-100, 100]
# Synthetic data:  0.8938914652498388 values range: [-500, 500]
# Real data:  0.8706427935259974 values range: [-500, 500]
# Synthetic data:  0.9000337827462301 values range: [-1000, 1000]
# Real data:  0.8728540278246982 values range: [-1000, 1000]
# Synthetic data:  0.922299683670649 values range: [-2500, 2500]
# Real data:  0.9255551119437364 values range: [-2500, 2500]
# Synthetic data:  0.956450968950585 values range: [-5000, 5000]
# Real data:  0.9493873038297349 values range: [-5000, 5000]
# Synthetic data:  0.9826172414852123 values range: [-10000, 10000]
# Real data:  0.9763520776388932 values range: [-10000, 10000]
# Synthetic data:  1.0 values range: [-50000, 50000]
# Real data:  0.9951168575903688 values range: [-50000, 50000]
# Synthetic data:  1.0 values range: [-99999, 99999]
# Real data:  1.0 values range: [-99999, 99999]

# %%
import seaborn as sns
df_reset_copy__ = df_reset_copy_.copy()
synthetic_data_ = synthetic_data_.copy()
df_reset_copy__['label'] = 'Dataset 1'
synthetic_data_['label'] = 'Dataset 2'

combined_data = pd.concat([df_reset_copy__, synthetic_data_], ignore_index=True)

sns.displot(combined_data, x="capital_net", kind="kde", hue='label')

# %%
#df_reset_copy_ = df_reset_copy_.drop('capital_net_log', axis=1)
df_reset_copy_ = df_reset_copy_.drop('fnlwgt', axis=1)

#synthetic_data_ = synthetic_data_.drop('capital_net_log', axis=1)
synthetic_data_ = synthetic_data_.drop('label', axis=1)

# %%
df_reset_copy_.to_csv("adult-data-census-complete.csv", index=False)

# %%
data = connector.read(
    folder_name='',
    file_names=['adult-data-census-complete.csv'],
    read_csv_parameters={
        'parse_dates': False,
        'encoding':'latin-1'
    }
)

# %%
from sdv.metadata import Metadata

metadata = Metadata.detect_from_dataframes(data)

metadata.visualize()
metadata.update_column(
    column_name='education_num',
    sdtype='numerical',
    table_name='adult-data-census-complete'
)

metadata.validate()

# %%
metadata_dict = metadata.to_dict()
metadata_dict['columns'] = metadata_dict['tables']['adult-data-census-complete']['columns']

# %%
from sdmetrics.reports.single_table import QualityReport

report = QualityReport()
report.generate(df_reset_copy_, synthetic_data_, metadata_dict)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 68.15it/s]|
# Column Shapes Score: 88.21%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 69.08it/s]|
# Column Pair Trends Score: 78.88%
#
# Overall Score (Average): 83.54%

# %%
column_shapes = report.get_details(property_name='Column Shapes')

# %%
column_shapes
# Out:
#             Column        Metric     Score
# 0              age  KSComplement  0.591474
# 1        workclass  TVComplement  0.875833
# 2    education_num  KSComplement  0.900310
# 3   marital_status  TVComplement  0.870643
# 4       occupation  TVComplement  0.784988
# 5     relationship  TVComplement  0.851847
# 6             race  TVComplement  0.950401
# 7              sex  TVComplement  0.993428
# 8   hours_per_week  KSComplement  0.889008
# 9   native_country  TVComplement  0.915942
# 10          income  TVComplement  0.981358
# 11     capital_net  KSComplement  0.979853

# %%
from sdmetrics.reports.single_table import DiagnosticReport

report1 = DiagnosticReport()
report1.generate(df_reset_copy_, synthetic_data_, metadata_dict)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 12/12 [00:00<00:00, 156.92it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 493.62it/s]|
# Data Structure Score: 84.62%
#
# Overall Score (Average): 92.31%

# %%
report1.get_details(
    property_name='Data Validity',
)
# Out:
#             Column             Metric  Score
# 0              age  BoundaryAdherence    1.0
# 1        workclass  CategoryAdherence    1.0
# 2    education_num  BoundaryAdherence    1.0
# 3   marital_status  CategoryAdherence    1.0
# 4       occupation  CategoryAdherence    1.0
# 5     relationship  CategoryAdherence    1.0
# 6             race  CategoryAdherence    1.0
# 7              sex  CategoryAdherence    1.0
# 8   hours_per_week  BoundaryAdherence    1.0
# 9   native_country  CategoryAdherence    1.0
# 10          income  CategoryAdherence    1.0
# 11     capital_net  BoundaryAdherence    1.0

# %%
from sdmetrics.reports.single_table import QualityReport

report2 = QualityReport()
report2.generate(df_reset_copy_, synthetic_data_, metadata_dict)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 67.79it/s]|
# Column Shapes Score: 88.21%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 67.02it/s]|
# Column Pair Trends Score: 78.88%
#
# Overall Score (Average): 83.54%

# %%
score_value_fidelity = round(report2.get_score(), ndigits=4) * 0.75 +  round(report1.get_score(), ndigits=4) * 0.25
score_value_fidelity = float(score_value_fidelity * 100)

# %%
score_value_fidelity
# Out:
# 85.73250000000002

# %%
report.get_properties()
# Out:
#              Property     Score
# 0       Column Shapes  0.882091
# 1  Column Pair Trends  0.788780

# %%
df_reset_copy_2 = df_reset_copy_.copy()

# %%
column_shapes
# Out:
#             Column        Metric     Score
# 0              age  KSComplement  0.591474
# 1        workclass  TVComplement  0.875833
# 2    education_num  KSComplement  0.900310
# 3   marital_status  TVComplement  0.870643
# 4       occupation  TVComplement  0.784988
# 5     relationship  TVComplement  0.851847
# 6             race  TVComplement  0.950401
# 7              sex  TVComplement  0.993428
# 8   hours_per_week  KSComplement  0.889008
# 9   native_country  TVComplement  0.915942
# 10          income  TVComplement  0.981358
# 11     capital_net  KSComplement  0.979853

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns

sns.displot(df_reset_copy_2, x="capital_net", kind="kde")

# %%
import seaborn as sns

sns.displot(synthetic_data_[synthetic_data_['capital_net']<=40000], x="capital_net", kind="kde")

# %% [markdown]
# Although in some of our tests, separate capital_gain and capital_loss provided better values (> higher than 0.9), we tested and the models provided worse results, so we decided to keep the them merged into a single column, capital_net. And they provided a worst result in terms of DQS.
#
# We sensed that capital_loss is zero, when capital_gain > 0, and capital_gain is zero, when capital_loss > 0, so we can create a new column called capital_net, which is the difference between capital_gain and capital_loss, and then we can drop the two columns. This helped the dataset create a more better distribution. We obtained the value of 0.528946 for capital_net.
#
# Before fixing within the snsynth library the zero-inflated column capital_net, the distribution of around zero (-500, 500) is roughly the same as across the real dataset (0.904 for synthetic, and 0.87 for real), and the subsequent drop in frequency of higher values in the synthetic dataset is more uniform and linear compared to the real data. The real dataset has "up and down" fluctuations, around 2 fluctuations around (0, 20000) and another one around 100000.
#
# Before fixing, column shapes, mainly measure differences in distribution between the real and synthetic datasets. For most columns we have values that are okay (>0.8), but for some columns such as 'capital_net', the values are low, for example 0.485949 and 'age', which it is 0.736617.  It can be seen that for 'capital_net', here is a very high peak at 0, and the high values are very rare, and there is an outlier at 1000000, but for synthetic data, the values are concentrated around values closer to zero, while never a value of zero, and then decreases sharply.
#
# After the fixing, most of the columns have values that are okay (>0.8), even 'capital_net', which now it has 0.979. But for 'age', it has now even a lower value of 0.591474 and the same for 'occupation', which is 0.785. But in other renderings, these values are different, it could be higher or lower, and this is due to the randomness of the synthetic dataset generation, but in general, these particular columns ('age' and 'occupation') have lower values than the other columns.
#
# Before these comparisons, for 'capital_net_log', there were higher outliers than in the real dataset, and in order to mantain a fidelity to the real dataset, we capped them at the maximum of the real dataset, same happen for values lower than in the real dataset.
# The same happened for 'capital_net' when we transformed the 'capital_net_log' back to 'capital_net' using the exponential function, we used the same capping technique to avoid outliers in the synthetic dataset. This helped us mantain a higher score for fidelity in 'Data Validity' section.
#
# KSComplement measuring using Kolmogorov-Smirnov the similarity in terms of distribution between the real and synthetic datasets, used for numerical and datetime columns. TVComplement, measuring using Total Variation Distance, the same similarity as KSComplement, but for categorical columns.
#
# In order to improve these results, we want to help the learn the heavy skewed distribution of capital_net for the synthetic dataset and after the synthetic dataset is generated, we reverse it back to the original distribution. But now there are a lot of values in the synthetic data that are gathered around 0 for the capital_net column, while having few outliers.

# %%
target_column = 'income'
df_reset_copy_ = df_reset_copy_2.copy()

# %%
from sklearn.model_selection import train_test_split
x_train_real, x_test_real, y_train_real, y_test_real = train_test_split(df_reset_copy_.copy().loc[:, df_reset_copy_.columns != target_column], df_reset_copy_.copy().loc[:, df_reset_copy_.columns == target_column], test_size=0.2, random_state=42)
x_train_syn, x_test_syn, y_train_syn, y_test_syn = train_test_split(synthetic_data_.copy().loc[:, synthetic_data_.columns != target_column], synthetic_data_.copy().loc[:, synthetic_data_.columns == target_column], test_size=0.2, random_state=42)

# %%
encoder = OneHotEncoder(sparse_output=False)
one_hot_encoded_y_train = encoder.fit_transform(y_train_real)
one_hot_df_y_train = pd.DataFrame(one_hot_encoded_y_train,  columns=encoder.get_feature_names_out(y_train_real.columns), index= y_train_real.index)
y_train_real = pd.concat([one_hot_df_y_train], axis=1)

# %%
y_test_real_copy = y_test_real.copy()

# %%
one_hot_encoded_y_test = encoder.transform(y_test_real)
one_hot_df_y_test = pd.DataFrame(one_hot_encoded_y_test,  columns=encoder.get_feature_names_out(y_test_real.columns), index= y_test_real.index)
y_test_real = pd.concat([one_hot_df_y_test], axis=1)

# %%
encoder = OneHotEncoder(sparse_output=False)
one_hot_encoded_y_train_syn = encoder.fit_transform(y_train_syn)
one_hot_df_y_train_syn = pd.DataFrame(one_hot_encoded_y_train_syn,  columns=encoder.get_feature_names_out(y_train_syn.columns), index= y_train_syn.index)
y_train_syn = pd.concat([one_hot_df_y_train_syn], axis=1)

one_hot_encoded_y_test_syn = encoder.transform(y_test_syn)
one_hot_df_y_test_syn = pd.DataFrame(one_hot_encoded_y_test_syn,  columns=encoder.get_feature_names_out(y_test_syn.columns), index= y_test_syn.index)
y_test_syn = pd.concat([one_hot_df_y_test_syn], axis=1)

one_hot_encoded_y_test_copy = encoder.transform(y_test_real_copy)
one_hot_df_y_test_copy = pd.DataFrame(one_hot_encoded_y_test_copy,  columns=encoder.get_feature_names_out(y_test_real_copy.columns), index= y_test_real_copy.index)
y_test_real_copy = pd.concat([one_hot_df_y_test_copy], axis=1)

# %%
is_col_OH.remove(target_column)

# %%
x_test_real_copy = x_test_real.copy()

# %%
encoder = OneHotEncoder(sparse_output=False)
one_hot_encoded_x_train = encoder.fit_transform(x_train_real[is_col_OH])
one_hot_df_x_train = pd.DataFrame(one_hot_encoded_x_train,  columns=encoder.get_feature_names_out(is_col_OH), index= x_train_real.index)
x_train_real = pd.concat([x_train_real.drop(is_col_OH, axis=1), one_hot_df_x_train], axis=1)

one_hot_encoded_x_test = encoder.transform(x_test_real[is_col_OH])
one_hot_df_x_test = pd.DataFrame(one_hot_encoded_x_test,  columns=encoder.get_feature_names_out(is_col_OH), index= x_test_real.index)
x_test_real = pd.concat([x_test_real.drop(is_col_OH, axis=1), one_hot_df_x_test], axis=1)

# %%
one_hot_encoded_x_train_syn = encoder.transform(x_train_syn[is_col_OH])
one_hot_df_x_train_syn = pd.DataFrame(one_hot_encoded_x_train_syn,  columns=encoder.get_feature_names_out(is_col_OH), index= x_train_syn.index)
x_train_syn = pd.concat([x_train_syn.drop(is_col_OH, axis=1), one_hot_df_x_train_syn], axis=1)

one_hot_encoded_x_test_syn = encoder.transform(x_test_syn[is_col_OH])
one_hot_df_x_test_syn = pd.DataFrame(one_hot_encoded_x_test_syn,  columns=encoder.get_feature_names_out(is_col_OH), index= x_test_syn.index)
x_test_syn = pd.concat([x_test_syn.drop(is_col_OH, axis=1), one_hot_df_x_test_syn], axis=1)

one_hot_encoded_x_test_copy = encoder.transform(x_test_real_copy[is_col_OH])
one_hot_df_x_test_copy = pd.DataFrame(one_hot_encoded_x_test_copy,  columns=encoder.get_feature_names_out(is_col_OH), index= x_test_real_copy.index)
x_test_real_copy = pd.concat([x_test_real_copy.drop(is_col_OH, axis=1), one_hot_df_x_test_copy], axis=1)

# %%
from scipy.stats import chi2_contingency
correlated_values_2 = {}
correlated_values_3 = {}

highest_corr_values = []
correlated_columns = set()
value_cosine_similarity = {}
for idx_col_cat in range(len(encoder.get_feature_names_out(is_col_OH))):

    for idx_col_cat_2 in range(idx_col_cat+1, len(encoder.get_feature_names_out(is_col_OH))):
        col_cat = encoder.get_feature_names_out(is_col_OH)[idx_col_cat]
        
        col_cat_2 = encoder.get_feature_names_out(is_col_OH)[idx_col_cat_2]

        
        
        contingency_table = pd.crosstab(x_train_syn[col_cat], x_train_syn[col_cat_2])
        chi2_statistic, p_value, dof, expected = chi2_contingency(contingency_table)
        n = contingency_table.sum().sum()
        phi2 = chi2_statistic / n
        r, k = contingency_table.shape
        if n == 1:
            v = 0
        else: 
            phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1))
            k_corr = k - (k - 1) * (k - 2) / (n - 1)
            r_corr = r - (r - 1) * (r - 2) / (n - 1)
            if k_corr == 1 and r_corr == 1:
                v = 0
            elif k_corr != 1 and r_corr==1:
                v = np.sqrt(phi2corr/(k_corr-1))
            elif r_corr != 1 and k_corr == 1:
                v = np.sqrt(phi2corr/(r_corr-1))
            else:
                v = np.sqrt(phi2corr / min(k_corr - 1, r_corr - 1))
        
        

        if v > 0.5:
            print("v=", v, " col_cat=", col_cat, " col_cat_2=", col_cat_2)
            

        
        if v > 0.6:
            
            if (col_cat, col_cat_2) not in correlated_columns or (col_cat_2, col_cat) not in correlated_columns:
                correlated_columns.add((col_cat, col_cat_2))
            if col_cat in correlated_values_2.keys():
                list_cat = correlated_values_2[col_cat]
                list_cat_2 = correlated_values_3[col_cat]
                list_cat.append((float(v), col_cat_2))
                list_cat_2.append(col_cat_2)
                correlated_values_2[col_cat] = list_cat
                correlated_values_3[col_cat] = list_cat_2

            else:
                correlated_values_2[col_cat] = [(float(v), col_cat_2)]
                correlated_values_3[col_cat] = [col_cat_2]
            
            if col_cat_2 in correlated_values_2.keys():
                list_cat = correlated_values_2[col_cat_2]
                list_cat_2 = correlated_values_3[col_cat_2]
                list_cat.append((float(v), col_cat))
                list_cat_2.append(col_cat)
                correlated_values_2[col_cat_2] = list_cat
                correlated_values_3[col_cat_2] = list_cat_2
            else:
                correlated_values_2[col_cat_2] = [(float(v), col_cat)]
                correlated_values_3[col_cat_2] = [col_cat]
# Out:
# v= 0.695142776525982  col_cat= workclass_Federal-gov  col_cat_2= workclass_Private
# v= 0.5172747996878211  col_cat= workclass_Local-gov  col_cat_2= workclass_Private
# v= 0.8435653972445059  col_cat= marital_status_Married-civ-spouse  col_cat_2= marital_status_Never-married
# v= 0.7455991959412174  col_cat= marital_status_Married-civ-spouse  col_cat_2= relationship_Husband
# v= 0.6019202555741295  col_cat= marital_status_Married-civ-spouse  col_cat_2= relationship_Not-in-family
# v= 0.5554308052322489  col_cat= marital_status_Married-civ-spouse  col_cat_2= relationship_Own-child
# v= 0.6290145894804285  col_cat= marital_status_Never-married  col_cat_2= relationship_Husband
# v= 0.6583792566585466  col_cat= marital_status_Never-married  col_cat_2= relationship_Own-child
# v= 0.5626804415398995  col_cat= relationship_Husband  col_cat_2= sex_Female
# v= 0.5626804415398995  col_cat= relationship_Husband  col_cat_2= sex_Male
# v= 0.5938046289750055  col_cat= relationship_Wife  col_cat_2= sex_Female
# v= 0.5938046289750055  col_cat= relationship_Wife  col_cat_2= sex_Male
# v= 0.9986347041397581  col_cat= race_Black  col_cat_2= race_White
# v= 0.9998932826737171  col_cat= sex_Female  col_cat_2= sex_Male
# v= 0.9742059889534141  col_cat= native_country_Others  col_cat_2= native_country_United-States

# %%
if len(y_train_real.columns) == 2 and target_column not in y_train_real.columns:
    y_train_real = y_train_real.drop(y_train_real.columns[0], axis=1)
    y_test_real = y_test_real.drop(y_test_real.columns[0], axis=1)
    y_test_real_copy = y_test_real_copy.drop(y_test_real_copy.columns[0], axis=1)
    y_train_syn = y_train_syn.drop(y_train_syn.columns[0], axis=1)
    y_test_syn = y_test_syn.drop(y_test_syn.columns[0], axis=1)

# %% [markdown]
# We use logistic regression, random forest, SVM, KNN and Decision Tree Classifier to evaluate the performance of the synthetic dataset, and we compare it with a real dataset.

# %%
# !pip install great_tables
# Out:
# Requirement already satisfied: great_tables in /usr/local/lib/python3.12/dist-packages (0.23.0)
# Requirement already satisfied: multimark>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.3.2)
# Requirement already satisfied: faicons>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.2.2)
# Requirement already satisfied: htmltools>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.7.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from great_tables) (8.7.1)
# Requirement already satisfied: nokap>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.1.0)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.12/dist-packages (from great_tables) (4.15.0)
# Requirement already satisfied: Babel>=2.13.1 in /usr/local/lib/python3.12/dist-packages (from great_tables) (2.18.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from great_tables) (7.1.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from htmltools>=0.4.1->great_tables) (26.1)
# Requirement already satisfied: cffi>=1.15 in /usr/local/lib/python3.12/dist-packages (from multimark>=0.1.3->great_tables) (2.0.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from multimark>=0.1.3->great_tables) (8.3.3)
# Requirement already satisfied: websockets>=12.0 in /usr/local/lib/python3.12/dist-packages (from nokap>=0.1.0->great_tables) (15.0.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->great_tables) (3.23.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.15->multimark>=0.1.3->great_tables) (3.0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, average_precision_score


model = LogisticRegression(max_iter=10000, n_jobs=-1, C=0.1, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of Logistic Regression model is: 77.96714263780132 %
# ROC of Logistic Regression model is: 72.3473386123076 %
# Precision of Logistic Regression model is: 53.786191536748326 %
# Recall of Logistic Regression model is: 61.489497135582425 %
# AUPRC of Logistic Regression model is: 42.36197278386098 %

# %%
model_name = "LogisticRegression"
hyper_parameters = "max_iter=10000, C=0.1"
type_ = "synthetic"
values_dict = {}
values_dict["model_name"] = []
values_dict["data_type"] = []
values_dict["hyper_parameters"] = []
values_dict["accuracy"] = []
values_dict["precision"] = []
values_dict["recall"] = []
values_dict["roc_auc"] = []
values_dict["auprc"] = []

values_dict["data_type"].append(type_)
values_dict["model_name"].append(model_name)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, average_precision_score


model = LogisticRegression(max_iter=10000, n_jobs=-1, C=1.0, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of Logistic Regression model is: 78.05926608321818 %
# ROC of Logistic Regression model is: 72.88565179120445 %
# Precision of Logistic Regression model is: 53.871319520174474 %
# Recall of Logistic Regression model is: 62.889879057924894 %
# AUPRC of Logistic Regression model is: 42.83093580615077 %
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model_name = "LogisticRegression"
hyper_parameters = "max_iter=10000, C=1.0"
type_ = "synthetic"
values_dict["data_type"].append(type_)
values_dict["model_name"].append(model_name)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, average_precision_score


model = LogisticRegression(max_iter=500, n_jobs=-1, C=0.1, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of Logistic Regression model is: 74.77352986335022 %
# ROC of Logistic Regression model is: 72.26191098731279 %
# Precision of Logistic Regression model is: 48.35616438356165 %
# Recall of Logistic Regression model is: 67.40929344366646 %
# AUPRC of Logistic Regression model is: 40.45774942298873 %
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model_name = "LogisticRegression"
hyper_parameters = "max_iter=500, C=0.1"
type_ = "synthetic"
values_dict["data_type"].append(type_)
values_dict["model_name"].append(model_name)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, average_precision_score


model = LogisticRegression(max_iter=2500, n_jobs=-1, C=0.1, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of Logistic Regression model is: 77.09196990634116 %
# ROC of Logistic Regression model is: 72.68244803308448 %
# Precision of Logistic Regression model is: 52.039235931853376 %
# Recall of Logistic Regression model is: 64.16295353278166 %
# AUPRC of Logistic Regression model is: 42.03416073138494 %
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model_name = "LogisticRegression"
hyper_parameters = "max_iter=2500, C=0.1"
type_ = "synthetic"
values_dict["data_type"].append(type_)
values_dict["model_name"].append(model_name)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression(max_iter=10000, n_jobs=-1, C=10.0, random_state=42)
model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of Logistic Regression model is: 84.99923230462153 %
# ROC of Logistic Regression model is: 76.30809561505443 %
# Precision of Logistic Regression model is: 73.27586206896551 %
# Recall of Logistic Regression model is: 59.516231699554424 %
# AUPRC of Logistic Regression model is: 53.37611706299844 %

# %%
model_name = "LogisticRegression"
hyper_parameters = "max_iter=10000, C=10.0"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression(max_iter=50, n_jobs=-1, C=0.1, random_state=42)
model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of Logistic Regression model is: 80.0092123445417 %
# ROC of Logistic Regression model is: 68.30899155860432 %
# Precision of Logistic Regression model is: 61.52527849185947 %
# Recall of Logistic Regression model is: 45.70337364735837 %
# AUPRC of Logistic Regression model is: 41.21601107347574 %

# %%
model_name = "LogisticRegression"
hyper_parameters = "max_iter=50, C=0.1"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
# !pip install polars
# !pip install great_tables
# Out:
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (1.35.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars) (1.35.2)
# Requirement already satisfied: great_tables in /usr/local/lib/python3.12/dist-packages (0.23.0)
# Requirement already satisfied: multimark>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.3.2)
# Requirement already satisfied: faicons>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.2.2)
# Requirement already satisfied: htmltools>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.7.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from great_tables) (8.7.1)
# Requirement already satisfied: nokap>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from great_tables) (0.1.0)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.12/dist-packages (from great_tables) (4.15.0)
# Requirement already satisfied: Babel>=2.13.1 in /usr/local/lib/python3.12/dist-packages (from great_tables) (2.18.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from great_tables) (7.1.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from htmltools>=0.4.1->great_tables) (26.1)
# Requirement already satisfied: cffi>=1.15 in /usr/local/lib/python3.12/dist-packages (from multimark>=0.1.3->great_tables) (2.0.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from multimark>=0.1.3->great_tables) (8.3.3)
# Requirement already satisfied: websockets>=12.0 in /usr/local/lib/python3.12/dist-packages (from nokap>=0.1.0->great_tables) (15.0.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->great_tables) (3.23.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.15->multimark>=0.1.3->great_tables) (3.0)

# %%
model = RandomForestClassifier(max_depth=10, max_samples=0.9, n_estimators=200, n_jobs=-1, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of RandomForestClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of RandomForestClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of RandomForestClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of RandomForestClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of RandomForestClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")

model = RandomForestClassifier(max_depth=10, max_samples=0.8, n_estimators=50, n_jobs=-1, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred_2 = model.predict(x_test_real)
print("Accuracy of RandomForestClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of RandomForestClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of RandomForestClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of RandomForestClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of RandomForestClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
# Out:
# Accuracy of RandomForestClassifier model is: 79.82496545370796 %
# ROC of RandomForestClassifier model is: 66.1468901768471 %
# Precision of RandomForestClassifier model is: 62.96670030272452 %
# Recall of RandomForestClassifier model is: 39.71992361553151 %
# AUPRC of RandomForestClassifier model is: 39.550475731757004 %
#
# Accuracy of RandomForestClassifier model is: 79.91708889912482 %
# ROC of RandomForestClassifier model is: 65.88195183801093 %
# Precision of RandomForestClassifier model is: 63.769633507853406 %
# Recall of RandomForestClassifier model is: 38.76511775938892 %
# AUPRC of RandomForestClassifier model is: 39.49083260588644 %

# %%
model_name = "RandomForestClassifier"
hyper_parameters = "max_depth=10, max_samples=0.9, n_estimators=200"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))


model_name = "RandomForestClassifier"
hyper_parameters = "max_depth=50, max_samples=0.8, n_estimators=50"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

# %%
model = RandomForestClassifier(max_depth=10, max_samples=0.8, n_estimators=100, n_jobs=-1, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred_2 = model.predict(x_test_real)
print("Accuracy of RandomForestClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of RandomForestClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of RandomForestClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of RandomForestClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of RandomForestClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print(" ")

model = RandomForestClassifier(max_depth=10, max_samples=0.8, n_estimators=200, n_jobs=-1, random_state=42)
model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred_3 = model.predict(x_test_real)
print("Accuracy of RandomForestClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("ROC of RandomForestClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Precision of RandomForestClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Recall of RandomForestClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("AUPRC of RandomForestClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
# Out:
# Accuracy of RandomForestClassifier model is: 79.8710271764164 %
# ROC of RandomForestClassifier model is: 66.17724226102355 %
# Precision of RandomForestClassifier model is: 63.1578947368421 %
# Recall of RandomForestClassifier model is: 39.71992361553151 %
# AUPRC of RandomForestClassifier model is: 39.62641801494566 %
#
# Accuracy of RandomForestClassifier model is: 79.61001074773529 %
# ROC of RandomForestClassifier model is: 65.67960461016796 %
# Precision of RandomForestClassifier model is: 62.46153846153846 %
# Recall of RandomForestClassifier model is: 38.76511775938892 %
# AUPRC of RandomForestClassifier model is: 38.98374802077772 %

# %%
model_name = "RandomForestClassifier"
hyper_parameters = "max_depth=10, max_samples=0.8, n_estimators=100"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))


model_name = "RandomForestClassifier"
hyper_parameters = "max_depth=10, max_samples=0.8, n_estimators=100"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))

# %%
model = RandomForestClassifier(max_depth=100, max_samples=0.5, n_estimators=200, n_jobs=-1, random_state=42)
model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred = model.predict(x_test_real)
print("Accuracy of RandomForestClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of RandomForestClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of RandomForestClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of RandomForestClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of RandomForestClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")


print(" ")
model = RandomForestClassifier(max_depth=10, max_samples=0.8, n_estimators=100, n_jobs=-1, random_state=42)
model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred_2 = model.predict(x_test_real)
print("Accuracy of RandomForestClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of RandomForestClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of RandomForestClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of RandomForestClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of RandomForestClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
# Out:
# Accuracy of RandomForestClassifier model is: 85.81298940580378 %
# ROC of RandomForestClassifier model is: 78.14688579759455 %
# Precision of RandomForestClassifier model is: 74.08786299329859 %
# Recall of RandomForestClassifier model is: 63.33545512412476 %
# AUPRC of RandomForestClassifier model is: 55.76773597856209 %
#
# Accuracy of RandomForestClassifier model is: 85.7976354982343 %
# ROC of RandomForestClassifier model is: 75.35795237485577 %
# Precision of RandomForestClassifier model is: 79.6875 %
# Recall of RandomForestClassifier model is: 55.18777848504137 %
# AUPRC of RandomForestClassifier model is: 54.78691190917875 %

# %%
model_name = "RandomForestClassifier"
hyper_parameters = "max_depth=100, max_samples=0.5, n_estimators=200"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict['auprc'].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))


model_name = "RandomForestClassifier"
hyper_parameters = "max_depth=10, max_samples=0.8, n_estimators=100"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict['auprc'].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

# %%
model = RandomForestClassifier(max_depth=10, max_samples=0.8, n_estimators=200, n_jobs=-1, random_state=42)
model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred_2 = model.predict(x_test_real)
print("Accuracy of RandomForestClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of RandomForestClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of RandomForestClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of RandomForestClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of RandomForestClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
# Out:
# Accuracy of RandomForestClassifier model is: 85.78228159066482 %
# ROC of RandomForestClassifier model is: 75.32612551298435 %
# Precision of RandomForestClassifier model is: 79.6688132474701 %
# Recall of RandomForestClassifier model is: 55.12412476129853 %
# AUPRC of RandomForestClassifier model is: 54.74124084686224 %

# %%
model_name = "RandomForestClassifier"
hyper_parameters = "max_depth=10, max_samples=0.8, n_estimators=200"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict['auprc'].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

# %%
from sklearn import svm

model_simple = svm.SVC(
    random_state=42, C=10.0, max_iter=10000, decision_function_shape="ovr"
)
model_simple.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of Logistic Regression model is: 77.78289574696761 %
# ROC of Logistic Regression model is: 56.768765934361184 %
# Precision of Logistic Regression model is: 66.14583333333334 %
# Recall of Logistic Regression model is: 16.168045830681095 %
# AUPRC of Logistic Regression model is: 30.915584917419725 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=10.0, max_iter=10000, decision_function_shape=ovr"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn import svm

model_simple = svm.SVC(
    random_state=42, C=10.0, max_iter=5000, decision_function_shape="ovo"
)
model_simple.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of Logistic Regression model is: 21.249808076155382 %
# ROC of Logistic Regression model is: 40.444599750485644 %
# Precision of Logistic Regression model is: 20.32032032032032 %
# Recall of Logistic Regression model is: 77.53023551877784 %
# AUPRC of Logistic Regression model is: 21.174321574539597 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=10.0, max_iter=5000, decision_function_shape=ovo"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
from sklearn import svm

model_simple = svm.SVC(
    random_state=42, C=1.0, max_iter=10000, decision_function_shape="ovo"
)
model_simple.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of Logistic Regression model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of Logistic Regression model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of Logistic Regression model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of Logistic Regression model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of Logistic Regression model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")
model_simple = svm.SVC(
    random_state=42, C=10.0, max_iter=1500, decision_function_shape="ovo"
)
model_simple.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred_2 = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")


print(" ")
model_simple = svm.SVC(
    random_state=42, C=100.0, max_iter=6330, decision_function_shape="ovr"
)
model_simple.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
y_pred_3 = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of Logistic Regression model is: 78.36634423460771 %
# ROC of Logistic Regression model is: 57.97818668547512 %
# Precision of Logistic Regression model is: 69.19431279620854 %
# Recall of Logistic Regression model is: 18.586887332908976 %
# AUPRC of Logistic Regression model is: 32.49871674157225 %
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=1500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of svm.SVC model is: 20.574236143098418 %
# ROC of svm.SVC model is: 36.829848779257595 %
# Precision of svm.SVC model is: 18.65645666550644 %
# Recall of svm.SVC model is: 68.23679185232336 %
# AUPRC of svm.SVC model is: 20.392167379029274 %
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=6330).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of svm.SVC model is: 77.96714263780132 %
# ROC of svm.SVC model is: 56.10863225381324 %
# Precision of svm.SVC model is: 72.66666666666667 %
# Recall of svm.SVC model is: 13.876511775938894 %
# AUPRC of svm.SVC model is: 30.85743549868387 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=1.0, max_iter=10000, decision_function_shape=ovr"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

model_name = "svm.SVC"
hyper_parameters = "C=10.0, max_iter=1500, decision_function_shape=ovo"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))


model_name = "svm.SVC"
hyper_parameters = "C=100.0, max_iter=6330, decision_function_shape=ovr"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))

# %%
model_simple = svm.SVC(
    random_state=42, C=10.0, max_iter=10000, decision_function_shape="ovr"
)
model_simple.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of svm.SVC model is: 80.74619990787656 %
# ROC of svm.SVC model is: 62.933059776024415 %
# Precision of svm.SVC model is: 77.37478411053542 %
# Recall of svm.SVC model is: 28.516868236791854 %
# AUPRC of svm.SVC model is: 39.30730343382558 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=10.0, max_iter=10000, decision_function_shape=ovr"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = svm.SVC(
    random_state=42, C=1.0, max_iter=10000, decision_function_shape="ovr"
)
model_simple.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of svm.SVC model is: 80.66943037002918 %
# ROC of svm.SVC model is: 62.88247296906366 %
# Precision of svm.SVC model is: 76.71232876712328 %
# Recall of svm.SVC model is: 28.516868236791854 %
# AUPRC of svm.SVC model is: 39.11839191641715 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=1.0, max_iter=10000, decision_function_shape=ovr"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = svm.SVC(
    random_state=42, C=10.0, max_iter=5000, decision_function_shape="ovr"
)
model_simple.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of svm.SVC model is: 21.387993244280672 %
# ROC of svm.SVC model is: 44.291399585928794 %
# Precision of svm.SVC model is: 21.971252566735114 %
# Recall of svm.SVC model is: 88.542329726289 %
# AUPRC of svm.SVC model is: 22.217562255140095 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=10.0, max_iter=5000, decision_function_shape=ovr"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = svm.SVC(
    random_state=42, C=10.0, max_iter=5375, decision_function_shape="ovr"
)
model_simple.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred_2 = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")

print(" ")
model_simple = svm.SVC(
    random_state=42, C=0.1, max_iter=500, decision_function_shape="ovo"
)
model_simple.fit(x_train_real, y_train_real[y_train_real.columns[0]])
y_pred_3 = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5375).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of svm.SVC model is: 80.37770612620912 %
# ROC of svm.SVC model is: 63.51520412082512 %
# Precision of svm.SVC model is: 71.5758468335788 %
# Recall of svm.SVC model is: 30.935709739019735 %
# AUPRC of svm.SVC model is: 38.80148593256321 %
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of svm.SVC model is: 19.83724857976355 %
# ROC of svm.SVC model is: 40.838082031643445 %
# Precision of svm.SVC model is: 20.602448453608247 %
# Recall of svm.SVC model is: 81.41311266709103 %
# AUPRC of svm.SVC model is: 21.256435582002553 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=10.0, max_iter=5375, decision_function_shape=ovr"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

model_name = "svm.SVC"
hyper_parameters = "C=0.1, max_iter=500, decision_function_shape=ovo"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))

# %%
is_col_numeric.remove("capital_gain")
is_col_numeric.remove("capital_loss")
is_col_numeric.append("capital_net")

# %%
x_train_syn_copy = x_train_syn.copy()
x_test_syn_copy = x_test_syn.copy()

x_train_real_copy = x_train_real.copy()
x_test_real_copy = x_test_real.copy()

# %%
y_train_syn_copy = y_train_syn.copy()
y_test_syn_copy = y_test_syn.copy()

y_train_real_copy = y_train_real.copy()
y_test_real_copy = y_test_real.copy()

# %%
is_col_numeric.remove("fnlwgt")

# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train_syn[is_col_numeric])
x_train_syn_scaled = scaler.transform(x_train_syn[is_col_numeric])
x_test_syn_scaled = scaler.transform(x_test_syn[is_col_numeric])
x_test_real_scaled = scaler.transform(x_test_real[is_col_numeric])
x_train_real_scaled = scaler.transform(x_train_real[is_col_numeric])

# %%
x_test_real_copy[is_col_numeric] = x_test_real_scaled
x_train_real_copy[is_col_numeric] = x_train_real_scaled
x_train_syn_copy[is_col_numeric] = x_train_syn_scaled
x_test_syn_copy[is_col_numeric] = x_test_syn_scaled

# %% [markdown]
# Precision and recall produce nan values for knn neighbors classifier, so we do not use them.

# %%
model_simple = KNeighborsClassifier(n_neighbors=50, leaf_size=200)
model_simple.fit(x_train_syn_scaled, y_train_syn_copy[y_train_syn_copy.columns[0]])
y_pred = model_simple.predict(x_test_real_scaled)
print("Accuracy of KNeighborsClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of KNeighborsClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of KNeighborsClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of KNeighborsClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of KNeighborsClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")
model_simple = KNeighborsClassifier(n_neighbors=200, leaf_size=200)
model_simple.fit(x_train_syn_scaled, y_train_syn_copy[y_train_syn_copy.columns[0]])
y_pred_2 = model_simple.predict(x_test_real_scaled)
print("Accuracy of KNeighborsClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of KNeighborsClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of KNeighborsClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of KNeighborsClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of KNeighborsClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
# Out:
# Accuracy of KNeighborsClassifier model is: 71.90234914785812 %
# ROC of KNeighborsClassifier model is: 62.250611227733756 %
# Precision of KNeighborsClassifier model is: 42.050337630448126 %
# Recall of KNeighborsClassifier model is: 43.602800763844684 %
# AUPRC of KNeighborsClassifier model is: 31.938687044084425 %
#
# Accuracy of KNeighborsClassifier model is: 76.52387532627054 %
# ROC of KNeighborsClassifier model is: 61.43164592146043 %
# Precision of KNeighborsClassifier model is: 52.160493827160494 %
# Recall of KNeighborsClassifier model is: 32.27243793761935 %
# AUPRC of KNeighborsClassifier model is: 33.170020652249065 %

# %%
model_name = "KNeighborsClassifier"
hyper_parameters = "n_neighbors=50, leaf_size=200"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

model_name = "KNeighborsClassifier"
hyper_parameters = "n_neighbors=200, leaf_size=200"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

# %%
model_simple = KNeighborsClassifier(n_neighbors=5, leaf_size=200)
model_simple.fit(x_train_syn_scaled, y_train_syn_copy[y_train_syn_copy.columns[0]])
y_pred = model_simple.predict(x_test_real_scaled)
print("Accuracy of KNeighborsClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of KNeighborsClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of KNeighborsClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of KNeighborsClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of KNeighborsClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")
# Out:
# Accuracy of KNeighborsClassifier model is: 67.80285582680791 %
# ROC of KNeighborsClassifier model is: 62.5668963026486 %
# Precision of KNeighborsClassifier model is: 37.90248390064397 %
# Recall of KNeighborsClassifier model is: 52.45066836409929 %
# AUPRC of KNeighborsClassifier model is: 31.349475086881796 %

# %%
model_name = "KNeighborsClassifier"
hyper_parameters = "n_neighbors=5, leaf_size=200"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = KNeighborsClassifier(n_neighbors=50, leaf_size=30)
model_simple.fit(x_train_real_scaled, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred = model_simple.predict(x_test_real_scaled)
print("Accuracy of KNeighborsClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of KNeighborsClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of KNeighborsClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of KNeighborsClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of KNeighborsClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of KNeighborsClassifier model is: 81.25287885766927 %
# ROC of KNeighborsClassifier model is: 64.28727922449104 %
# Precision of KNeighborsClassifier model is: 77.34375 %
# Recall of KNeighborsClassifier model is: 31.508593252705285 %
# AUPRC of KNeighborsClassifier model is: 40.89073213864589 %

# %%
model_name = "KNeighborsClassifier"
hyper_parameters = "n_neighbors=50, leaf_size=30"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = KNeighborsClassifier(n_neighbors=5, leaf_size=200)
model_simple.fit(x_train_real_scaled, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred = model_simple.predict(x_test_real_scaled)
print("Accuracy of KNeighborsClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of KNeighborsClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of KNeighborsClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of KNeighborsClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of KNeighborsClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of KNeighborsClassifier model is: 79.37970213419315 %
# ROC of KNeighborsClassifier model is: 65.310749184493 %
# Precision of KNeighborsClassifier model is: 61.75257731958763 %
# Recall of KNeighborsClassifier model is: 38.12858052196054 %
# AUPRC of KNeighborsClassifier model is: 38.469379325216 %

# %%
model_name = "KNeighborsClassifier"
hyper_parameters = "n_neighbors=5, leaf_size=200"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = KNeighborsClassifier(n_neighbors=200, leaf_size=50)
model_simple.fit(x_train_real_scaled, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred = model_simple.predict(x_test_real_scaled)
print("Accuracy of KNeighborsClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of KNeighborsClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of KNeighborsClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of KNeighborsClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of KNeighborsClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of KNeighborsClassifier model is: 80.9765085214187 %
# ROC of KNeighborsClassifier model is: 62.064473674380935 %
# Precision of KNeighborsClassifier model is: 85.31914893617021 %
# Recall of KNeighborsClassifier model is: 25.52514322087842 %
# AUPRC of KNeighborsClassifier model is: 39.74190681707944 %

# %%
model_name = "KNeighborsClassifier"
hyper_parameters = "n_neighbors=200, leaf_size=50"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = KNeighborsClassifier(n_neighbors=50, leaf_size=2)
model_simple.fit(x_train_real_scaled, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred_2 = model_simple.predict(x_test_real_scaled)
print("Accuracy of KNeighborsClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of KNeighborsClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of KNeighborsClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of KNeighborsClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of KNeighborsClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
# Out:
# Accuracy of KNeighborsClassifier model is: 81.13004759711346 %
# ROC of KNeighborsClassifier model is: 63.83727882520627 %
# Precision of KNeighborsClassifier model is: 77.85016286644951 %
# Recall of KNeighborsClassifier model is: 30.426479949077024 %
# AUPRC of KNeighborsClassifier model is: 40.468885168321805 %

# %%
model_name = "KNeighborsClassifier"
hyper_parameters = "n_neighbors=50, leaf_size=2"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_simple = DecisionTreeClassifier(criterion='entropy', min_samples_split=50, min_samples_leaf=100)
model_simple.fit(x_train_syn, y_train_syn_copy[y_train_syn_copy.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of DecisionTreeClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of DecisionTreeClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of DecisionTreeClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of DecisionTreeClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of DecisionTreeClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")
# Out:
# Accuracy of DecisionTreeClassifier model is: 78.16674343620451 %
# ROC of DecisionTreeClassifier model is: 63.27403610719483 %
# Precision of DecisionTreeClassifier model is: 57.967914438502675 %
# Recall of DecisionTreeClassifier model is: 34.50031826861871 %
# AUPRC of DecisionTreeClassifier model is: 35.79828586395525 %

# %%
model_name = "DecisionTreeClassifier"
hyper_parameters = "criterion='entropy', min_samples_split=50, min_samples_leaf=100"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = DecisionTreeClassifier(criterion='gini', min_samples_split=20, min_samples_leaf=100)
model_simple.fit(x_train_syn, y_train_syn_copy[y_train_syn_copy.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of DecisionTreeClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of DecisionTreeClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of DecisionTreeClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of DecisionTreeClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of DecisionTreeClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")

print(" ")
# Out:
# Accuracy of DecisionTreeClassifier model is: 78.12068171349608 %
# ROC of DecisionTreeClassifier model is: 65.24095806711126 %
# Precision of DecisionTreeClassifier model is: 56.50623885918004 %
# Recall of DecisionTreeClassifier model is: 40.3564608529599 %
# AUPRC of DecisionTreeClassifier model is: 37.19052955728442 %

# %%
model_name = "DecisionTreeClassifier"
hyper_parameters = "criterion='gini', min_samples_split=20, min_samples_leaf=100"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = DecisionTreeClassifier(criterion='log_loss', min_samples_split=20, min_samples_leaf=100)
model_simple.fit(x_train_syn, y_train_syn_copy[y_train_syn_copy.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of DecisionTreeClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of DecisionTreeClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of DecisionTreeClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of DecisionTreeClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of DecisionTreeClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print(" ")
model_simple = DecisionTreeClassifier(criterion='log_loss', min_samples_split=2, min_samples_leaf=1)
model_simple.fit(x_train_syn, y_train_syn_copy[y_train_syn_copy.columns[0]])
y_pred_2 = model_simple.predict(x_test_real)
print("Accuracy of DecisionTreeClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of DecisionTreeClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of DecisionTreeClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of DecisionTreeClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of DecisionTreeClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
# Out:
# Accuracy of DecisionTreeClassifier model is: 78.33563641946876 %
# ROC of DecisionTreeClassifier model is: 63.29848908059138 %
# Precision of DecisionTreeClassifier model is: 58.73362445414847 %
# Recall of DecisionTreeClassifier model is: 34.24570337364736 %
# AUPRC of DecisionTreeClassifier model is: 35.974329330428844 %
#
# Accuracy of DecisionTreeClassifier model is: 75.26485490557346 %
# ROC of DecisionTreeClassifier model is: 62.751262834752 %
# Precision of DecisionTreeClassifier model is: 48.402555910543136 %
# Recall of DecisionTreeClassifier model is: 38.574156588160406 %
# AUPRC of DecisionTreeClassifier model is: 33.48739851414956 %

# %%
model_name = "DecisionTreeClassifier"
hyper_parameters = "criterion='log_loss', min_samples_split=20, min_samples_leaf=100"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

model_name = "DecisionTreeClassifier"
hyper_parameters = "criterion='log_loss', min_samples_split=2, min_samples_leaf=1"
type_ = "synthetic"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

# %%
model_simple = DecisionTreeClassifier(criterion='entropy', min_samples_split=50, min_samples_leaf=100)
model_simple.fit(x_train_real, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of DecisionTreeClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of DecisionTreeClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Precision of DecisionTreeClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of DecisionTreeClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of DecisionTreeClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
# Out:
# Accuracy of DecisionTreeClassifier model is: 85.50591125441424 %
# ROC of DecisionTreeClassifier model is: 75.94726452565868 %
# Precision of DecisionTreeClassifier model is: 76.59033078880407 %
# Recall of DecisionTreeClassifier model is: 57.47931253978358 %
# AUPRC of DecisionTreeClassifier model is: 54.28000586576104 %

# %%
model_name = "DecisionTreeClassifier"
hyper_parameters = "criterion='entropy', min_samples_split=50, min_samples_leaf=100"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
model_simple = DecisionTreeClassifier(criterion='gini', min_samples_split=200, min_samples_leaf=1)
model_simple.fit(x_train_real, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred_2 = model_simple.predict(x_test_real)
print("Accuracy of DecisionTreeClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("ROC of DecisionTreeClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of DecisionTreeClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Recall of DecisionTreeClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("AUPRC of DecisionTreeClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")

print(" ")
# Out:
# Accuracy of DecisionTreeClassifier model is: 86.16612927990174 %
# ROC of DecisionTreeClassifier model is: 77.83684759763221 %
# Precision of DecisionTreeClassifier model is: 76.37795275590551 %
# Recall of DecisionTreeClassifier model is: 61.74411203055379 %
# AUPRC of DecisionTreeClassifier model is: 56.38658716550508 %

# %%
model_simple = DecisionTreeClassifier(criterion='entropy', min_samples_split=50, min_samples_leaf=100)
model_simple.fit(x_train_real, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred_3 = model_simple.predict(x_test_real)
print("Accuracy of DecisionTreeClassifier model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("ROC of DecisionTreeClassifier model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Precision of DecisionTreeClassifier model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("Recall of DecisionTreeClassifier model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
print("AUPRC of DecisionTreeClassifier model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred_3)*100, "%")
# Out:
# Accuracy of DecisionTreeClassifier model is: 85.50591125441424 %
# ROC of DecisionTreeClassifier model is: 75.94726452565868 %
# Precision of DecisionTreeClassifier model is: 76.59033078880407 %
# Recall of DecisionTreeClassifier model is: 57.47931253978358 %
# AUPRC of DecisionTreeClassifier model is: 54.28000586576104 %

# %%
model_name = "DecisionTreeClassifier"
hyper_parameters = "criterion='gini', min_samples_split=200, min_samples_leaf=1"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_2))

model_name = "DecisionTreeClassifier"
hyper_parameters = "criterion='entropy', min_samples_split=50, min_samples_leaf=10"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred_3))

# %%
model_simple = svm.SVC(C=10.0, max_iter=5000, decision_function_shape="ovo")
model_simple.fit(x_train_real, y_train_real_copy[y_train_real_copy.columns[0]])
y_pred = model_simple.predict(x_test_real)
print("Accuracy of svm.SVC model is:", accuracy_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("ROC of svm.SVC model is:", roc_auc_score(y_test_real[y_test_real.columns[0]], y_pred_2)*100, "%")
print("Precision of svm.SVC model is:", precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("Recall of svm.SVC model is:", recall_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print("AUPRC of svm.SVC model is:", average_precision_score(y_test_real[y_test_real.columns[0]], y_pred)*100, "%")
print(" ")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy of svm.SVC model is: 21.387993244280672 %
# ROC of svm.SVC model is: 77.83684759763221 %
# Precision of svm.SVC model is: 21.971252566735114 %
# Recall of svm.SVC model is: 88.542329726289 %
# AUPRC of svm.SVC model is: 22.217562255140095 %

# %%
model_name = "svm.SVC"
hyper_parameters = "C=10.0, max_iter=5000, decision_function_shape='ovo'"
type_ = "real"

values_dict["model_name"].append(model_name)
values_dict["data_type"].append(type_)
values_dict["hyper_parameters"].append(hyper_parameters)
values_dict["accuracy"].append(accuracy_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["precision"].append(precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["recall"].append(recall_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["roc_auc"].append(roc_auc_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))
values_dict["auprc"].append(average_precision_score(y_test_real_copy[y_test_real_copy.columns[0]], y_pred))

# %%
table_element_real = pd.DataFrame({'model_name': values_dict['model_name'], 'data_type':values_dict['data_type'], 'hyper_parameters': values_dict['hyper_parameters'], 'accuracy':values_dict['accuracy'], 'precision':values_dict['precision'], 'recall':values_dict['recall'], 'auprc':values_dict['auprc'] ,'roc_auc':values_dict['roc_auc']})

# %%
table_element_real
# Out:
#                 model_name  data_type  \
# 0       LogisticRegression  synthetic
# 1       LogisticRegression  synthetic
# 2       LogisticRegression  synthetic
# 3       LogisticRegression  synthetic
# 4       LogisticRegression       real
# 5       LogisticRegression       real
# 6   RandomForestClassifier  synthetic
# 7   RandomForestClassifier  synthetic
# 8   RandomForestClassifier  synthetic
# 9   RandomForestClassifier  synthetic
# 10  RandomForestClassifier       real
# 11  RandomForestClassifier       real
# 12  RandomForestClassifier       real
# 13                 svm.SVC  synthetic
# 14                 svm.SVC  synthetic
# 15                 svm.SVC  synthetic
# 16                 svm.SVC  synthetic
# 17                 svm.SVC  synthetic
# 18                 svm.SVC       real
# 19                 svm.SVC       real
# 20                 svm.SVC       real
# 21                 svm.SVC       real
# 22                 svm.SVC       real
# 23    KNeighborsClassifier  synthetic
# 24    KNeighborsClassifier  synthetic
# 25    KNeighborsClassifier  synthetic
# 26    KNeighborsClassifier       real
# 27    KNeighborsClassifier       real
# 28    KNeighborsClassifier       real
# 29    KNeighborsClassifier       real
# 30  DecisionTreeClassifier  synthetic
# 31  DecisionTreeClassifier  synthetic
# 32  DecisionTreeClassifier  synthetic
# 33  DecisionTreeClassifier  synthetic
# 34  DecisionTreeClassifier       real
# 35  DecisionTreeClassifier       real
# 36  DecisionTreeClassifier       real
# 37                 svm.SVC       real
#
#                                      hyper_parameters  accuracy  precision  \
# 0                               max_iter=10000, C=0.1  0.779671   0.537862
# 1                               max_iter=10000, C=1.0  0.780593   0.538713
# 2                                 max_iter=500, C=0.1  0.747735   0.483562
# 3                                max_iter=2500, C=0.1  0.770920   0.520392
# 4                              max_iter=10000, C=10.0  0.849992   0.732759
# 5                                  max_iter=50, C=0.1  0.800092   0.615253
# 6     max_depth=10, max_samples=0.9, n_estimators=200  0.798250   0.629667
# 7      max_depth=50, max_samples=0.8, n_estimators=50  0.799171   0.637696
# 8     max_depth=10, max_samples=0.8, n_estimators=100  0.798710   0.631579
# 9     max_depth=10, max_samples=0.8, n_estimators=100  0.796100   0.624615
# 10   max_depth=100, max_samples=0.5, n_estimators=200  0.858130   0.740879
# 11    max_depth=10, max_samples=0.8, n_estimators=100  0.857976   0.796875
# 12    max_depth=10, max_samples=0.8, n_estimators=200  0.857823   0.796688
# 13  C=10.0, max_iter=10000, decision_function_shap...  0.777829   0.661458
# 14  C=10.0, max_iter=5000, decision_function_shape...  0.212498   0.203203
# 15  C=1.0, max_iter=10000, decision_function_shape...  0.783663   0.691943
# 16  C=10.0, max_iter=1500, decision_function_shape...  0.205742   0.186565
# 17  C=100.0, max_iter=6330, decision_function_shap...  0.779671   0.726667
# 18  C=10.0, max_iter=10000, decision_function_shap...  0.807462   0.773748
# 19  C=1.0, max_iter=10000, decision_function_shape...  0.806694   0.767123
# 20  C=10.0, max_iter=5000, decision_function_shape...  0.213880   0.219713
# 21  C=10.0, max_iter=5375, decision_function_shape...  0.803777   0.715758
# 22   C=0.1, max_iter=500, decision_function_shape=ovo  0.198372   0.206024
# 23                      n_neighbors=50, leaf_size=200  0.719023   0.420503
# 24                     n_neighbors=200, leaf_size=200  0.765239   0.521605
# 25                       n_neighbors=5, leaf_size=200  0.678029   0.379025
# 26                       n_neighbors=50, leaf_size=30  0.812529   0.773438
# 27                       n_neighbors=5, leaf_size=200  0.793797   0.617526
# 28                      n_neighbors=200, leaf_size=50  0.809765   0.853191
# 29                        n_neighbors=50, leaf_size=2  0.811300   0.778502
# 30  criterion='entropy', min_samples_split=50, min...  0.781667   0.579679
# 31  criterion='gini', min_samples_split=20, min_sa...  0.781207   0.565062
# 32  criterion='log_loss', min_samples_split=20, mi...  0.783356   0.587336
# 33  criterion='log_loss', min_samples_split=2, min...  0.752649   0.484026
# 34  criterion='entropy', min_samples_split=50, min...  0.855059   0.765903
# 35  criterion='gini', min_samples_split=200, min_s...  0.861661   0.763780
# 36  criterion='entropy', min_samples_split=50, min...  0.855059   0.765903
# 37  C=10.0, max_iter=5000, decision_function_shape...  0.213880   0.219713
#
#       recall     auprc   roc_auc
# 0   0.614895  0.423620  0.723473
# 1   0.628899  0.428309  0.728857
# 2   0.674093  0.404577  0.722619
# 3   0.641630  0.420342  0.726824
# 4   0.595162  0.533761  0.763081
# 5   0.457034  0.412160  0.683090
# 6   0.397199  0.395505  0.661469
# 7   0.387651  0.394908  0.658820
# 8   0.397199  0.396264  0.661772
# 9   0.387651  0.389837  0.656796
# 10  0.633355  0.557677  0.781469
# 11  0.551878  0.547869  0.753580
# 12  0.551241  0.547412  0.753261
# 13  0.161680  0.309156  0.567688
# 14  0.775302  0.211743  0.404446
# 15  0.185869  0.324987  0.579782
# 16  0.682368  0.203922  0.368298
# 17  0.138765  0.308574  0.561086
# 18  0.285169  0.393073  0.629331
# 19  0.285169  0.391184  0.628825
# 20  0.885423  0.222176  0.442914
# 21  0.309357  0.388015  0.635152
# 22  0.814131  0.212564  0.408381
# 23  0.436028  0.319387  0.622506
# 24  0.322724  0.331700  0.614316
# 25  0.524507  0.313495  0.625669
# 26  0.315086  0.408907  0.642873
# 27  0.381286  0.384694  0.653107
# 28  0.255251  0.397419  0.620645
# 29  0.304265  0.404689  0.638373
# 30  0.345003  0.357983  0.632740
# 31  0.403565  0.371905  0.652410
# 32  0.342457  0.359743  0.632985
# 33  0.385742  0.334874  0.627513
# 34  0.574793  0.542800  0.759473
# 35  0.617441  0.563866  0.778368
# 36  0.574793  0.542800  0.759473
# 37  0.885423  0.222176  0.442914

# %%
import polars as pl

from great_tables import GT, from_column, style, loc
from great_tables.data import airquality
table_element_real = table_element_real.sort_values(by=['model_name', 'auprc', 'data_type'], ascending=False, ignore_index=True)

gt_table_element = GT(table_element_real)
location_list = []
for idx, elements in enumerate(table_element_real.columns):
    if "accuracy" in elements or "precision" in elements or "auprc" in elements or "recall" in elements or "roc_auc" in elements:
        pos_min, pos_max = (np.argmin(table_element_real[elements]), np.argmax(table_element_real[elements]))
        location_list.append(loc.body(columns=elements, rows=[int(pos_min), int(pos_max)]))

# %%
gt_table_element.tab_style(
    style=style.text(color="black", font="Times New Roman", weight="bold"),
    locations=location_list
)
# Out:
# GT(_tbl_data=                model_name  data_type  \
# 0                  svm.SVC       real
# 1                  svm.SVC       real
# 2                  svm.SVC       real
# 3                  svm.SVC  synthetic
# 4                  svm.SVC  synthetic
# 5                  svm.SVC  synthetic
# 6                  svm.SVC       real
# 7                  svm.SVC       real
# 8                  svm.SVC       real
# 9                  svm.SVC  synthetic
# 10                 svm.SVC  synthetic
# 11  RandomForestClassifier       real
# 12  RandomForestClassifier       real
# 13  RandomForestClassifier       real
# 14  RandomForestClassifier  synthetic
# 15  RandomForestClassifier  synthetic
# 16  RandomForestClassifier  synthetic
# 17  RandomForestClassifier  synthetic
# 18      LogisticRegression       real
# 19      LogisticRegression  synthetic
# 20      LogisticRegression  synthetic
# 21      LogisticRegression  synthetic
# 22      LogisticRegression       real
# 23      LogisticRegression  synthetic
# 24    KNeighborsClassifier       real
# 25    KNeighborsClassifier       real
# 26    KNeighborsClassifier       real
# 27    KNeighborsClassifier       real
# 28    KNeighborsClassifier  synthetic
# 29    KNeighborsClassifier  synthetic
# 30    KNeighborsClassifier  synthetic
# 31  DecisionTreeClassifier       real
# 32  DecisionTreeClassifier       real
# 33  DecisionTreeClassifier       real
# 34  DecisionTreeClassifier  synthetic
# 35  DecisionTreeClassifier  synthetic
# 36  DecisionTreeClassifier  synthetic
# 37  DecisionTreeClassifier  synthetic
#
#                                      hyper_parameters  accuracy  precision  \
# 0   C=10.0, max_iter=10000, decision_function_shap...  0.807462   0.773748
# 1   C=1.0, max_iter=10000, decision_function_shape...  0.806694   0.767123
# 2   C=10.0, max_iter=5375, decision_function_shape...  0.803777   0.715758
# 3   C=1.0, max_iter=10000, decision_function_shape...  0.783663   0.691943
# 4   C=10.0, max_iter=10000, decision_function_shap...  0.777829   0.661458
# 5   C=100.0, max_iter=6330, decision_function_shap...  0.779671   0.726667
# 6   C=10.0, max_iter=5000, decision_function_shape...  0.213880   0.219713
# 7   C=10.0, max_iter=5000, decision_function_shape...  0.213880   0.219713
# 8    C=0.1, max_iter=500, decision_function_shape=ovo  0.198372   0.206024
# 9   C=10.0, max_iter=5000, decision_function_shape...  0.212498   0.203203
# 10  C=10.0, max_iter=1500, decision_function_shape...  0.205742   0.186565
# 11   max_depth=100, max_samples=0.5, n_estimators=200  0.858130   0.740879
# 12    max_depth=10, max_samples=0.8, n_estimators=100  0.857976   0.796875
# 13    max_depth=10, max_samples=0.8, n_estimators=200  0.857823   0.796688
# 14    max_depth=10, max_samples=0.8, n_estimators=100  0.798710   0.631579
# 15    max_depth=10, max_samples=0.9, n_estimators=200  0.798250   0.629667
# 16     max_depth=50, max_samples=0.8, n_estimators=50  0.799171   0.637696
# 17    max_depth=10, max_samples=0.8, n_estimators=100  0.796100   0.624615
# 18                             max_iter=10000, C=10.0  0.849992   0.732759
# 19                              max_iter=10000, C=1.0  0.780593   0.538713
# 20                              max_iter=10000, C=0.1  0.779671   0.537862
# 21                               max_iter=2500, C=0.1  0.770920   0.520392
# 22                                 max_iter=50, C=0.1  0.800092   0.615253
# 23                                max_iter=500, C=0.1  0.747735   0.483562
# 24                       n_neighbors=50, leaf_size=30  0.812529   0.773438
# 25                        n_neighbors=50, leaf_size=2  0.811300   0.778502
# 26                      n_neighbors=200, leaf_size=50  0.809765   0.853191
# 27                       n_neighbors=5, leaf_size=200  0.793797   0.617526
# 28                     n_neighbors=200, leaf_size=200  0.765239   0.521605
# 29                      n_neighbors=50, leaf_size=200  0.719023   0.420503
# 30                       n_neighbors=5, leaf_size=200  0.678029   0.379025
# 31  criterion='gini', min_samples_split=200, min_s...  0.861661   0.763780
# 32  criterion='entropy', min_samples_split=50, min...  0.855059   0.765903
# 33  criterion='entropy', min_samples_split=50, min...  0.855059   0.765903
# 34  criterion='gini', min_samples_split=20, min_sa...  0.781207   0.565062
# 35  criterion='log_loss', min_samples_split=20, mi...  0.783356   0.587336
# 36  criterion='entropy', min_samples_split=50, min...  0.781667   0.579679
# 37  criterion='log_loss', min_samples_split=2, min...  0.752649   0.484026
#
#       recall     auprc   roc_auc
# 0   0.285169  0.393073  0.629331
# 1   0.285169  0.391184  0.628825
# 2   0.309357  0.388015  0.635152
# 3   0.185869  0.324987  0.579782
# 4   0.161680  0.309156  0.567688
# 5   0.138765  0.308574  0.561086
# 6   0.885423  0.222176  0.442914
# 7   0.885423  0.222176  0.442914
# 8   0.814131  0.212564  0.408381
# 9   0.775302  0.211743  0.404446
# 10  0.682368  0.203922  0.368298
# 11  0.633355  0.557677  0.781469
# 12  0.551878  0.547869  0.753580
# 13  0.551241  0.547412  0.753261
# 14  0.397199  0.396264  0.661772
# 15  0.397199  0.395505  0.661469
# 16  0.387651  0.394908  0.658820
# 17  0.387651  0.389837  0.656796
# 18  0.595162  0.533761  0.763081
# 19  0.628899  0.428309  0.728857
# 20  0.614895  0.423620  0.723473
# 21  0.641630  0.420342  0.726824
# 22  0.457034  0.412160  0.683090
# 23  0.674093  0.404577  0.722619
# 24  0.315086  0.408907  0.642873
# 25  0.304265  0.404689  0.638373
# 26  0.255251  0.397419  0.620645
# 27  0.381286  0.384694  0.653107
# 28  0.322724  0.331700  0.614316
# 29  0.436028  0.319387  0.622506
# 30  0.524507  0.313495  0.625669
# 31  0.617441  0.563866  0.778368
# 32  0.574793  0.542800  0.759473
# 33  0.574793  0.542800  0.759473
# 34  0.403565  0.371905  0.652410
# 35  0.342457  0.359743  0.632985
# 36  0.345003  0.357983  0.632740
# 37  0.385742  0.334874  0.627513  , _body=<great_tables._gt_data.Body object at 0x7eed4bcca570>, _boxhead=Boxhead([ColInfo(var='model_name', type=<ColInfoTypeEnum.default: 1>, column_label='model_name', column_align='left', column_width=None), ColInfo(var='data_type', type=<ColInfoTypeEnum.default: 1>, column_label='data_type', column_align='left', column_width=None), ColInfo(var='hyper_parameters', type=<ColInfoTypeEnum.default: 1>, column_label='hyper_parameters', column_align='left', column_width=None), ColInfo(var='accuracy', type=<ColInfoTypeEnum.default: 1>, column_label='accuracy', column_align='right', column_width=None), ColInfo(var='precision', type=<ColInfoTypeEnum.default: 1>, column_label='precision', column_align='right', column_width=None), ColInfo(var='recall', type=<ColInfoTypeEnum.default: 1>, column_label='recall', column_align='right', column_width=None), ColInfo(var='auprc', type=<ColInfoTypeEnum.default: 1>, column_label='auprc', column_align='right', column_width=None), ColInfo(var='roc_auc', type=<ColInfoTypeEnum.default: 1>, column_label='roc_auc', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7eef4ce325a0>, _spanners=Spanners([]), _heading=Heading(title=None, subtitle=None, preheader=None), _stubhead=None, _summary_rows=<great_tables._gt_data.SummaryRows object at 0x7eef4c57f6e0>, _summary_rows_grand=<great_tables._gt_data.SummaryRows object at 0x7eef4ce32180>, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='accuracy', rows=[8, 31], mask=None), grpname=None, colname='accuracy', rownum=8, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns='accuracy', rows=[8, 31], mask=None), grpname=None, colname='accuracy', rownum=31, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns='precision', rows=[10, 26], mask=None), grpname=None, colname='precision', rownum=10, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns='precision', rows=[10, 26], mask=None), grpname=None, colname='precision', rownum=26, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns='recall', rows=[5, 6], mask=None), grpname=None, colname='recall', rownum=5, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns='recall', rows=[5, 6], mask=None), grpname=None, colname='recall', rownum=6, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns='auprc', rows=[10, 31], mask=None), grpname=None, colname='auprc', rownum=10, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=None, transform=None, whitespace=None)]), StyleInfo(locname=LocBody(columns='auprc', rows=[10, 31], mask=None), grpname=None, colname='auprc', rownum=31, colnum=None, styles=[CellStyleText(color='black', font='Times New Roman', size=None, align=None, v_align=None, style=None, weight='bold', stretch=None, decorate=Non ...

# %%
idx_list = []
for models in table_element_real['model_name'].unique():
    for data_type in table_element_real['data_type'].unique():
        idx_list.append(int(table_element_real[table_element_real['model_name']==models][table_element_real['data_type']==data_type]['auprc'].index[0]))

# %%
idx_list
# Out:
# [0, 3, 11, 14, 18, 19, 24, 28, 31, 34]

# %%
table_element_real_copy = table_element_real.copy()

# %%
table_element_real_copy = table_element_real_copy.loc[idx_list, :]

# %%
table_element_real_copy.index = list(range(len(idx_list)))

# %%
table_element_real_copy
# Out:
#                model_name  data_type  \
# 0                 svm.SVC       real
# 1                 svm.SVC  synthetic
# 2  RandomForestClassifier       real
# 3  RandomForestClassifier  synthetic
# 4      LogisticRegression       real
# 5      LogisticRegression  synthetic
# 6    KNeighborsClassifier       real
# 7    KNeighborsClassifier  synthetic
# 8  DecisionTreeClassifier       real
# 9  DecisionTreeClassifier  synthetic
#
#                                     hyper_parameters  accuracy  precision  \
# 0  C=10.0, max_iter=10000, decision_function_shap...  0.807462   0.773748
# 1  C=1.0, max_iter=10000, decision_function_shape...  0.783663   0.691943
# 2   max_depth=100, max_samples=0.5, n_estimators=200  0.858130   0.740879
# 3    max_depth=10, max_samples=0.8, n_estimators=100  0.798710   0.631579
# 4                             max_iter=10000, C=10.0  0.849992   0.732759
# 5                              max_iter=10000, C=1.0  0.780593   0.538713
# 6                       n_neighbors=50, leaf_size=30  0.812529   0.773438
# 7                     n_neighbors=200, leaf_size=200  0.765239   0.521605
# 8  criterion='gini', min_samples_split=200, min_s...  0.861661   0.763780
# 9  criterion='gini', min_samples_split=20, min_sa...  0.781207   0.565062
#
#      recall     auprc   roc_auc
# 0  0.285169  0.393073  0.629331
# 1  0.185869  0.324987  0.579782
# 2  0.633355  0.557677  0.781469
# 3  0.397199  0.396264  0.661772
# 4  0.595162  0.533761  0.763081
# 5  0.628899  0.428309  0.728857
# 6  0.315086  0.408907  0.642873
# 7  0.322724  0.331700  0.614316
# 8  0.617441  0.563866  0.778368
# 9  0.403565  0.371905  0.652410

# %% [markdown]
# Accuracy is not a good metric to measure the performance of the models, as it is not a good metric for imbalanced datasets, so we use roc_auc instead.

# %%
values_dict2 = {}
values_dict2["model_name"] = []
values_dict2["difference_between_data_type"] = []
values_dict2["percentage_reduction"] = []
values_dict2["synthetic_data_auprc"] = []
values_dict2["real_data_auprc"] = []

# %%
for _model_columns in table_element_real_copy["model_name"].unique():
    dif_in_percentage=table_element_real_copy[table_element_real_copy["model_name"]==_model_columns]
    dif_in_percentage_syn = table_element_real_copy[table_element_real_copy["model_name"]==_model_columns][table_element_real_copy["data_type"]=="synthetic"]
    dif_in_percentage_real = table_element_real_copy[table_element_real_copy["model_name"]==_model_columns][table_element_real_copy["data_type"]=="real"]

    dif_copy = dif_in_percentage_real["auprc"].to_list()[0]-dif_in_percentage_syn["auprc"].to_list()[0]
    dif_in_percentage_copy = (dif_in_percentage_real["auprc"].to_list()[0]-dif_in_percentage_syn["auprc"].to_list()[0])/dif_in_percentage_real["auprc"].to_list()[0]
    
    values_dict2["model_name"].append(_model_columns)
    values_dict2["difference_between_data_type"].append(dif_copy)
    values_dict2["percentage_reduction"].append(round(dif_in_percentage_copy*100, ndigits=2))
    values_dict2["synthetic_data_auprc"].append(dif_in_percentage_syn["auprc"].to_list()[0])
    values_dict2["real_data_auprc"].append(dif_in_percentage_real["auprc"].to_list()[0])

# %%
table_element_real = pd.DataFrame({'model_name': values_dict2['model_name'], 'synthetic_data_auprc': values_dict2['synthetic_data_auprc'], 'real_data_auprc': values_dict2['real_data_auprc'], 'difference_between_data_type':values_dict2['difference_between_data_type'], 'percentage_reduction': values_dict2['percentage_reduction']})

# %%
table_element_real
# Out:
#                model_name  synthetic_data_auprc  real_data_auprc  \
# 0                 svm.SVC              0.324987         0.393073
# 1  RandomForestClassifier              0.396264         0.557677
# 2      LogisticRegression              0.428309         0.533761
# 3    KNeighborsClassifier              0.331700         0.408907
# 4  DecisionTreeClassifier              0.371905         0.563866
#
#    difference_between_data_type  percentage_reduction
# 0                      0.068086                 17.32
# 1                      0.161413                 28.94
# 2                      0.105452                 19.76
# 3                      0.077207                 18.88
# 4                      0.191961                 34.04

# %%
mean_value_ratio = 0
for idx in table_element_real.index:
    mean_value_ratio += table_element_real['synthetic_data_auprc'][idx]/table_element_real['real_data_auprc'][idx]
score_value_utility = float(round(mean_value_ratio/len(table_element_real), ndigits=4) * 100)

# %%
score_value_utility
# Out:
# 76.21

# %% [markdown]
# We used AUPRC (Area Under Precision-Recall Curve) as a metric to evaluate the performance of the models, as it is a better metric for imbalanced datasets, having a ratio of 3:1 between the two classes, and it is a better metric than roc_auc and accuracy.
# The synthetic dataset, across diverse models such as Logistic Regression, Random Forest, SVM, KNN and Decision Tree Classifier, has auprc ranging from 0.325 to 0.428, whereas real data has auprc ranging from 0.393 to 0.557.

# %%
for elements in y_test_real['income_>50K'].unique():
    print(elements, " percentage of elements:",round(len(y_test_real[y_test_real['income_>50K']==elements])/len(y_test_real)*100, ndigits=2))
# Out:
# 0.0  percentage of elements: 75.88
# 1.0  percentage of elements: 24.12

# %%
len(x_train_syn)
# Out:
# 26048

# %%
x_train_real_1, x_train_real_2 = train_test_split(
x_train_real, test_size=0.5, random_state=42)

# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train_syn[is_col_numeric])
x_train_syn_scaled_sample = scaler.transform(x_train_syn[is_col_numeric].sample(n=2000, random_state=42))
x_train_real_scaled_sample = scaler.transform(x_train_real[is_col_numeric].sample(n=2000, random_state=42))
x_test_syn_scaled_sample = scaler.transform(x_test_syn[is_col_numeric].sample(n=2000, random_state=42))
x_test_real_scaled_sample = scaler.transform(x_test_real[is_col_numeric].sample(n=2000, random_state=42))

x_train_real_scaled_sample_1 = scaler.transform(x_train_real_1[is_col_numeric].sample(n=2000, random_state=42))
x_train_real_scaled_sample_2 = scaler.transform(x_train_real_2[is_col_numeric].sample(n=2000, random_state=42))

# %%
x_train_syn_copy_sampled = x_train_syn.copy().sample(n=2000, random_state=42)
x_test_syn_copy_sampled = x_test_syn.copy().sample(n=2000, random_state=42)

x_train_real_copy_sampled = x_train_real.copy().sample(n=2000, random_state=42)

x_train_real_copy_sampled_1 = x_train_real_1.copy().sample(n=2000, random_state=42)
x_train_real_copy_sampled_2 = x_train_real_2.copy().sample(n=2000, random_state=42)

x_test_real_copy_sampled = x_test_real.copy().sample(n=2000, random_state=42)

y_train_syn_copy_sampled = y_train_syn.copy().sample(n=2000, random_state=42)
y_test_syn_copy_sampled = y_test_syn.copy().sample(n=2000, random_state=42)

y_train_real_copy_sampled = y_train_real.copy().sample(n=2000, random_state=42)
y_test_real_copy_sampled = y_test_real.copy().sample(n=2000, random_state=42)

# %%
x_train_syn_copy_sampled[is_col_numeric] = x_train_syn_scaled_sample
x_train_real_copy_sampled[is_col_numeric] = x_train_real_scaled_sample
x_test_syn_copy_sampled[is_col_numeric] = x_test_syn_scaled_sample
x_test_real_copy_sampled[is_col_numeric] = x_test_real_scaled_sample
x_train_real_copy_sampled_1[is_col_numeric] = x_train_real_scaled_sample_1
x_train_real_copy_sampled_2[is_col_numeric] = x_train_real_scaled_sample_2

# %%
from sklearn.metrics import pairwise_distances

# %%
pw_dist = pairwise_distances(x_train_real_copy_sampled, x_train_syn_copy_sampled, metric='euclidean')

# %%
pw_dist2 = pairwise_distances(x_train_real_copy_sampled_1, x_train_real_copy_sampled_2, metric='euclidean')

# %%
pw_dist_min = pw_dist.min(axis=1)

# %%
pw_dist_min2 = pw_dist2.min(axis=1)

# %%
list_pw_dist = pw_dist_min.copy()
list_pw_dist2 = pw_dist_min2.copy()

# %%
list_pw_dist.sort()
list_pw_dist2.sort()

# %% [markdown]
# We will use the DCR (Distanfce to Closest Record) metric to ensure that the synthetic dataset is suitable for privacy, and it is not that too similar to the real dataset. The DCR metric uses euclidean distance to measure the distance between the data in each dataset, and it produces the differences rows x rows in a form of a matrix.
#
# Then we extract the minimum distance for each row, as to get an idea of how close the data is between the two datasets. We extract the mean, median and 5 percentile of the minimum distances

# %%
print("For real-synthetic:")
print("The mean is:", list_pw_dist.mean())
if len(list_pw_dist) % 2 != 0:
    print("The median is:", list_pw_dist[len(list_pw_dist)//2])
else:
    print("The median is:", (list_pw_dist[len(list_pw_dist)//2]+list_pw_dist[len(list_pw_dist)//2-1])/2)
print("The 5 percentile is:", list_pw_dist[len(list_pw_dist)*5//100])

print("\n")
print("For real-real:")
print("The mean is:", list_pw_dist2.mean())
if len(list_pw_dist2) % 2 != 0:
    print("The median is:", list_pw_dist2[len(list_pw_dist2)//2])
else:
    print("The median is:", (list_pw_dist2[len(list_pw_dist2)//2]+list_pw_dist2[len(list_pw_dist2)//2-1])/2)
print("The 5 percentile is:", list_pw_dist2[len(list_pw_dist2)*5//100])
# Out:
# For real-synthetic:
# The mean is: 2.126998066264204
# The median is: 1.8538546149883364
# The 5 percentile is: 0.2812626697967907
#
#
# For real-real:
# The mean is: 1.3945423260117014
# The median is: 1.4419114707294634
# The 5 percentile is: 0.1406313348983448

# %%
mean_1 = list_pw_dist.mean()
mean_2 = list_pw_dist2.mean()

# %%
score_dcr = min(mean_1/mean_2, 1.0) * 100.0

# %% [markdown]
# As it can be seen, the mean, median and 5 percentile of the synthetic-real datasets are higher than the real-real datasets, which indicates that the synthetic dataset is different enough from the real one.

# %% [markdown]
# We will conduct now membership inference test (MITM)

# %%
from sklearn.metrics import log_loss
current_threshold = 0.5
def check_if_values_okay(predict_prob, current_label, column_name):
    loss=log_loss([current_label[column_name]], [predict_prob], labels=[0.0,1.0])
    return loss < current_threshold, loss

# %%
x_real = pd.concat([x_train_real, x_test_real], ignore_index=False)
y_real = pd.concat([y_train_real, y_test_real], ignore_index=False)

# %%
best_model = LogisticRegression(max_iter=10000, C=0.1, random_state=42)
best_model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
predict_prob = best_model.predict_proba(x_real)

list_of_mitm_values = []
list_of_mitm_values_train = []
list_of_mitm_values_test = []
for idx in range(len(x_real)):
    current_sample = x_real.loc[x_real.index[idx], :]
    current_label = y_real.loc[y_real.index[idx], :]
    is_in_train, loss = check_if_values_okay(predict_prob[idx], current_label, y_real.columns[0])
    list_of_mitm_values.append((loss, int(x_real.index[idx])))

    if x_real.index[idx] in list(x_train_real.index):
        list_of_mitm_values_train.append((loss, int(x_real.index[idx])))
    elif x_real.index[idx] in list(x_test_real.index):
        list_of_mitm_values_test.append((loss, int(x_real.index[idx])))

# %%
import statistics
print("For real train - real test dataset:")
avg_train_1 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_train)))
print("avg_train=",avg_train_1)
avg_test_1 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_test)))
print("avg_test=",avg_test_1)
# Out:
# For real train - real test dataset:
# avg_train= 0.329922013274641
# avg_test= 0.3298342875968774

# %%
score_mitm_1 = min(avg_train_1/avg_test_1, 1.0) * 100

# %% [markdown]
# It can be seen that the training dataset has a loss that near the one from the test dataset (although slightly higher by 0.00034), which indicates that the model is not overfitting and there is not a problem in regards to the leakage of information from the training dataset.

# %%
x_syn_real = pd.concat([x_train_syn, x_test_real], ignore_index=False)
y_syn_real = pd.concat([y_train_syn, y_test_real], ignore_index=False)

# %%
best_model = LogisticRegression(max_iter=10000, C=0.1, random_state=42)
best_model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
predict_prob = best_model.predict_proba(x_syn_real)

list_of_mitm_values_2 = []
list_of_mitm_values_train_2 = []
list_of_mitm_values_test_2 = []
for idx in range(len(x_syn_real)):
    current_sample = x_syn_real.loc[x_syn_real.index[idx], :]
    current_label = y_syn_real.loc[y_syn_real.index[idx], :]
    is_in_train, loss = check_if_values_okay(predict_prob[idx], current_label, y_syn_real.columns[0])
    list_of_mitm_values_2.append((loss, int(x_syn_real.index[idx])))

    if x_syn_real.index[idx] in list(x_train_syn.index):
        list_of_mitm_values_train_2.append((loss, int(x_syn_real.index[idx])))
    elif y_syn_real.index[idx] in list(x_test_real.index):
        list_of_mitm_values_test_2.append((loss, int(x_syn_real.index[idx])))

# %%
import statistics
print("For synthetic train - real test dataset:")
avg_train_2 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_train_2)))
print("avg_train=",avg_train_2)
avg_test_2 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_test_2)))
print("avg_test=",avg_test_2)
# Out:
# For synthetic train - real test dataset:
# avg_train= 0.29091033686043316
# avg_test= 0.522280572700637

# %%
score_mitm_2 = min(avg_train_2/avg_test_2, 1.0) * 100

# %%
score_value_privacy = score_dcr * 0.5 + score_mitm_1 * 0.25 + score_mitm_2 * 0.25

# %% [markdown]
# Before the treating the zero-inflated column, when trying training data from the synthetic dataset combined with the testing data from the real dataset, we can see that the loss is significantly lower in the training dataset as compared to the testing dataset (by 0.23), which does not indicate a problem in regards to the leakage of information.
#
# Before the zero-inflated, that the synthetic dataset might have even less reproducibility than even the real dataset, as the difference is even higher when compared to the real train - real test datasets, which is 0.012 vs 0.00034, respectively. But this was due to the fact that it used MinMaxTransformer even across the zero values, which heavily distorted the distribution of the synthetic datasets towards the extreme outliers, while zero values being zero, and some values being gathered around 0. By treating this problem, we saw that the synthetic dataset has in fact a better reproducibility than the real dataset, probably due to the fact that we have more values in the zero range, and less outliers.
#
# These tests combined with the DCR metric, indicate that the synthetic dataset can have some problems in regards to the privacy, with some evidence of problems such as reproducibility.

# %% [markdown]
# ### DIVERSITY AND COVERAGE

# %%
okay=0
score_value_categorical_diversity = 0
from functools import reduce

for columns in is_col_categorical:
    list_of_categories = (list(df_reset_copy__[columns].unique()))
    list_of_categories_that_appear_on_synthetic = list(filter(lambda x: x in list(synthetic_data_[columns]), list_of_categories))
    if len(list_of_categories) != len(list_of_categories_that_appear_on_synthetic):
        print(f"This columns {columns} has not all the values")
        okay=1

if okay == 0:
    print("The synthetic dataset includes all the values in the categorical columns")
list_of_values_different = []
for columns in is_col_categorical:
    counts_per_category_real = (dict(df_reset_copy__[columns].value_counts()))
    counts_per_category_synthetic = (dict(synthetic_data_[columns].value_counts()))
    
    counts_per_category_real_per = dict(map(lambda k: (k[0], float(round((k[1]/len(df_reset_copy__)), ndigits=6))), counts_per_category_real.items()))
    counts_per_category_syn_per = dict(map(lambda k: (k[0], float(round((k[1]/len(synthetic_data_)), ndigits=6))), counts_per_category_synthetic.items()))
    
    counts_per_category_real_per_not_present = dict(filter(lambda k: k[0] not in counts_per_category_synthetic.keys(), counts_per_category_real_per.items()))
    counts_per_category_syn_per_not_present = dict(filter(lambda k: k[0] not in counts_per_category_real.keys(), counts_per_category_syn_per.items()))

    counts_per_category_real_per = dict(filter(lambda k: k[0] in counts_per_category_synthetic.keys(), counts_per_category_real_per.items()))
    counts_per_category_syn_per = dict(filter(lambda k: k[0] in counts_per_category_real.keys(), counts_per_category_syn_per.items()))

    counts_per_category_both_per = list(map(lambda k, v: (k[0], k[1], v[1]), counts_per_category_real_per.items(), counts_per_category_syn_per.items()))
    counts_per_category_both_per = list(filter(lambda k: k[1]!=k[2], counts_per_category_both_per))
    if counts_per_category_both_per != []:
        counts_per_category_real_per_not_present = list(map(lambda k: (k[0], k[1], 0.0), counts_per_category_real_per_not_present.items()))
        counts_per_category_syn_per_not_present = list(map(lambda k: (k[0], 0.0, k[1]), counts_per_category_syn_per_not_present.items()))

        list_of_values_different.extend(counts_per_category_both_per)
        list_of_values_different.extend(counts_per_category_real_per_not_present)
        list_of_values_different.extend(counts_per_category_syn_per_not_present)


if list_of_values_different == []:
    print("Same proportions for categorical values")
    score_value_categorical_diversity = 0.0
    
else:
    print("Differences between data_types:")
    print("list_of_values_different=",list_of_values_different)
    biggest_categorical_diversity = list(map(lambda k: (k[0], abs(k[1]-k[2])), list_of_values_different))
    biggest_categorical_diversity.sort(key=lambda item: item[1], reverse=True)
    print("biggest_categorical_diversity=",biggest_categorical_diversity)
    score_value_categorical_diversity = reduce(lambda k, y : abs(y[1]-y[2])+k, list_of_values_different, 0.0)
    
    score_value_categorical_diversity = (1-(score_value_categorical_diversity/len(is_col_categorical))) * 100.0
# Out:
# This columns workclass has not all the values
# This columns marital_status has not all the values
# This columns occupation has not all the values
# This columns relationship has not all the values
# This columns race has not all the values
# This columns native_country has not all the values
# Differences between data_types:
# list_of_values_different= [('Private', 0.753417, 0.783483), ('Self-emp-not-inc', 0.078038, 0.118055), ('Local-gov', 0.064279, 0.069807), ('State-gov', 0.039864, 0.015172), ('Self-emp-inc', 0.034274, 0.013237), ('Federal-gov', 0.029483, 0.000246), ('Without-pay', 0.00043, 0.0), ('Never-worked', 0.000215, 0.0), ('Married-civ-spouse', 0.459937, 0.540677), ('Never-married', 0.328092, 0.376708), ('Divorced', 0.136452, 0.082614), ('Separated', 0.031479, 0.0), ('Widowed', 0.030497, 0.0), ('Married-spouse-absent', 0.012837, 0.0), ('Married-AF-spouse', 0.000706, 0.0), ('Prof-specialty', 0.183747, 0.197015), ('Craft-repair', 0.125887, 0.176407), ('Exec-managerial', 0.124873, 0.14072), ('Adm-clerical', 0.115783, 0.130186), ('Sales', 0.112097, 0.107767), ('Other-service', 0.101195, 0.103068), ('Machine-op-inspct', 0.061485, 0.096496), ('Transport-moving', 0.049046, 0.017598), ('Handlers-cleaners', 0.042075, 0.013667), ('Farming-fishing', 0.030527, 0.011978), ('Tech-support', 0.0285, 0.005098), ('Protective-serv', 0.019932, 0.0), ('Priv-house-serv', 0.004576, 0.0), ('Armed-Forces', 0.000276, 0.0), ('Husband', 0.405209, 0.39664), ('Not-in-family', 0.25506, 0.234759), ('Own-child', 0.155646, 0.207887), ('Unmarried', 0.105832, 0.144037), ('Wife', 0.048125, 0.016676), ('Other-relative', 0.030128, 0.0), ('White', 0.854274, 0.888763), ('Black', 0.095943, 0.111053), ('Asian-Pac-Islander', 0.031909, 0.000154), ('Amer-Indian-Eskimo', 0.009551, 3.1e-05), ('Other', 0.008323, 0.0), ('Male', 0.669205, 0.675778), ('Female', 0.330795, 0.324222), ('<=50K', 0.75919, 0.777832), ('>50K', 0.24081, 0.222168), ('United-States', 0.913762, 0.997819), ('Others', 0.01941, 0.002119), ('Cuba', 0.002918, 3.1e-05), ('China', 0.002303, 3.1e-05), ('Mexico', 0.019748, 0.0), ('Philippines', 0.006081, 0.0), ('Germany', 0.004207, 0.0), ('Canada', 0.003716, 0.0), ('Puerto-Rico', 0.003501, 0.0), ('El-Salvador', 0.003255, 0.0), ('India', 0.003071, 0.0), ('England', 0.002764, 0.0), ('Jamaica', 0.002488, 0.0), ('South', 0.002457, 0.0), ('Italy', 0.002242, 0.0), ('Dominican-Republic', 0.00215, 0.0), ('Vietnam', 0.002058, 0.0), ('Guatemala', 0.001966, 0.0), ('Japan', 0.001904, 0.0)]
# biggest_categorical_diversity= [('United-States', 0.08405700000000005), ('Married-civ-spouse', 0.08073999999999998), ('Divorced', 0.05383799999999998), ('Own-child', 0.05224099999999998), ('Craft-repair', 0.05052000000000001), ('Never-married', 0.04861599999999999), ('Self-emp-not-inc', 0.040017), ('Unmarried', 0.038205), ('Machine-op-inspct', 0.035011), ('White', 0.03448899999999999), ('Asian-Pac-Islander', 0.031755), ('Separated', 0.031479), ('Wife', 0.031449000000000005), ('Transport-moving', 0.031448000000000004), ('Widowed', 0.030497), ('Other-relative', 0.030128), ('Private', 0.030066000000000037), ('Federal-gov', 0.029237), ('Handlers-cleaners', 0.028408000000000003), ('State-gov', 0.024692), ('Tech-support', 0.023402), ('Self-emp-inc', 0.021037), ('Not-in-family', 0.020301000000000013), ('Protective-serv', 0.019932), ('Mexico', 0.019748), ('>50K', 0.018641999999999992), ('<=50K', 0.018641999999999936), ('Farming-fishing', 0.018548999999999996), ('Others', 0.017291), ('Exec-managerial', 0.015847000000000014), ('Black', 0.015109999999999998), ('Adm-clerical', 0.014403), ('Prof-specialty', 0.013268000000000002), ('Married-spouse-absent', 0.012837), ('Amer-Indian-Eskimo', 0.00952), ('Husband', 0.008568999999999993), ('Other', 0.008323), ('Female', 0.0065729999999999955), ('Male', 0.00657299999999994), ('Philippines', 0.006081), ('Local-gov', 0.005527999999999991), ('Priv-house-serv', 0.004576), ('Sales', 0.0043300000000000005), ('Germany', 0.004207), ('Canada', 0.003716), ('Puerto-Rico', 0.003501), ('El-Salvador', 0.003255), ('India', 0.003071), ('Cuba', 0.002887), ('England', 0.002764), ('Jamaica', 0.002488), ('South', 0.002457), ('China', 0.0022719999999999997), ('Italy', 0.002242), ('Dominican-Republic', 0.00215), ('Vietnam', 0.002058), ('Guatemala', 0.001966), ('Japan', 0.001904), ('Other-service', 0.0018730000000000135), ('Married-AF-spouse', 0.000706), ('Without-pay', 0.00043), ('Armed-Forces', 0.000276), ('Never-worked', 0.000215)]

# %% [markdown]
# It can be observed that for categorical columns, the differences are small between the real and synthetic datasets, the biggest difference is at around 0.085, while the next one hovers at around than 0.08, and the successive values are around or less than 0.05, which indicates that the synthetic dataset is able to capture the diversity of the real dataset, in the categorical columns.
# But there are some columns in the synthetic that are not represented fully as they do not have all the categories that are present in the real dataset, such as 'workclass', 'marital_status', 'occupation', 'relationship', 'race' and 'native_country'.

# %%
score_value_categorical_diversity
# Out:
# 85.3698375

# %%
binary_numerical_columns = list(filter(lambda x: len(df_reset_copy__[x].unique())==2, list(df_reset_copy__.columns)))

# %%
print("For binary columns")
difference_value = 0
for b_column in binary_numerical_columns:
    value_1_real = df_reset_copy__[df_reset_copy__[b_column]==df_reset_copy__[b_column].unique()[0]]
    value_2_real = df_reset_copy__[df_reset_copy__[b_column]==df_reset_copy__[b_column].unique()[1]]
    
    value_1_syn = synthetic_data_[synthetic_data_[b_column]==df_reset_copy__[b_column].unique()[0]]
    value_2_syn = synthetic_data_[synthetic_data_[b_column]==df_reset_copy__[b_column].unique()[1]]
    
    per_value_1_real = round(len(value_1_real)/len(df_reset_copy__), ndigits=6)
    per_value_2_real = round(len(value_2_real)/len(df_reset_copy__), ndigits=6)

    per_value_1_syn = round(len(value_1_syn)/len(df_reset_copy__), ndigits=6)
    per_value_2_syn = round(len(value_2_syn)/len(df_reset_copy__), ndigits=6)

    print(f"column: {b_column}")
    print(f"The ratio between values for real data is:", per_value_1_real, per_value_2_real)
    print(f"The ratio between values for synthetic data is:", per_value_1_syn, per_value_2_syn)
    difference_value += abs(per_value_1_real - per_value_1_syn)
difference_value/=len(binary_numerical_columns)
# Out:
# For binary columns
# column: sex
# The ratio between values for real data is: 0.669205 0.330795
# The ratio between values for synthetic data is: 0.675778 0.324222
# column: income
# The ratio between values for real data is: 0.75919 0.24081
# The ratio between values for synthetic data is: 0.777832 0.222168

# %% [markdown]
# For the columns with binary numerical values, we can see that the ratios are quite similar between the real and synthetic datasets, for sex the difference is roughly at 0.06 and for income the difference is at roughly 0.017.

# %%
difference_value = round(difference_value, ndigits=6)

# %%
score_value_binary_columns_diversity = (1-difference_value)*100

# %%
score_value_binary_columns_diversity = round(score_value_binary_columns_diversity, ndigits=6)

# %%
score_value_binary_columns_diversity
# Out:
# 98.7393

# %%
is_col_numeric_without_binary = list(set(is_col_numeric.copy())-(set(binary_numerical_columns)))

# %%
diffferences_in_values = 0.0

# %%
for col in is_col_numeric_without_binary:
    print("For column: ", col)
    diff = 0
    for percentiles in [0.99, 0.97, 0.95, 0.93, 0.92, 0.9, 0.875, 0.8, 0.75, 0.65]:
        x = np.percentile(df_reset_copy__[col], (1.0-percentiles)*100.0)
        y = np.percentile(df_reset_copy__[col], percentiles*100.0)

        per_syn = round(len(synthetic_data_[synthetic_data_[col]<=y][synthetic_data_[col]>=x])/len(synthetic_data_), ndigits=6)
        per_real = round(len(df_reset_copy__[df_reset_copy__[col]<=y][df_reset_copy__[col]>=x])/len(df_reset_copy__), ndigits=6)

        print("For percentiles:", percentiles*100.0, (1.0-percentiles)*100.0)
        print("Synthetic data: ", f"{round(len(synthetic_data_[synthetic_data_[col]<=y][synthetic_data_[col]>=x])/len(synthetic_data_), ndigits=6)*100}%", f"values range: [{x}, {y}]")
        print("Real data: ", f"{round(len(df_reset_copy__[df_reset_copy__[col]<=y][df_reset_copy__[col]>=x])/len(df_reset_copy__), ndigits=6)*100}%", f"values range: [{x}, {y}]")
        diff += abs(per_real - per_syn)
    diff/=len([0.99, 0.97, 0.95, 0.93, 0.92, 0.9, 0.875, 0.8, 0.75, 0.65])
    diffferences_in_values+=diff
    print("diff=", diff)
    print("\n")
diffferences_in_values/=len(is_col_numeric_without_binary)
# Out:
# For column:  hours_per_week
# For percentiles: 99.0 1.0000000000000009
# Synthetic data:  100.0% values range: [8.0, 80.0]
# Real data:  98.4552% values range: [8.0, 80.0]
# For percentiles: 97.0 3.0000000000000027
# Synthetic data:  100.0% values range: [14.800000000000864, 65.0]
# Real data:  94.475% values range: [14.800000000000864, 65.0]
# For percentiles: 95.0 5.000000000000004
# Synthetic data:  100.0% values range: [18.0, 60.0]
# Real data:  91.6311% values range: [18.0, 60.0]
# For percentiles: 93.0 6.999999999999995
# Synthetic data:  100.0% values range: [20.0, 60.0]
# Real data:  91.3578% values range: [20.0, 60.0]
# For percentiles: 92.0 7.9999999999999964
# Synthetic data:  98.5934% values range: [20.0, 58.0]
# Real data:  86.8124% values range: [20.0, 58.0]
# For percentiles: 90.0 9.999999999999998
# Synthetic data:  94.8374% values range: [24.0, 55.0]
# Real data:  82.3439% values range: [24.0, 55.0]
# For percentiles: 87.5 12.5
# Synthetic data:  92.27300000000001% values range: [28.0, 50.0]
# Real data:  76.51790000000001% values range: [28.0, 50.0]
# For percentiles: 80.0 19.999999999999996
# Synthetic data:  64.3039% values range: [35.0, 48.0]
# Real data:  62.9188% values range: [35.0, 48.0]
# For percentiles: 75.0 25.0
# Synthetic data:  58.091% values range: [40.0, 45.0]
# Real data:  54.2336% values range: [40.0, 45.0]
# For percentiles: 65.0 35.0
# Synthetic data:  55.5358% values range: [40.0, 40.0]
# Real data:  46.733799999999995% values range: [40.0, 40.0]
# diff= 0.07815500000000002
#
#
# For column:  capital_net
# For percentiles: 99.0 1.0000000000000009
# Synthetic data:  97.021% values range: [-1980.0, 15024.0]
# Real data:  98.2003% values range: [-1980.0, 15024.0]
# For percentiles: 97.0 3.0000000000000027
# Synthetic data:  95.2581% values range: [-1848.0, 7688.0]
# Real data:  94.5026% values range: [-1848.0, 7688.0]
# For percentiles: 95.0 5.000000000000004
# Synthetic data:  92.19000000000001% values range: [0.0, 5013.0]
# Real data:  90.4856% values range: [0.0, 5013.0]
# For percentiles: 93.0 6.999999999999995
# Synthetic data:  90.5316% values range: [0.0, 2885.0]
# Real data:  88.345% values range: [0.0, 2885.0]
# For percentiles: 92.0 7.9999999999999964
# Synthetic data:  89.6164% values range: [0.0, 1458.2000000000116]
# Real data:  87.3345% values range: [0.0, 1458.2000000000116]
# For percentiles: 90.0 9.999999999999998
# Synthetic data:  88.7534% values range: [0.0, 0.0]
# Real data:  87.0059% values range: [0.0, 0.0]
# For percentiles: 87.5 12.5
# Synthetic data:  88.7534% values range: [0.0, 0.0]
# Real data:  87.0059% values range: [0.0, 0.0]
# For percentiles: 80.0 19.999999999999996
# Synthetic data:  88.7534% values range: [0.0, 0.0]
# Real data:  87.0059% values range: [0.0, 0.0]
# For percentiles: 75.0 25.0
# Synthetic data:  88.7534% values range: [0.0, 0.0]
# Real data:  87.0059% values range: [0.0, 0.0]
# For percentiles: 65.0 35.0
# Synthetic data:  88.7534% values range: [0.0, 0.0]
# Real data:  87.0059% values range: [0.0, 0.0]
# diff= 0.016845200000000005
#
#
# For column:  age
# For percentiles: 99.0 1.0000000000000009
# Synthetic data:  100.0% values range: [17.0, 74.0]
# Real data:  99.1216% values range: [17.0, 74.0]
# For percentiles: 97.0 3.0000000000000027
# Synthetic data:  98.36% values range: [19.0, 67.0]
# Real data:  94.4658% values range: [19.0, 67.0]
# For percentiles: 95.0 5.000000000000004
# Synthetic data:  98.36% values range: [19.0, 63.0]
# Real data:  92.3559% values range: [19.0, 63.0]
# For percentiles: 93.0 6.999999999999995
# Synthetic data:  96.5787% values range: [20.0, 61.0]
# Real data:  88.67049999999999% values range: [20.0, 61.0]
# For percentiles: 92.0 7.9999999999999964
# Synthetic data:  96.5787% values range: [21.0, 60.0]
# Real data:  85.4366% values range: [21.0, 60.0]
# For percentiles: 90.0 9.999999999999998
# Synthetic data:  96.5787% values range: [22.0, 58.0]
# Real data:  81.17689999999999% values range: [22.0, 58.0]
# For percentiles: 87.5 12.5
# Synthetic data:  96.5787% values range: [23.0, 56.0]
# Real data:  76.6039% values range: [23.0, 56.0]
# For percentiles: 80.0 19.999999999999996
# Synthetic data:  58.183099999999996% values range: [26.0, 50.0]
# Real data:  60.4711% values range: [26.0, 50.0]
# For percentiles: 75.0 25.0
# Synthetic data:  50.8277% values range: [28.0, 48.0]
# Real data:  51.874900000000004% values range: [28.0, 48.0]
# For percentiles: 65.0 35.0
# Synthetic data:  47.2314% values range: [31.0, 43.0]
# Real data:  33.487899999999996% values range: [31.0, 43.0]
# diff= 0.0822823

# %% [markdown]
# For 'age' in the synthetic dataset, there more values concentrated around [17.0, 74.0], this can be especially noticable in the regions such as [31.0, 43.0] and [23.0, 56.0], where the difference was at around 14% and 20% respectively. But in the real dataset, there are values in the regions [17.0, 23.0] and [56.0, 74.0], where the percentage in synthetic largely stagnates or increases slowly, compared to the real dataset, although as a total it remains higher.
#
# Before applying the zero-inflated methodology,  the synthetic dataset as repeated before, had zero values which contain zeros, while the real dataset contained most of its values at zero, another thing, was the fact that the synthetic dataset contains more negative values around zero, this is why before when it were taken around only the positive values at [0.0, 5013.0], there only 57.38% of the values, while when taking into consideration the negative values in [-1848.0, 7688.0], it jumped at 97.2175%.
#
# But now the values from the synthetic dataset and the real dataset are more similar, while now values in the synthetic dataset has more values than real in the range [0.0, 1458.2] and [-1980.0, -1848.0) and (7688.0, 15024.0], while the real dataset has more than synthetic in the range (1458.2, 7688.0] and [-1848.0, 0.0). While the extreme outliers are higher in the synthetic dataset.

# %%
score_value_numerical_diversity=(1.0-diffferences_in_values)*100

# %%
score_value_diversity = (len(is_col_numeric_without_binary) * score_value_numerical_diversity + len(binary_numerical_columns) * score_value_binary_columns_diversity + len(is_col_categorical) * score_value_binary_columns_diversity)/(len(is_col_categorical)+len(binary_numerical_columns)+len(is_col_numeric_without_binary))

# %%
DQS = score_value_fidelity*0.1 + score_value_utility * 0.35 + score_value_privacy * 0.35 + score_value_diversity * 0.2

# %%
score_value_utility
# Out:
# 76.21

# %%
score_value_diversity
# Out:
# 97.66651923076923

# %%
score_value_privacy
# Out:
# 88.9250027698799

# %%
DQS = round(DQS, ndigits=2)

# %%
DQS
# Out:
# 85.9

# %% [markdown]
# This DQS (Data Quality Score) indicates a good quality of the synthetic dataset, but for certain categories such as utility, it has a moderate performance of 76.21.  Other than that, other categories such as privacy, diversity and fidelity have good scores, which indicates that the synthetic dataset is suitable for privacy, fidelity and diversity.

# %% [markdown]
# It can be seen here that the DPCTGANSynthetizer is not able to perfectly capture the distribution of the real dataset, having a hard time capturing the distribution among the extreme values (due to using the log trick, but we have seen that the log trick provides better results in terms of DQS compared to not using it).
#
# The best reproduced column is capital_net, where there is a sizeable differences between the distributions in the range of 1-2%, meanwhile the next best is hours_per_week, where there the same range. It can be observed that although the difference gets smaller in some cases, in others it gets bigger, as in same other runs a bigger percentile might have reduced the differentce, but in this case it is less noticeable. This is not valid for the age column, where the difference is in the can be sometimes especially in the earlier ranges of around 15%.

# %%
for values in [0, 5, 10, 50, 100, 200, 500, 1000, 2500, 10000, 50000, 100000]:
    x = -values
    y = values
    print("Synthetic data: ", len(synthetic_data_[synthetic_data_['capital_net']<=y][synthetic_data_['capital_net']>=x])/len(synthetic_data_), f"values range: [{x}, {y}]")
    print("Real data: ", len(df_reset_copy_[df_reset_copy_['capital_net']<=y][df_reset_copy_['capital_net']>=x])/len(df_reset_copy_), f"values range: [{x}, {y}]")
# Out:
# Synthetic data:  0.8875341666410737 values range: [0, 0]
# Real data:  0.8700592733638401 values range: [0, 0]
# Synthetic data:  0.8875955898160376 values range: [-5, 5]
# Real data:  0.8700592733638401 values range: [-5, 5]
# Synthetic data:  0.8876570129910015 values range: [-10, 10]
# Real data:  0.8700592733638401 values range: [-10, 10]
# Synthetic data:  0.8882098215656767 values range: [-50, 50]
# Real data:  0.8700592733638401 values range: [-50, 50]
# Synthetic data:  0.8888240533153159 values range: [-100, 100]
# Real data:  0.8700592733638401 values range: [-100, 100]
# Synthetic data:  0.8902367863394859 values range: [-200, 200]
# Real data:  0.8702742544762139 values range: [-200, 200]
# Synthetic data:  0.8938914652498388 values range: [-500, 500]
# Real data:  0.8706427935259974 values range: [-500, 500]
# Synthetic data:  0.9000337827462301 values range: [-1000, 1000]
# Real data:  0.8728540278246982 values range: [-1000, 1000]
# Synthetic data:  0.922299683670649 values range: [-2500, 2500]
# Real data:  0.9255551119437364 values range: [-2500, 2500]
# Synthetic data:  0.9826172414852123 values range: [-10000, 10000]
# Real data:  0.9763520776388932 values range: [-10000, 10000]
# Synthetic data:  1.0 values range: [-50000, 50000]
# Real data:  0.9951168575903688 values range: [-50000, 50000]
# Synthetic data:  1.0 values range: [-100000, 100000]
# Real data:  1.0 values range: [-100000, 100000]

# %% [markdown]
# Previously, before zero-inputting, in the real dataset, most values are in the value of range [-x, x], where x either 0 or 25000 or 10000 , while in the synthetic dataset, there are fewer values in these intervals, but in the synthetic there more values in the ranges of [-x,x], where x is either from 5 to 1000, or from 50000 to 100000. Meaning that the synthetic dataset captures more outliers, which can be due to the clipping mechanism, which caps extreme values to the maximum and minimum of the real dataset. And the synthetic dataset due to using linearity is not able to capture that the distribution is not linear, and has most values around zero. But is able to somehow detect this by putting most of the rows, in the range of values close to zero, and then it decreases sharply.
#
# But now, after doing it, the values in the synthetic dataset are extremely similar to the real dataset, although the real dataset has more values in range of [-100000, -2500] and [2500, 100000], while the synthetic dataset in the other range.

# %%
df_reset_copy__2 = df_reset_copy__.copy()
synthetic_data_2 = synthetic_data_.copy()
df_reset_copy__2=df_reset_copy__2.drop("label", axis=1)

# %%
from sdmetrics.reports.single_table import QualityReport

report = QualityReport()
report.generate(df_reset_copy_, synthetic_data_, metadata_dict)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 72.15it/s]|
# Column Shapes Score: 88.21%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 68.88it/s]|
# Column Pair Trends Score: 78.88%
#
# Overall Score (Average): 83.54%

# %%
column_shapes = report.get_details(property_name='Column Shapes')
print(column_shapes[column_shapes['Metric']=='KSComplement'])
# Out:
#             Column        Metric     Score
# 0              age  KSComplement  0.591474
# 2    education_num  KSComplement  0.900310
# 8   hours_per_week  KSComplement  0.889008
# 11     capital_net  KSComplement  0.979853

# %%
DQS_list = [DQS]
score_value_utility_list = [round(score_value_utility, ndigits=2)]
score_value_privacy_list = [round(score_value_privacy, ndigits=2)]
score_value_diversity_list = [round(score_value_diversity, ndigits=2)]
score_value_fidelity_list = [round(score_value_fidelity, ndigits=2)]

# %%
for epsilon in [1,3, 5, 10]:
    print("Epsilon:", epsilon)
    import math
    #df_reset_copy_['capital_net_log'] = np.sign(df_reset_copy_['capital_net']) * np.log2(abs(df_reset_copy_['capital_net'])+1) 
    
    df_reset_copy_.to_csv("adult-data-census-complete.csv", index=False)
    
    df_reset_copy_2 = df_reset_copy_.copy()

    for idx, merged_lists in enumerate(current_lists):
        df_reset_copy_2[f"merged_list_{idx}"] = df_reset_copy_2[merged_lists].agg(';'.join, axis=1)
    
    
    flat_list = [
        x
        for xs in current_lists
        for x in xs
    ]
    df_reset_copy_2=df_reset_copy_2.drop(flat_list, axis=1)
    df_reset_copy_2.to_csv("adult-data-census-complete2.csv", index=False)
    
    import pandas as pd
    import math
    from snsynth import Synthesizer
    
    pums = pd.read_csv("adult-data-census-complete2.csv")

    synth = Synthesizer.create("dpctgan", epsilon=epsilon, epochs=1800, batch_size=2000)
    synth.fit(pums, preprocessor_eps=epsilon*0.3)
    synthetic_data_ = synth.sample(len(df_reset_copy_))
    df_reset_copy_2 = df_reset_copy_.copy()
    #synthetic_data_['capital_net_log'] = synthetic_data_['capital_net_log'].clip(upper=max(df_reset_copy_2['capital_net_log']), lower=min(df_reset_copy_2['capital_net_log']))
    #synthetic_data_['capital_net'] = round(np.sign(synthetic_data_['capital_net_log']) * (np.exp2(abs(synthetic_data_['capital_net_log']))+1)).astype(int)
    synthetic_data_['capital_net'] = synthetic_data_['capital_net'].clip(upper=max(df_reset_copy_['capital_net']), lower=min(df_reset_copy_['capital_net']))

    print("max min=", max(synthetic_data_['capital_net']), min(synthetic_data_['capital_net']))
    
    #df_reset_copy_2 = df_reset_copy_2.drop('capital_net_log', axis=1)
    #synthetic_data_ = synthetic_data_.drop('capital_net_log', axis=1)
    
    for idx, merged_lists in enumerate(current_lists):
        cols = synthetic_data_[f"merged_list_{idx}"].str.split(';', expand=True)
        synthetic_data_[merged_lists] = cols
        synthetic_data_ = synthetic_data_.drop(f"merged_list_{idx}", axis=1)
    df_reset_copy_2.to_csv("adult-data-census-complete2.csv", index=False)
    data = connector.read(
        folder_name='',
        file_names=['adult-data-census-complete2.csv'],
        read_csv_parameters={
            'parse_dates': False,
            'encoding':'latin-1'
        }
    )
    from sdv.metadata import Metadata
    
    metadata = Metadata.detect_from_dataframes(data)
    
    metadata.visualize()
    metadata.update_column(
        column_name='education_num',
        sdtype='numerical',
        table_name='adult-data-census-complete2'
    )
    metadata.validate()
    metadata_dict = metadata.to_dict()
    metadata_dict['columns'] = metadata_dict['tables']['adult-data-census-complete2']['columns']
    from sdmetrics.reports.single_table import QualityReport
    report1 = DiagnosticReport()
    report1.generate(df_reset_copy_, synthetic_data_, metadata_dict)

    
    
    report2 = QualityReport()
    report2.generate(df_reset_copy_2, synthetic_data_, metadata_dict)
    column_shapes = report2.get_details(property_name='Column Shapes')
    print(column_shapes)
       
  
    score_value_fidelity = round(report1.get_score(), ndigits=4) * 0.25 + round(report2.get_score(), ndigits=4) * 0.75
    score_value_fidelity = float(score_value_fidelity * 100)
    
    
    import seaborn as sns
    df_reset_copy__ = df_reset_copy_.copy()
    synthetic_data__ = synthetic_data_.copy()
    print("max min 2=", max(synthetic_data__['capital_net']), min(synthetic_data__['capital_net']))
    df_reset_copy__['label'] = 'Dataset 1'
    synthetic_data__['label'] = 'Dataset 2'
    
    combined_data = pd.concat([df_reset_copy__, synthetic_data__])
    
    sns.displot(combined_data, x="capital_net", kind="kde", hue='label')

    from sklearn.model_selection import train_test_split
    x_train_real, x_test_real, y_train_real, y_test_real = train_test_split(df_reset_copy_2.copy().loc[:, df_reset_copy_2.columns != target_column], df_reset_copy_2.copy().loc[:, df_reset_copy_2.columns == target_column], test_size=0.2, random_state=42)
    x_train_syn, x_test_syn, y_train_syn, y_test_syn = train_test_split(synthetic_data_.copy().loc[:, synthetic_data_.columns != target_column], synthetic_data_.copy().loc[:, synthetic_data_.columns == target_column], test_size=0.2, random_state=42)
    encoder = OneHotEncoder(sparse_output=False)
    one_hot_encoded_y_train = encoder.fit_transform(y_train_real)
    one_hot_df_y_train = pd.DataFrame(one_hot_encoded_y_train,  columns=encoder.get_feature_names_out(y_train_real.columns), index= y_train_real.index)
    y_train_real = pd.concat([one_hot_df_y_train], axis=1)
    
    y_test_real_copy = y_test_real.copy()
    one_hot_encoded_y_test = encoder.transform(y_test_real)
    one_hot_df_y_test = pd.DataFrame(one_hot_encoded_y_test,  columns=encoder.get_feature_names_out(y_test_real.columns), index= y_test_real.index)
    y_test_real = pd.concat([one_hot_df_y_test], axis=1)
    
    encoder = OneHotEncoder(sparse_output=False)
    one_hot_encoded_y_train_syn = encoder.fit_transform(y_train_syn)
    one_hot_df_y_train_syn = pd.DataFrame(one_hot_encoded_y_train_syn,  columns=encoder.get_feature_names_out(y_train_syn.columns), index= y_train_syn.index)
    y_train_syn = pd.concat([one_hot_df_y_train_syn], axis=1)
    
    one_hot_encoded_y_test_syn = encoder.transform(y_test_syn)
    one_hot_df_y_test_syn = pd.DataFrame(one_hot_encoded_y_test_syn,  columns=encoder.get_feature_names_out(y_test_syn.columns), index= y_test_syn.index)
    y_test_syn = pd.concat([one_hot_df_y_test_syn], axis=1)
    
    one_hot_encoded_y_test_copy = encoder.transform(y_test_real_copy)
    one_hot_df_y_test_copy = pd.DataFrame(one_hot_encoded_y_test_copy,  columns=encoder.get_feature_names_out(y_test_real_copy.columns), index= y_test_real_copy.index)
    y_test_real_copy = pd.concat([one_hot_df_y_test_copy], axis=1)
    
    x_test_real_copy = x_test_real.copy() 
    encoder = OneHotEncoder(sparse_output=False)
    one_hot_encoded_x_train = encoder.fit_transform(x_train_real[is_col_OH])
    one_hot_df_x_train = pd.DataFrame(one_hot_encoded_x_train,  columns=encoder.get_feature_names_out(is_col_OH), index= x_train_real.index)
    x_train_real = pd.concat([x_train_real.drop(is_col_OH, axis=1), one_hot_df_x_train], axis=1)
    
    one_hot_encoded_x_test = encoder.transform(x_test_real[is_col_OH])
    one_hot_df_x_test = pd.DataFrame(one_hot_encoded_x_test,  columns=encoder.get_feature_names_out(is_col_OH), index= x_test_real.index)
    x_test_real = pd.concat([x_test_real.drop(is_col_OH, axis=1), one_hot_df_x_test], axis=1)

    one_hot_encoded_x_train_syn = encoder.transform(x_train_syn[is_col_OH])
    one_hot_df_x_train_syn = pd.DataFrame(one_hot_encoded_x_train_syn,  columns=encoder.get_feature_names_out(is_col_OH), index= x_train_syn.index)
    x_train_syn = pd.concat([x_train_syn.drop(is_col_OH, axis=1), one_hot_df_x_train_syn], axis=1)
    
    one_hot_encoded_x_test_syn = encoder.transform(x_test_syn[is_col_OH])
    one_hot_df_x_test_syn = pd.DataFrame(one_hot_encoded_x_test_syn,  columns=encoder.get_feature_names_out(is_col_OH), index= x_test_syn.index)
    x_test_syn = pd.concat([x_test_syn.drop(is_col_OH, axis=1), one_hot_df_x_test_syn], axis=1)
    
    one_hot_encoded_x_test_copy = encoder.transform(x_test_real_copy[is_col_OH])
    one_hot_df_x_test_copy = pd.DataFrame(one_hot_encoded_x_test_copy,  columns=encoder.get_feature_names_out(is_col_OH), index= x_test_real_copy.index)
    x_test_real_copy = pd.concat([x_test_real_copy.drop(is_col_OH, axis=1), one_hot_df_x_test_copy], axis=1)
    
    if len(y_train_real.columns) == 2 and target_column not in y_train_real.columns:
        y_train_real = y_train_real.drop(y_train_real.columns[0], axis=1)
        y_test_real = y_test_real.drop(y_test_real.columns[0], axis=1)
        y_test_real_copy = y_test_real_copy.drop(y_test_real_copy.columns[0], axis=1)
        y_train_syn = y_train_syn.drop(y_train_syn.columns[0], axis=1)
        y_test_syn = y_test_syn.drop(y_test_syn.columns[0], axis=1)
    
    model_configs = [
        (LogisticRegression, dict(max_iter=10000, C=0.1, random_state=42), False, "synthetic"),
        (LogisticRegression, dict(max_iter=10000, C=1.0, random_state=42), False, "synthetic"),
        (LogisticRegression, dict(max_iter=500,   C=0.1, random_state=42), False, "synthetic"),
        (LogisticRegression, dict(max_iter=2500,  C=0.1, random_state=42), False, "synthetic"),
        (LogisticRegression, dict(max_iter=10000, C=10.0, random_state=42), False, "real"),
        (LogisticRegression, dict(max_iter=50,    C=0.1, random_state=42), False, "real"),
    
        (RandomForestClassifier, dict(max_depth=10, max_samples=0.9, n_estimators=200, n_jobs=-1, random_state=42), False, "synthetic"),
        (RandomForestClassifier, dict(max_depth=50, max_samples=0.8, n_estimators=50,  n_jobs=-1, random_state=42), False, "synthetic"),
        (RandomForestClassifier, dict(max_depth=10, max_samples=0.8, n_estimators=100, n_jobs=-1, random_state=42), False, "synthetic"),
        (RandomForestClassifier, dict(max_depth=10, max_samples=0.8, n_estimators=200, n_jobs=-1, random_state=42), False, "synthetic"),
        (RandomForestClassifier, dict(max_depth=100,max_samples=0.5, n_estimators=200, n_jobs=-1, random_state=42), False, "real"),
        (RandomForestClassifier, dict(max_depth=10, max_samples=0.8, n_estimators=100, n_jobs=-1, random_state=42), False, "real"),
        (RandomForestClassifier, dict(max_depth=10, max_samples=0.8, n_estimators=200, n_jobs=-1, random_state=42), False, "real"),
    
        (svm.SVC, dict(C=10.0,  max_iter=10000, decision_function_shape="ovr", random_state=42), False, "synthetic"),
        (svm.SVC, dict(C=10.0,  max_iter=5000,  decision_function_shape="ovo", random_state=42), False, "synthetic"),
        (svm.SVC, dict(C=1.0,   max_iter=10000, decision_function_shape="ovr", random_state=42), False, "synthetic"),
        (svm.SVC, dict(C=10.0,  max_iter=1500,  decision_function_shape="ovo", random_state=42), False, "synthetic"),
        (svm.SVC, dict(C=100.0, max_iter=6330,  decision_function_shape="ovr", random_state=42), False, "synthetic"),
        (svm.SVC, dict(C=10.0,  max_iter=10000, decision_function_shape="ovr", random_state=42), False, "real"),
        (svm.SVC, dict(C=1.0,   max_iter=10000, decision_function_shape="ovr", random_state=42), False, "real"),
        (svm.SVC, dict(C=10.0,  max_iter=5000,  decision_function_shape="ovr", random_state=42), False, "real"),
        (svm.SVC, dict(C=10.0,  max_iter=5375,  decision_function_shape="ovr", random_state=42), False, "real"),
        (svm.SVC, dict(C=0.1,   max_iter=500,   decision_function_shape="ovo", random_state=42), False, "real"),
    
        (KNeighborsClassifier, dict(n_neighbors=50,  leaf_size=200), True, "synthetic"),
        (KNeighborsClassifier, dict(n_neighbors=200, leaf_size=200), True, "synthetic"),
        (KNeighborsClassifier, dict(n_neighbors=5,   leaf_size=200), True, "synthetic"),
        (KNeighborsClassifier, dict(n_neighbors=50,  leaf_size=30),  True, "real"),
        (KNeighborsClassifier, dict(n_neighbors=5,   leaf_size=200), True, "real"),
        (KNeighborsClassifier, dict(n_neighbors=200, leaf_size=50),  True, "real"),
        (KNeighborsClassifier, dict(n_neighbors=50,  leaf_size=2),   True, "real"),
    
        (DecisionTreeClassifier, dict(criterion='entropy', min_samples_split=50,  min_samples_leaf=100), False, "synthetic"),
        (DecisionTreeClassifier, dict(criterion='gini',    min_samples_split=20,  min_samples_leaf=100), False, "synthetic"),
        (DecisionTreeClassifier, dict(criterion='log_loss',min_samples_split=20,  min_samples_leaf=100), False, "synthetic"),
        (DecisionTreeClassifier, dict(criterion='log_loss',min_samples_split=2,   min_samples_leaf=1),   False, "synthetic"),
        (DecisionTreeClassifier, dict(criterion='entropy', min_samples_split=50,  min_samples_leaf=100), False, "real"),
        (DecisionTreeClassifier, dict(criterion='gini',    min_samples_split=200, min_samples_leaf=1),   False, "real"),
        (DecisionTreeClassifier, dict(criterion='entropy', min_samples_split=50,  min_samples_leaf=100), False, "real"),
    ]
    
    scaler = StandardScaler()
    scaler.fit(x_train_syn[is_col_numeric])
    
    x_train_syn_scaled = x_train_syn.copy()
    x_train_syn_scaled[is_col_numeric] = scaler.transform(x_train_syn[is_col_numeric])
    x_train_real_scaled = x_train_real.copy()
    x_train_real_scaled[is_col_numeric] = scaler.transform(x_train_real[is_col_numeric])
    x_test_real_scaled = x_test_real.copy()
    x_test_real_scaled[is_col_numeric] = scaler.transform(x_test_real[is_col_numeric])
    
    target_col = y_test_real_copy.columns[0]
    rows = []
    
    for model_cls, kwargs, needs_scaling, data_type in model_configs:
        if data_type == "synthetic":
            X_train, y_train_ = (x_train_syn_scaled, y_train_syn) if needs_scaling else (x_train_syn, y_train_syn)
        else:
            X_train, y_train_ = (x_train_real_scaled, y_train_real) if needs_scaling else (x_train_real, y_train_real)
    
        X_test = x_test_real_scaled if needs_scaling else x_test_real
    
        model = model_cls(**kwargs)
        model.fit(X_train, y_train_[y_train_.columns[0]])
        y_pred = model.predict(X_test)
        y_true = y_test_real_copy[target_col]
    
        rows.append({
            "model_name": model_cls.__name__,
            "data_type": data_type,
            "hyper_parameters": str(kwargs),
            "accuracy": accuracy_score(y_true, y_pred),
            "precision": precision_score(y_true, y_pred),
            "recall": recall_score(y_true, y_pred),
            "roc_auc": roc_auc_score(y_true, y_pred),
            "auprc": average_precision_score(y_true, y_pred),
        })
    
    table_element_real = pd.DataFrame(rows)
    
    import polars as pl
    
    from great_tables import GT, from_column, style, loc
    from great_tables.data import airquality
    table_element_real = table_element_real.sort_values(by=['model_name', 'auprc', 'data_type'], ascending=False, ignore_index=True)
    
    gt_table_element = GT(table_element_real)
    location_list = []
    for idx, elements in enumerate(table_element_real.columns):
        if "accuracy" in elements or "precision" in elements or "auprc" in elements or "recall" in elements or "roc_auc" in elements:
            pos_min, pos_max = (np.argmin(table_element_real[elements]), np.argmax(table_element_real[elements]))
            location_list.append(loc.body(columns=elements, rows=[int(pos_min), int(pos_max)]))
            
    
    idx_list = []
    for models in table_element_real['model_name'].unique():
        for data_type in table_element_real['data_type'].unique():
            idx_list.append(int(table_element_real[table_element_real['model_name']==models][table_element_real['data_type']==data_type]['auprc'].index[0]))
    
    table_element_real_copy = table_element_real.copy()
    table_element_real_copy = table_element_real_copy.loc[idx_list, :]
    table_element_real_copy.index = list(range(len(idx_list)))
    values_dict2 = {}
    values_dict2["model_name"] = []
    values_dict2["difference_between_data_type"] = []
    values_dict2["percentage_reduction"] = []
    values_dict2["synthetic_data_auprc"] = []
    values_dict2["real_data_auprc"] = []
    for _model_columns in table_element_real_copy["model_name"].unique():
        dif_in_percentage=table_element_real_copy[table_element_real_copy["model_name"]==_model_columns]
        dif_in_percentage_syn = table_element_real_copy[table_element_real_copy["model_name"]==_model_columns][table_element_real_copy["data_type"]=="synthetic"]
        dif_in_percentage_real = table_element_real_copy[table_element_real_copy["model_name"]==_model_columns][table_element_real_copy["data_type"]=="real"]
    
        dif_copy = dif_in_percentage_real["auprc"].to_list()[0]-dif_in_percentage_syn["auprc"].to_list()[0]
        dif_in_percentage_copy = (dif_in_percentage_real["auprc"].to_list()[0]-dif_in_percentage_syn["auprc"].to_list()[0])/dif_in_percentage_real["auprc"].to_list()[0]
        
        values_dict2["model_name"].append(_model_columns)
        values_dict2["difference_between_data_type"].append(dif_copy)
        values_dict2["percentage_reduction"].append(round(dif_in_percentage_copy*100, ndigits=2))
        values_dict2["synthetic_data_auprc"].append(dif_in_percentage_syn["auprc"].to_list()[0])
        values_dict2["real_data_auprc"].append(dif_in_percentage_real["auprc"].to_list()[0])
    
    table_element_real = pd.DataFrame({'model_name': values_dict2['model_name'], 'synthetic_data_auprc': values_dict2['synthetic_data_auprc'], 'real_data_auprc': values_dict2['real_data_auprc'], 'difference_between_data_type':values_dict2['difference_between_data_type'], 'percentage_reduction': values_dict2['percentage_reduction']})
    
    print(table_element_real)
    
    mean_value_ratio = 0
    for idx in table_element_real.index:
        mean_value_ratio += table_element_real['synthetic_data_auprc'][idx]/table_element_real['real_data_auprc'][idx]
    score_value_utility = float(round(mean_value_ratio/len(table_element_real), ndigits=4) * 100)
    
    
    x_train_real_1, x_train_real_2 = train_test_split(
    x_train_real, test_size=0.5, random_state=42)
    
    scaler = StandardScaler()
    scaler.fit(x_train_syn[is_col_numeric])
    x_train_syn_scaled_sample = scaler.transform(x_train_syn[is_col_numeric].sample(n=2000, random_state=42))
    x_train_real_scaled_sample = scaler.transform(x_train_real[is_col_numeric].sample(n=2000, random_state=42))
    x_test_syn_scaled_sample = scaler.transform(x_test_syn[is_col_numeric].sample(n=2000, random_state=42))
    x_test_real_scaled_sample = scaler.transform(x_test_real[is_col_numeric].sample(n=2000, random_state=42))
    
    x_train_real_scaled_sample_1 = scaler.transform(x_train_real_1[is_col_numeric].sample(n=2000, random_state=42))
    x_train_real_scaled_sample_2 = scaler.transform(x_train_real_2[is_col_numeric].sample(n=2000, random_state=42))
    
    x_train_syn_copy_sampled = x_train_syn.copy().sample(n=2000, random_state=42)
    x_test_syn_copy_sampled = x_test_syn.copy().sample(n=2000, random_state=42)
    
    x_train_real_copy_sampled = x_train_real.copy().sample(n=2000, random_state=42)
    
    x_train_real_copy_sampled_1 = x_train_real_1.copy().sample(n=2000, random_state=42)
    x_train_real_copy_sampled_2 = x_train_real_2.copy().sample(n=2000, random_state=42)
    
    x_test_real_copy_sampled = x_test_real.copy().sample(n=2000, random_state=42)
    
    y_train_syn_copy_sampled = y_train_syn.copy().sample(n=2000, random_state=42)
    y_test_syn_copy_sampled = y_test_syn.copy().sample(n=2000, random_state=42)
    
    y_train_real_copy_sampled = y_train_real.copy().sample(n=2000, random_state=42)
    y_test_real_copy_sampled = y_test_real.copy().sample(n=2000, random_state=42)
    
    x_train_syn_copy_sampled[is_col_numeric] = x_train_syn_scaled_sample
    x_train_real_copy_sampled[is_col_numeric] = x_train_real_scaled_sample
    x_test_syn_copy_sampled[is_col_numeric] = x_test_syn_scaled_sample
    x_test_real_copy_sampled[is_col_numeric] = x_test_real_scaled_sample
    x_train_real_copy_sampled_1[is_col_numeric] = x_train_real_scaled_sample_1
    x_train_real_copy_sampled_2[is_col_numeric] = x_train_real_scaled_sample_2
    
    
    from sklearn.metrics import pairwise_distances
    
    pw_dist = pairwise_distances(x_train_real_copy_sampled, x_train_syn_copy_sampled, metric='euclidean')
    pw_dist2 = pairwise_distances(x_train_real_copy_sampled_1, x_train_real_copy_sampled_2, metric='euclidean')
    pw_dist_min = pw_dist.min(axis=1)
    pw_dist_min2 = pw_dist2.min(axis=1)
    list_pw_dist = pw_dist_min.copy()
    list_pw_dist2 = pw_dist_min2.copy()
    list_pw_dist.sort()
    list_pw_dist2.sort()
    
    mean_1 = list_pw_dist.mean()
    mean_2 = list_pw_dist2.mean()
    score_dcr = min(mean_1/mean_2, 1.0) * 100.0
    x_real = pd.concat([x_train_real, x_test_real], ignore_index=False)
    y_real = pd.concat([y_train_real, y_test_real], ignore_index=False)
    x_syn_real = pd.concat([x_train_syn, x_test_real], ignore_index=False)
    y_syn_real = pd.concat([y_train_syn, y_test_real], ignore_index=False)
        
    best_model = LogisticRegression(max_iter=10000, C=0.1, random_state=42)
    best_model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
    predict_prob = best_model.predict_proba(x_real)
    
    best_model = LogisticRegression(max_iter=10000, C=0.1, random_state=42)
    best_model.fit(x_train_real, y_train_real[y_train_real.columns[0]])
    predict_prob = best_model.predict_proba(x_real)
    
    list_of_mitm_values = []
    list_of_mitm_values_train = []
    list_of_mitm_values_test = []
    for idx in range(len(x_real)):
        current_sample = x_real.loc[x_real.index[idx], :]
        current_label = y_real.loc[y_real.index[idx], :]
        is_in_train, loss = check_if_values_okay(predict_prob[idx], current_label, y_real.columns[0])
        list_of_mitm_values.append((loss, int(x_real.index[idx])))
    
        if x_real.index[idx] in list(x_train_real.index):
            list_of_mitm_values_train.append((loss, int(x_real.index[idx])))
        elif x_real.index[idx] in list(x_test_real.index):
            list_of_mitm_values_test.append((loss, int(x_real.index[idx])))

    avg_train_1 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_train)))
    avg_test_1 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_test)))
    score_mitm_1 = min(avg_train_1/avg_test_1, 1.0) * 100
    
    x_syn_real = pd.concat([x_train_syn, x_test_real], ignore_index=False)
    y_syn_real = pd.concat([y_train_syn, y_test_real], ignore_index=False)
    
    best_model = LogisticRegression(max_iter=10000, C=0.1, random_state=42)
    best_model.fit(x_train_syn, y_train_syn[y_train_syn.columns[0]])
    predict_prob = best_model.predict_proba(x_syn_real)
    
    list_of_mitm_values_2 = []
    list_of_mitm_values_train_2 = []
    list_of_mitm_values_test_2 = []
    for idx in range(len(x_syn_real)):
        current_sample = x_syn_real.loc[x_syn_real.index[idx], :]
        current_label = y_syn_real.loc[y_syn_real.index[idx], :]
        is_in_train, loss = check_if_values_okay(predict_prob[idx], current_label, y_syn_real.columns[0])
        list_of_mitm_values_2.append((loss, int(x_syn_real.index[idx])))
    
        if x_syn_real.index[idx] in list(x_train_syn.index):
            list_of_mitm_values_train_2.append((loss, int(x_syn_real.index[idx])))
        elif y_syn_real.index[idx] in list(x_test_real.index):
            list_of_mitm_values_test_2.append((loss, int(x_syn_real.index[idx])))
    
    avg_train_2 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_train_2)))
    avg_test_2 = statistics.mean(list(map(lambda x: x[0], list_of_mitm_values_test_2)))
    score_mitm_2 = min(avg_train_2/avg_test_2, 1.0) * 100
    
    score_value_privacy = score_dcr * 0.5 + score_mitm_1 * 0.25 + score_mitm_2 * 0.25
    okay=0
    score_value_categorical_diversity = 0
    from functools import reduce
    
    for columns in is_col_categorical:
        list_of_categories = (list(df_reset_copy_2[columns].unique()))
        list_of_categories_that_appear_on_synthetic = list(filter(lambda x: x in list(synthetic_data_[columns]), list_of_categories))
        if len(list_of_categories) != len(list_of_categories_that_appear_on_synthetic):
            okay=1
    
    list_of_values_different = []
    for columns in is_col_categorical:
        counts_per_category_real = (dict(df_reset_copy_2[columns].value_counts()))
        counts_per_category_synthetic = (dict(synthetic_data_[columns].value_counts()))
        
        counts_per_category_real_per = dict(map(lambda k: (k[0], float(round((k[1]/len(df_reset_copy_2)), ndigits=6))), counts_per_category_real.items()))
        counts_per_category_syn_per = dict(map(lambda k: (k[0], float(round((k[1]/len(synthetic_data_)), ndigits=6))), counts_per_category_synthetic.items()))
        
        counts_per_category_real_per_not_present = dict(filter(lambda k: k[0] not in counts_per_category_synthetic.keys(), counts_per_category_real_per.items()))
        counts_per_category_syn_per_not_present = dict(filter(lambda k: k[0] not in counts_per_category_real.keys(), counts_per_category_syn_per.items()))

        counts_per_category_real_per = dict(filter(lambda k: k[0] in counts_per_category_synthetic.keys(), counts_per_category_real_per.items()))
        counts_per_category_syn_per = dict(filter(lambda k: k[0] in counts_per_category_real.keys(), counts_per_category_syn_per.items()))
    
        counts_per_category_both_per = list(map(lambda k, v: (k[0], k[1], v[1]), counts_per_category_real_per.items(), counts_per_category_syn_per.items()))
        counts_per_category_both_per = list(filter(lambda k: k[1]!=k[2], counts_per_category_both_per))
        if counts_per_category_both_per != []:
            counts_per_category_real_per_not_present = list(map(lambda k: (k[0], k[1], 0.0), counts_per_category_real_per_not_present.items()))
            counts_per_category_syn_per_not_present = list(map(lambda k: (k[0], 0.0, k[1]), counts_per_category_syn_per_not_present.items()))
    
            list_of_values_different.extend(counts_per_category_both_per)
            list_of_values_different.extend(counts_per_category_real_per_not_present)
            list_of_values_different.extend(counts_per_category_syn_per_not_present)
    
    
    if list_of_values_different == []:
        score_value_categorical_diversity = 0.0
        
    else:
        biggest_categorical_diversity = list(map(lambda k: (k[0], abs(k[1]-k[2])), list_of_values_different))
        biggest_categorical_diversity.sort(key=lambda item: item[1], reverse=True)
        score_value_categorical_diversity = reduce(lambda k, y : abs(y[1]-y[2])+k, list_of_values_different, 0.0)
        
        score_value_categorical_diversity = (1-(score_value_categorical_diversity/len(is_col_categorical))) * 100.0
    binary_numerical_columns = list(filter(lambda x: len(df_reset_copy_2[x].unique())==2, list(df_reset_copy_2.columns)))
    
    difference_value = 0
    for b_column in binary_numerical_columns:
        value_1_real = df_reset_copy_2[df_reset_copy_2[b_column]==df_reset_copy_2[b_column].unique()[0]]
        value_2_real = df_reset_copy_2[df_reset_copy_2[b_column]==df_reset_copy_2[b_column].unique()[1]]
        
        value_1_syn = synthetic_data_[synthetic_data_[b_column]==df_reset_copy_2[b_column].unique()[0]]
        value_2_syn = synthetic_data_[synthetic_data_[b_column]==df_reset_copy_2[b_column].unique()[1]]
        
        per_value_1_real = round(len(value_1_real)/len(df_reset_copy_2), ndigits=6)
        per_value_2_real = round(len(value_2_real)/len(df_reset_copy_2), ndigits=6)
    
        per_value_1_syn = round(len(value_1_syn)/len(df_reset_copy_2), ndigits=6)
        per_value_2_syn = round(len(value_2_syn)/len(df_reset_copy_2), ndigits=6)
        difference_value += abs(per_value_1_real - per_value_1_syn)
    difference_value/=len(binary_numerical_columns)
    
    difference_value = round(difference_value, ndigits=6)
    score_value_binary_columns_diversity = (1-difference_value)*100
    score_value_binary_columns_diversity = round(score_value_binary_columns_diversity, ndigits=6)
    is_col_numeric_without_binary = list(set(is_col_numeric.copy())-(set(binary_numerical_columns)))
    
    diffferences_in_values = 0.0
    
    for col in is_col_numeric_without_binary:
        diff = 0
        for percentiles in [0.99, 0.97, 0.95, 0.93, 0.92, 0.9, 0.875, 0.8, 0.75, 0.65]:
            x = np.percentile(df_reset_copy_2[col], (1.0-percentiles)*100.0)
            y = np.percentile(df_reset_copy_2[col], percentiles*100.0)
    
            per_syn = round(len(synthetic_data_[synthetic_data_[col]<=y][synthetic_data_[col]>=x])/len(synthetic_data_), ndigits=6)
            per_real = round(len(df_reset_copy_2[df_reset_copy_2[col]<=y][df_reset_copy_2[col]>=x])/len(df_reset_copy_2), ndigits=6)
            diff += abs(per_real - per_syn)
        diff/=len([0.99, 0.97, 0.95, 0.93, 0.92, 0.9, 0.875, 0.8, 0.75, 0.65])
        diffferences_in_values+=diff
    diffferences_in_values/=len(is_col_numeric_without_binary)
    score_value_numerical_diversity=(1.0-diffferences_in_values)*100
    
    score_value_diversity = (len(is_col_numeric_without_binary) * score_value_numerical_diversity + len(binary_numerical_columns) * score_value_binary_columns_diversity + len(is_col_categorical) * score_value_binary_columns_diversity)/(len(is_col_categorical)+len(binary_numerical_columns)+len(is_col_numeric_without_binary))
    
    DQS = score_value_fidelity*0.1 + score_value_utility * 0.35 + score_value_privacy * 0.35 + score_value_diversity * 0.2
    score_value_fidelity_list.append(round(score_value_fidelity, ndigits=2))
    score_value_utility_list.append(round(score_value_utility, ndigits=2))
    score_value_privacy_list.append(round(score_value_privacy, ndigits=2))
    score_value_diversity_list.append(round(score_value_diversity, ndigits=2))
    DQS = round(DQS, ndigits=2)
    print(DQS)
    DQS_list.append(DQS)
# Out:
# Epsilon: 1
# before TableTransformer.create
# after it
# Spent 0.3 epsilon on preprocessor, leaving 0.7 for training
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:638: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:229: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1867: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Epoch 1, Loss G: 0.7151, Loss D: 1.3785
# epsilon is 0.1685669340063301, alpha is 63.0
# Epoch 2, Loss G: 0.7047, Loss D: 1.3769
# epsilon is 0.35087099872193805, alpha is 59.0
# Epoch 3, Loss G: 0.6927, Loss D: 1.3807
# epsilon is 0.4932741420837069, alpha is 45.0
# Epoch 4, Loss G: 0.6846, Loss D: 1.3858
# epsilon is 0.6042796523846699, alpha is 38.0
# Epoch 5, Loss G: 0.6824, Loss D: 1.3877
# epsilon is 0.6988118744717009, alpha is 33.0
# max min= 0.0 0.0
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 12/12 [00:00<00:00, 169.05it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 520.19it/s]|
# Data Structure Score: 84.62%
#
# Overall Score (Average): 92.31%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 89.17it/s]|
# Column Shapes Score: 79.24%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 74.90it/s]|
# Column Pair Trends Score: 57.96%
#
# Overall Score (Average): 68.6%
#
#             Column        Metric     Score
# 0              age  KSComplement  0.780289
# 1        workclass  TVComplement  0.782408
# 2    education_num  KSComplement  0.786217
# 3   marital_status  TVComplement  0.663247
# 4       occupation  TVComplement  0.652744
# 5     relationship  TVComplement  0.669267
# 6             race  TVComplement  0.889438
# 7              sex  TVComplement  0.844784
# 8   hours_per_week  KSComplement  0.688554
# 9   native_country  TVComplement  0.959491
# 10          income  TVComplement  0.875342
# 11     capital_net  KSComplement  0.916710
# max min 2= 0.0 0.0
# /tmp/ipykernel_58/4255562933.py:92: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(combined_data, x="capital_net", kind="kde", hue='label')
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=1500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=6330).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5375).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                model_name  synthetic_data_auprc  real_data_auprc  \
# 0                     SVC               0.24121         0.393073
# 1  RandomForestClassifier               0.24121         0.557677
# 2      LogisticRegression               0.24121         0.534199
# 3    KNeighborsClassifier               0.24121         0.575014
# 4  DecisionTreeClassifier               0.24121         0.565209
#
#    difference_between_data_type  percentage_reduction
# 0                      0.151863                 38.63
# 1                      0.316467                 56.75
# 2                      0.292989                 54.85
# 3                      0.333805                 58.05
# 4                      0.323999                 57.32
# 72.38
# Epsilon: 3
# before TableTransformer.create
# after it
# Spent 0.8999999999999999 epsilon on preprocessor, leaving 2.1 for training
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:638: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:229: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1867: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Epoch 1, Loss G: 0.7150, Loss D: 1.3790
# epsilon is 0.1685669340063301, alpha is 63.0
# Epoch 2, Loss G: 0.7050, Loss D: 1.3756
# epsilon is 0.35087099872193805, alpha is 59.0
# Epoch 3, Loss G: 0.6926, Loss D: 1.3801
# epsilon is 0.4932741420837069, alpha is 45.0
# Epoch 4, Loss G: 0.6838, Loss D: 1.3854
# epsilon is 0.6042796523846699, alpha is 38.0
# Epoch 5, Loss G: 0.6804, Loss D: 1.3898
# epsilon is 0.6988118744717009, alpha is 33.0
# Epoch 6, Loss G: 0.6802, Loss D: 1.3937
# epsilon is 0.7828014761953501, alpha is 30.0
# Epoch 7, Loss G: 0.6837, Loss D: 1.3938
# epsilon is 0.8592371022659602, alpha is 28.0
# Epoch 8, Loss G: 0.6910, Loss D: 1.3904
# epsilon is 0.9299480108802527, alpha is 26.0
# Epoch 9, Loss G: 0.6967, Loss D: 1.3882
# epsilon is 0.9962382906342205, alpha is 25.0
# Epoch 10, Loss G: 0.6998, Loss D: 1.3883
# epsilon is 1.0586989652469627, alpha is 23.0
# Epoch 11, Loss G: 0.7028, Loss D: 1.3881
# epsilon is 1.1179585973940969, alpha is 22.0
# Epoch 12, Loss G: 0.7039, Loss D: 1.3858
# epsilon is 1.174699139378363, alpha is 21.0
# Epoch 13, Loss G: 0.7011, Loss D: 1.3882
# epsilon is 1.2289173335166175, alpha is 21.0
# Epoch 14, Loss G: 0.6983, Loss D: 1.3877
# epsilon is 1.2809208093175959, alpha is 20.0
# Epoch 15, Loss G: 0.6969, Loss D: 1.3885
# epsilon is 1.3315140806404386, alpha is 19.0
# Epoch 16, Loss G: 0.6949, Loss D: 1.3888
# epsilon is 1.3803180354630415, alpha is 19.0
# Epoch 17, Loss G: 0.6935, Loss D: 1.3902
# epsilon is 1.427546585910209, alpha is 18.0
# Epoch 18, Loss G: 0.6975, Loss D: 1.3857
# epsilon is 1.4736644203050084, alpha is 18.0
# Epoch 19, Loss G: 0.6984, Loss D: 1.3849
# epsilon is 1.5184630389181348, alpha is 17.0
# Epoch 20, Loss G: 0.6982, Loss D: 1.3852
# epsilon is 1.5619085601596139, alpha is 17.0
# Epoch 21, Loss G: 0.6958, Loss D: 1.3878
# epsilon is 1.605354081401093, alpha is 17.0
# Epoch 22, Loss G: 0.6956, Loss D: 1.3896
# epsilon is 1.6462336398603987, alpha is 16.0
# Epoch 23, Loss G: 0.6965, Loss D: 1.3888
# epsilon is 1.6870205139522907, alpha is 16.0
# Epoch 24, Loss G: 0.6980, Loss D: 1.3876
# epsilon is 1.7278073880441827, alpha is 16.0
# Epoch 25, Loss G: 0.6969, Loss D: 1.3874
# epsilon is 1.7662846225051718, alpha is 15.0
# Epoch 26, Loss G: 0.6970, Loss D: 1.3870
# epsilon is 1.8044263764299593, alpha is 15.0
# Epoch 27, Loss G: 0.6969, Loss D: 1.3881
# epsilon is 1.8425681303547468, alpha is 15.0
# Epoch 28, Loss G: 0.6985, Loss D: 1.3863
# epsilon is 1.8806048635571693, alpha is 14.0
# Epoch 29, Loss G: 0.7010, Loss D: 1.3847
# epsilon is 1.916114887476239, alpha is 14.0
# Epoch 30, Loss G: 0.7017, Loss D: 1.3848
# epsilon is 1.951624911395309, alpha is 14.0
# Epoch 31, Loss G: 0.7003, Loss D: 1.3854
# epsilon is 1.9871349353143788, alpha is 14.0
# Epoch 32, Loss G: 0.6990, Loss D: 1.3847
# epsilon is 2.022644959233449, alpha is 14.0
# Epoch 33, Loss G: 0.6968, Loss D: 1.3855
# epsilon is 2.05759991004724, alpha is 13.0
# Epoch 34, Loss G: 0.6941, Loss D: 1.3858
# epsilon is 2.0904914594530926, alpha is 13.0
# max min= 19066.970703125 -4095.75439453125
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 12/12 [00:00<00:00, 175.76it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 525.73it/s]|
# Data Structure Score: 84.62%
#
# Overall Score (Average): 92.31%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 90.62it/s]|
# Column Shapes Score: 77.96%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 71.10it/s]|
# Column Pair Trends Score: 57.65%
#
# Overall Score (Average): 67.8%
#
#             Column        Metric     Score
# 0              age  KSComplement  0.725746
# 1        workclass  TVComplement  0.909432
# 2    education_num  KSComplement  0.665797
# 3   marital_status  TVComplement  0.675379
# 4       occupation  TVComplement  0.610853
# 5     relationship  TVComplement  0.640490
# 6             race  TVComplement  0.896656
# 7              sex  TVComplement  0.741501
# 8   hours_per_week  KSComplement  0.732195
# 9   native_country  TVComplement  0.914038
# 10          income  TVComplement  0.931728
# 11     capital_net  KSComplement  0.911182
# max min 2= 19066.970703125 -4095.75439453125
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=1500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=6330).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5375).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                model_name  synthetic_data_auprc  real_data_auprc  \
# 0                     SVC              0.248455         0.393073
# 1  RandomForestClassifier              0.260898         0.557677
# 2      LogisticRegression              0.241210         0.534199
# 3    KNeighborsClassifier              0.255248         0.554249
# 4  DecisionTreeClassifier              0.241210         0.563866
#
#    difference_between_data_type  percentage_reduction
# 0                      0.144618                 36.79
# 1                      0.296780                 53.22
# 2                      0.292989                 54.85
# 3                      0.299001                 53.95
# 4                      0.322656                 57.22
# 73.37
# Epsilon: 5
# before TableTransformer.create
# after it
# Spent 1.5 epsilon on preprocessor, leaving 3.5 for training
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:638: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:229: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1867: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Epoch 1, Loss G: 0.7149, Loss D: 1.3794
# epsilon is 0.1685669340063301, alpha is 63.0
# Epoch 2, Loss G: 0.7048, Loss D: 1.3757
# epsilon is 0.35087099872193805, alpha is 59.0
# Epoch 3, Loss G: 0.6925, Loss D: 1.3800
# epsilon is 0.4932741420837069, alpha is 45.0
# Epoch 4, Loss G: 0.6839, Loss D: 1.3856
# epsilon is 0.6042796523846699, alpha is 38.0
# Epoch 5, Loss G: 0.6815, Loss D: 1.3892
# epsilon is 0.6988118744717009, alpha is 33.0
# Epoch 6, Loss G: 0.6801, Loss D: 1.3921
# epsilon is 0.7828014761953501, alpha is 30.0
# Epoch 7, Loss G: 0.6851, Loss D: 1.3907
# epsilon is 0.8592371022659602, alpha is 28.0
# Epoch 8, Loss G: 0.6914, Loss D: 1.3897
# epsilon is 0.9299480108802527, alpha is 26.0
# Epoch 9, Loss G: 0.6951, Loss D: 1.3899
# epsilon is 0.9962382906342205, alpha is 25.0
# Epoch 10, Loss G: 0.6976, Loss D: 1.3900
# epsilon is 1.0586989652469627, alpha is 23.0
# Epoch 11, Loss G: 0.6988, Loss D: 1.3885
# epsilon is 1.1179585973940969, alpha is 22.0
# Epoch 12, Loss G: 0.7008, Loss D: 1.3857
# epsilon is 1.174699139378363, alpha is 21.0
# Epoch 13, Loss G: 0.6986, Loss D: 1.3866
# epsilon is 1.2289173335166175, alpha is 21.0
# Epoch 14, Loss G: 0.6948, Loss D: 1.3880
# epsilon is 1.2809208093175959, alpha is 20.0
# Epoch 15, Loss G: 0.6943, Loss D: 1.3902
# epsilon is 1.3315140806404386, alpha is 19.0
# Epoch 16, Loss G: 0.6929, Loss D: 1.3910
# epsilon is 1.3803180354630415, alpha is 19.0
# Epoch 17, Loss G: 0.6941, Loss D: 1.3904
# epsilon is 1.427546585910209, alpha is 18.0
# Epoch 18, Loss G: 0.6979, Loss D: 1.3870
# epsilon is 1.4736644203050084, alpha is 18.0
# Epoch 19, Loss G: 0.6995, Loss D: 1.3833
# epsilon is 1.5184630389181348, alpha is 17.0
# Epoch 20, Loss G: 0.6968, Loss D: 1.3844
# epsilon is 1.5619085601596139, alpha is 17.0
# Epoch 21, Loss G: 0.6932, Loss D: 1.3900
# epsilon is 1.605354081401093, alpha is 17.0
# Epoch 22, Loss G: 0.6925, Loss D: 1.3902
# epsilon is 1.6462336398603987, alpha is 16.0
# Epoch 23, Loss G: 0.6971, Loss D: 1.3867
# epsilon is 1.6870205139522907, alpha is 16.0
# Epoch 24, Loss G: 0.6955, Loss D: 1.3890
# epsilon is 1.7278073880441827, alpha is 16.0
# Epoch 25, Loss G: 0.6986, Loss D: 1.3865
# epsilon is 1.7662846225051718, alpha is 15.0
# Epoch 26, Loss G: 0.6981, Loss D: 1.3864
# epsilon is 1.8044263764299593, alpha is 15.0
# Epoch 27, Loss G: 0.6965, Loss D: 1.3880
# epsilon is 1.8425681303547468, alpha is 15.0
# Epoch 28, Loss G: 0.6997, Loss D: 1.3857
# epsilon is 1.8806048635571693, alpha is 14.0
# Epoch 29, Loss G: 0.6989, Loss D: 1.3833
# epsilon is 1.916114887476239, alpha is 14.0
# Epoch 30, Loss G: 0.6962, Loss D: 1.3848
# epsilon is 1.951624911395309, alpha is 14.0
# Epoch 31, Loss G: 0.6941, Loss D: 1.3868
# epsilon is 1.9871349353143788, alpha is 14.0
# Epoch 32, Loss G: 0.6931, Loss D: 1.3884
# epsilon is 2.022644959233449, alpha is 14.0
# Epoch 33, Loss G: 0.6982, Loss D: 1.3834
# epsilon is 2.05759991004724, alpha is 13.0
# Epoch 34, Loss G: 0.7002, Loss D: 1.3801
# epsilon is 2.0904914594530926, alpha is 13.0
# Epoch 35, Loss G: 0.6946, Loss D: 1.3836
# epsilon is 2.1233830088589456, alpha is 13.0
# Epoch 36, Loss G: 0.6905, Loss D: 1.3864
# epsilon is 2.1562745582647986, alpha is 13.0
# Epoch 37, Loss G: 0.6893, Loss D: 1.3868
# epsilon is 2.1891661076706512, alpha is 13.0
# Epoch 38, Loss G: 0.6917, Loss D: 1.3824
# epsilon is 2.2220576570765043, alpha is 13.0
# Epoch 39, Loss G: 0.6874, Loss D: 1.3869
# epsilon is 2.2549004264655568, alpha is 12.0
# Epoch 40, Loss G: 0.6860, Loss D: 1.3899
# epsilon is 2.2851866242874026, alpha is 12.0
# Epoch 41, Loss G: 0.6890, Loss D: 1.3862
# epsilon is 2.315472822109249, alpha is 12.0
# Epoch 42, Loss G: 0.6901, Loss D: 1.3831
# epsilon is 2.345759019931095, alpha is 12.0
# Epoch 43, Loss G: 0.6926, Loss D: 1.3822
# epsilon is 2.376045217752941, alpha is 12.0
# Epoch 44, Loss G: 0.6912, Loss D: 1.3835
# epsilon is 2.4063314155747872, alpha is 12.0
# Epoch 45, Loss G: 0.6858, Loss D: 1.3877
# epsilon is 2.4366176133966335, alpha is 12.0
# Epoch 46, Loss G: 0.6819, Loss D: 1.3888
# epsilon is 2.46690381121848, alpha is 12.0
# Epoch 47, Loss G: 0.6842, Loss D: 1.3800
# epsilon is 2.497190009040326, alpha is 12.0
# Epoch 48, Loss G: 0.6770, Loss D: 1.3836
# epsilon is 2.5263168016153785, alpha is 10.9
# Epoch 49, Loss G: 0.6735, Loss D: 1.3864
# epsilon is 2.5537521139830988, alpha is 10.9
# Epoch 50, Loss G: 0.6743, Loss D: 1.3870
# epsilon is 2.5811874263508185, alpha is 10.9
# Epoch 51, Loss G: 0.6766, Loss D: 1.3865
# epsilon is 2.6086227387185383, alpha is 10.9
# Epoch 52, Loss G: 0.6792, Loss D: 1.3847
# epsilon is 2.636058051086258, alpha is 10.9
# Epoch 53, Loss G: 0.6786, Loss D: 1.3855
# epsilon is 2.663493363453978, alpha is 10.9
# Epoch 54, Loss G: 0.6749, Loss D: 1.3907
# epsilon is 2.690841261537267, alpha is 10.8
# Epoch 55, Loss G: 0.6755, Loss D: 1.3886
# epsilon is 2.7179696081212437, alpha is 10.7
# Epoch 56, Loss G: 0.6796, Loss D: 1.3835
# epsilon is 2.744888048010825, alpha is 10.6
# Epoch 57, Loss G: 0.6792, Loss D: 1.3833
# epsilon is 2.771548552043293, alpha is 10.6
# Epoch 58, Loss G: 0.6774, Loss D: 1.3843
# epsilon is 2.798009112586759, alpha is 10.5
# Epoch 59, Loss G: 0.6774, Loss D: 1.3875
# epsilon is 2.8242803920411794, alpha is 10.4
# Epoch 60, Loss G: 0.6807, Loss D: 1.3866
# epsilon is 2.850373287078834, alpha is 10.3
# Epoch 61, Loss G: 0.6852, Loss D: 1.3813
# epsilon is 2.876260135941629, alpha is 10.3
# Epoch 62, Loss G: 0.6874, Loss D: 1.3794
# epsilon is 2.90192837759987, alpha is 10.2
# Epoch 63, Loss G: 0.6840, Loss D: 1.3843
# epsilon is 2.927441572865636, alpha is 10.1
# Epoch 64, Loss G: 0.6839, Loss D: 1.3852
# epsilon is 2.9528120886699463, alpha is 10.0
# Epoch 65, Loss G: 0.6852, Loss D: 1.3827
# epsilon is 2.977926432115591, alpha is 10.0
# Epoch 66, Loss G: 0.6842, Loss D: 1.3831
# epsilon is 3.0029099349849817, alpha is 9.9
# Epoch 67, Loss G: 0.6806, Loss D: 1.3864
# epsilon is 3.0277670315378344, alpha is 9.9
# Epoch 68, Loss G: 0.6771, Loss D: 1.3908
# epsilon is 3.0523772672955767, alpha is 9.8
# Epoch 69, Loss G: 0.6745, Loss D: 1.3890
# epsilon is 3.076885585451035, alpha is 9.7
# Epoch 70, Loss G: 0.6757, Loss D: 1.3839
# epsilon is 3.101228569834663, alpha is 9.7
# Epoch 71, Loss G: 0.6742, Loss D: 1.3842
# epsilon is 3.125392854980874, alpha is 9.6
# Epoch 72, Loss G: 0.6732, Loss D: 1.3840
# epsilon is 3.1494789738378324, alpha is 9.6
# Epoch 73, Loss G: 0.6704, Loss D: 1.3873
# epsilon is 3.1733149158871004, alpha is 9.5
# Epoch 74, Loss G: 0.6682, Loss D: 1.3876
# epsilon is 3.1970955436626145, alpha is 9.4
# Epoch 75, Loss G: 0.6743, Loss D: 1.3851
# epsilon is 3.2206683119577266, alpha is 9.4
# Epoch 76, Loss G: 0.6774, Loss D: 1.3799
# epsilon is 3.2441540751631064, alpha is 9.3
# Epoch 77, Loss G: 0.6766, Loss D: 1.3810
# epsilon is 3.2674703581738855, alpha is 9.3
# Epoch 78, Loss G: 0.6725, Loss D: 1.3842
# epsilon is 3.290679264105437, alpha is 9.2
# Epoch 79, Loss G: 0.6730, Loss D: 1.3843
# epsilon is 3.313739188330479, alpha is 9.2
# Epoch 80, Loss G: 0.6696, Loss D: 1.3857
# epsilon is 3.336690114378751, alpha is 9.1
# Epoch 81, Loss G: 0.6674, Loss D: 1.3858
# epsilon is 3.3594938061925768, alpha is 9.1
# Epoch 82, Loss G: 0.6704, Loss D: 1.3833
# epsilon is 3.382206554869948, alpha is 9.0
# Epoch 83, Loss G: 0.6738, Loss D: 1.3818
# epsilon is 3.404754140523163, alpha is 9.0
# Epoch 84, Loss G: 0.6721, Loss D: 1.3831
# epsilon is 3.427249498712797, alpha is 8.9
# Epoch 85, Loss G: 0.6725, Loss D: 1.3842
# epsilon is 3.449541104332288, alpha is 8.9
# Epoch 86, Loss G: 0.6726, Loss D: 1.3865
# epsilon is 3.471832709951779, alpha is 8.9
# Epoch 87, Loss G: 0.6743, Loss D: 1.3852
# epsilon is 3.493876658719311, alpha is 8.8
# max min= 99999.0 0.0
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 12/12 [00:00<00:00, 170.83it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 417.76it/s]|
# Data Structure Score: 84.62%
#
# Overall Score (Average): 92.31%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 84.75it/s]|
# Column Shapes Score: 79.29%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 70.09it/s]|
# Column Pair Trends Score: 71.6%
#
# Overall Score (Average): 75.45%
#
#             Column        Metric     Score
# 0              age  KSComplement  0.755444
# 1        workclass  TVComplement  0.647892
# 2    education_num  KSComplement  0.620036
# 3   marital_status  TVComplement  0.844722
# 4       occupation  TVComplement  0.614078
# 5     relationship  TVComplement  0.717607
# 6             race  TVComplement  0.958202
# 7              sex  TVComplement  0.903750
# 8   hours_per_week  KSComplement  0.602224
# 9   native_country  TVComplement  0.928442
# 10          income  TVComplement  0.968920
# 11     capital_net  KSComplement  0.953349
# max min 2= 99999.0 0.0
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=1500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=6330).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5375).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#                model_name  synthetic_data_auprc  real_data_auprc  \
# 0                     SVC              0.354349         0.393073
# 1  RandomForestClassifier              0.318212         0.557677
# 2      LogisticRegression              0.318967         0.534199
# 3    KNeighborsClassifier              0.338705         0.509872
# 4  DecisionTreeClassifier              0.304879         0.564761
#
#    difference_between_data_type  percentage_reduction
# 0                      0.038724                  9.85
# 1                      0.239465                 42.94
# 2                      0.215232                 40.29
# 3                      0.171168                 33.57
# 4                      0.259882                 46.02
# 81.25
# Epsilon: 10
# before TableTransformer.create
# after it
# Spent 3.0 epsilon on preprocessor, leaving 7.0 for training
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:638: UserWarning: The sample rate will be defined from ``batch_size`` and ``sample_size``.The returned privacy budget will be incorrect.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/opacus/privacy_engine.py:229: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_rng`` turned on.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1867: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Epoch 1, Loss G: 0.7154, Loss D: 1.3794
# epsilon is 0.1685669340063301, alpha is 63.0
# Epoch 2, Loss G: 0.7053, Loss D: 1.3764
# epsilon is 0.35087099872193805, alpha is 59.0
# Epoch 3, Loss G: 0.6923, Loss D: 1.3805
# epsilon is 0.4932741420837069, alpha is 45.0
# Epoch 4, Loss G: 0.6849, Loss D: 1.3850
# epsilon is 0.6042796523846699, alpha is 38.0
# Epoch 5, Loss G: 0.6818, Loss D: 1.3897
# epsilon is 0.6988118744717009, alpha is 33.0
# Epoch 6, Loss G: 0.6798, Loss D: 1.3932
# epsilon is 0.7828014761953501, alpha is 30.0
# Epoch 7, Loss G: 0.6848, Loss D: 1.3940
# epsilon is 0.8592371022659602, alpha is 28.0
# Epoch 8, Loss G: 0.6923, Loss D: 1.3896
# epsilon is 0.9299480108802527, alpha is 26.0
# Epoch 9, Loss G: 0.6982, Loss D: 1.3880
# epsilon is 0.9962382906342205, alpha is 25.0
# Epoch 10, Loss G: 0.7001, Loss D: 1.3877
# epsilon is 1.0586989652469627, alpha is 23.0
# Epoch 11, Loss G: 0.7019, Loss D: 1.3891
# epsilon is 1.1179585973940969, alpha is 22.0
# Epoch 12, Loss G: 0.7019, Loss D: 1.3886
# epsilon is 1.174699139378363, alpha is 21.0
# Epoch 13, Loss G: 0.7028, Loss D: 1.3870
# epsilon is 1.2289173335166175, alpha is 21.0
# Epoch 14, Loss G: 0.6978, Loss D: 1.3881
# epsilon is 1.2809208093175959, alpha is 20.0
# Epoch 15, Loss G: 0.6947, Loss D: 1.3895
# epsilon is 1.3315140806404386, alpha is 19.0
# Epoch 16, Loss G: 0.6936, Loss D: 1.3895
# epsilon is 1.3803180354630415, alpha is 19.0
# Epoch 17, Loss G: 0.6945, Loss D: 1.3882
# epsilon is 1.427546585910209, alpha is 18.0
# Epoch 18, Loss G: 0.6980, Loss D: 1.3870
# epsilon is 1.4736644203050084, alpha is 18.0
# Epoch 19, Loss G: 0.7008, Loss D: 1.3844
# epsilon is 1.5184630389181348, alpha is 17.0
# Epoch 20, Loss G: 0.6986, Loss D: 1.3864
# epsilon is 1.5619085601596139, alpha is 17.0
# Epoch 21, Loss G: 0.6968, Loss D: 1.3882
# epsilon is 1.605354081401093, alpha is 17.0
# Epoch 22, Loss G: 0.6976, Loss D: 1.3876
# epsilon is 1.6462336398603987, alpha is 16.0
# Epoch 23, Loss G: 0.6993, Loss D: 1.3867
# epsilon is 1.6870205139522907, alpha is 16.0
# Epoch 24, Loss G: 0.7006, Loss D: 1.3849
# epsilon is 1.7278073880441827, alpha is 16.0
# Epoch 25, Loss G: 0.6991, Loss D: 1.3840
# epsilon is 1.7662846225051718, alpha is 15.0
# Epoch 26, Loss G: 0.6952, Loss D: 1.3869
# epsilon is 1.8044263764299593, alpha is 15.0
# Epoch 27, Loss G: 0.6953, Loss D: 1.3879
# epsilon is 1.8425681303547468, alpha is 15.0
# Epoch 28, Loss G: 0.6972, Loss D: 1.3859
# epsilon is 1.8806048635571693, alpha is 14.0
# Epoch 29, Loss G: 0.6995, Loss D: 1.3852
# epsilon is 1.916114887476239, alpha is 14.0
# Epoch 30, Loss G: 0.7027, Loss D: 1.3831
# epsilon is 1.951624911395309, alpha is 14.0
# Epoch 31, Loss G: 0.6999, Loss D: 1.3860
# epsilon is 1.9871349353143788, alpha is 14.0
# Epoch 32, Loss G: 0.6967, Loss D: 1.3882
# epsilon is 2.022644959233449, alpha is 14.0
# Epoch 33, Loss G: 0.6966, Loss D: 1.3879
# epsilon is 2.05759991004724, alpha is 13.0
# Epoch 34, Loss G: 0.7008, Loss D: 1.3824
# epsilon is 2.0904914594530926, alpha is 13.0
# Epoch 35, Loss G: 0.6988, Loss D: 1.3843
# epsilon is 2.1233830088589456, alpha is 13.0
# Epoch 36, Loss G: 0.6963, Loss D: 1.3876
# epsilon is 2.1562745582647986, alpha is 13.0
# Epoch 37, Loss G: 0.6979, Loss D: 1.3854
# epsilon is 2.1891661076706512, alpha is 13.0
# Epoch 38, Loss G: 0.6955, Loss D: 1.3870
# epsilon is 2.2220576570765043, alpha is 13.0
# Epoch 39, Loss G: 0.6942, Loss D: 1.3885
# epsilon is 2.2549004264655568, alpha is 12.0
# Epoch 40, Loss G: 0.6954, Loss D: 1.3870
# epsilon is 2.2851866242874026, alpha is 12.0
# Epoch 41, Loss G: 0.6966, Loss D: 1.3857
# epsilon is 2.315472822109249, alpha is 12.0
# Epoch 42, Loss G: 0.6962, Loss D: 1.3844
# epsilon is 2.345759019931095, alpha is 12.0
# Epoch 43, Loss G: 0.6915, Loss D: 1.3863
# epsilon is 2.376045217752941, alpha is 12.0
# Epoch 44, Loss G: 0.6895, Loss D: 1.3856
# epsilon is 2.4063314155747872, alpha is 12.0
# Epoch 45, Loss G: 0.6886, Loss D: 1.3853
# epsilon is 2.4366176133966335, alpha is 12.0
# Epoch 46, Loss G: 0.6874, Loss D: 1.3830
# epsilon is 2.46690381121848, alpha is 12.0
# Epoch 47, Loss G: 0.6859, Loss D: 1.3826
# epsilon is 2.497190009040326, alpha is 12.0
# Epoch 48, Loss G: 0.6823, Loss D: 1.3856
# epsilon is 2.5263168016153785, alpha is 10.9
# Epoch 49, Loss G: 0.6816, Loss D: 1.3894
# epsilon is 2.5537521139830988, alpha is 10.9
# Epoch 50, Loss G: 0.6854, Loss D: 1.3864
# epsilon is 2.5811874263508185, alpha is 10.9
# Epoch 51, Loss G: 0.6868, Loss D: 1.3848
# epsilon is 2.6086227387185383, alpha is 10.9
# Epoch 52, Loss G: 0.6843, Loss D: 1.3856
# epsilon is 2.636058051086258, alpha is 10.9
# Epoch 53, Loss G: 0.6842, Loss D: 1.3866
# epsilon is 2.663493363453978, alpha is 10.9
# Epoch 54, Loss G: 0.6843, Loss D: 1.3875
# epsilon is 2.690841261537267, alpha is 10.8
# Epoch 55, Loss G: 0.6859, Loss D: 1.3866
# epsilon is 2.7179696081212437, alpha is 10.7
# Epoch 56, Loss G: 0.6871, Loss D: 1.3854
# epsilon is 2.744888048010825, alpha is 10.6
# Epoch 57, Loss G: 0.6876, Loss D: 1.3862
# epsilon is 2.771548552043293, alpha is 10.6
# Epoch 58, Loss G: 0.6892, Loss D: 1.3833
# epsilon is 2.798009112586759, alpha is 10.5
# Epoch 59, Loss G: 0.6886, Loss D: 1.3838
# epsilon is 2.8242803920411794, alpha is 10.4
# Epoch 60, Loss G: 0.6873, Loss D: 1.3854
# epsilon is 2.850373287078834, alpha is 10.3
# Epoch 61, Loss G: 0.6854, Loss D: 1.3868
# epsilon is 2.876260135941629, alpha is 10.3
# Epoch 62, Loss G: 0.6830, Loss D: 1.3879
# epsilon is 2.90192837759987, alpha is 10.2
# Epoch 63, Loss G: 0.6810, Loss D: 1.3888
# epsilon is 2.927441572865636, alpha is 10.1
# Epoch 64, Loss G: 0.6841, Loss D: 1.3847
# epsilon is 2.9528120886699463, alpha is 10.0
# Epoch 65, Loss G: 0.6851, Loss D: 1.3835
# epsilon is 2.977926432115591, alpha is 10.0
# Epoch 66, Loss G: 0.6862, Loss D: 1.3805
# epsilon is 3.0029099349849817, alpha is 9.9
# Epoch 67, Loss G: 0.6843, Loss D: 1.3833
# epsilon is 3.0277670315378344, alpha is 9.9
# Epoch 68, Loss G: 0.6785, Loss D: 1.3871
# epsilon is 3.0523772672955767, alpha is 9.8
# Epoch 69, Loss G: 0.6750, Loss D: 1.3903
# epsilon is 3.076885585451035, alpha is 9.7
# Epoch 70, Loss G: 0.6760, Loss D: 1.3879
# epsilon is 3.101228569834663, alpha is 9.7
# Epoch 71, Loss G: 0.6772, Loss D: 1.3848
# epsilon is 3.125392854980874, alpha is 9.6
# Epoch 72, Loss G: 0.6734, Loss D: 1.3894
# epsilon is 3.1494789738378324, alpha is 9.6
# Epoch 73, Loss G: 0.6726, Loss D: 1.3923
# epsilon is 3.1733149158871004, alpha is 9.5
# Epoch 74, Loss G: 0.6801, Loss D: 1.3857
# epsilon is 3.1970955436626145, alpha is 9.4
# Epoch 75, Loss G: 0.6835, Loss D: 1.3810
# epsilon is 3.2206683119577266, alpha is 9.4
# Epoch 76, Loss G: 0.6813, Loss D: 1.3836
# epsilon is 3.2441540751631064, alpha is 9.3
# Epoch 77, Loss G: 0.6798, Loss D: 1.3846
# epsilon is 3.2674703581738855, alpha is 9.3
# Epoch 78, Loss G: 0.6819, Loss D: 1.3806
# epsilon is 3.290679264105437, alpha is 9.2
# Epoch 79, Loss G: 0.6818, Loss D: 1.3804
# epsilon is 3.313739188330479, alpha is 9.2
# Epoch 80, Loss G: 0.6770, Loss D: 1.3845
# epsilon is 3.336690114378751, alpha is 9.1
# Epoch 81, Loss G: 0.6778, Loss D: 1.3846
# epsilon is 3.3594938061925768, alpha is 9.1
# Epoch 82, Loss G: 0.6790, Loss D: 1.3862
# epsilon is 3.382206554869948, alpha is 9.0
# Epoch 83, Loss G: 0.6814, Loss D: 1.3858
# epsilon is 3.404754140523163, alpha is 9.0
# Epoch 84, Loss G: 0.6860, Loss D: 1.3838
# epsilon is 3.427249498712797, alpha is 8.9
# Epoch 85, Loss G: 0.6867, Loss D: 1.3815
# epsilon is 3.449541104332288, alpha is 8.9
# Epoch 86, Loss G: 0.6837, Loss D: 1.3816
# epsilon is 3.471832709951779, alpha is 8.9
# Epoch 87, Loss G: 0.6800, Loss D: 1.3826
# epsilon is 3.493876658719311, alpha is 8.8
# Epoch 88, Loss G: 0.6797, Loss D: 1.3810
# epsilon is 3.5159124103084323, alpha is 8.8
# Epoch 89, Loss G: 0.6729, Loss D: 1.3868
# epsilon is 3.537783881730258, alpha is 8.7
# Epoch 90, Loss G: 0.6696, Loss D: 1.3901
# epsilon is 3.5595639051689933, alpha is 8.7
# Epoch 91, Loss G: 0.6704, Loss D: 1.3902
# epsilon is 3.581287042708072, alpha is 8.6
# Epoch 92, Loss G: 0.6727, Loss D: 1.3871
# epsilon is 3.602811463753288, alpha is 8.6
# Epoch 93, Loss G: 0.6713, Loss D: 1.3859
# epsilon is 3.6243358847985045, alpha is 8.6
# Epoch 94, Loss G: 0.6706, Loss D: 1.3866
# epsilon is 3.645680626908752, alpha is 8.5
# Epoch 95, Loss G: 0.6718, Loss D: 1.3852
# epsilon is 3.666949571194349, alpha is 8.5
# Epoch 96, Loss G: 0.6735, Loss D: 1.3835
# ...
# epsilon is 5.158743086778826, alpha is 6.6
# Epoch 177, Loss G: 0.6417, Loss D: 1.3814
# epsilon is 5.175158418024588, alpha is 6.5
# Epoch 178, Loss G: 0.6409, Loss D: 1.3777
# epsilon is 5.191344022511594, alpha is 6.5
# Epoch 179, Loss G: 0.6356, Loss D: 1.3736
# epsilon is 5.207529626998599, alpha is 6.5
# Epoch 180, Loss G: 0.6298, Loss D: 1.3749
# epsilon is 5.2237152314856035, alpha is 6.5
# Epoch 181, Loss G: 0.6264, Loss D: 1.3768
# epsilon is 5.239900835972609, alpha is 6.5
# Epoch 182, Loss G: 0.6290, Loss D: 1.3787
# epsilon is 5.256086440459614, alpha is 6.5
# Epoch 183, Loss G: 0.6236, Loss D: 1.3894
# epsilon is 5.272272044946619, alpha is 6.5
# Epoch 184, Loss G: 0.6236, Loss D: 1.3888
# epsilon is 5.288386048788823, alpha is 6.4
# Epoch 185, Loss G: 0.6257, Loss D: 1.3818
# epsilon is 5.304318786751034, alpha is 6.4
# Epoch 186, Loss G: 0.6205, Loss D: 1.3834
# epsilon is 5.320251524713245, alpha is 6.4
# Epoch 187, Loss G: 0.6183, Loss D: 1.3875
# epsilon is 5.336184262675456, alpha is 6.4
# Epoch 188, Loss G: 0.6185, Loss D: 1.3858
# epsilon is 5.3521170006376675, alpha is 6.4
# Epoch 189, Loss G: 0.6236, Loss D: 1.3812
# epsilon is 5.368049738599879, alpha is 6.4
# Epoch 190, Loss G: 0.6247, Loss D: 1.3779
# epsilon is 5.38398247656209, alpha is 6.4
# Epoch 191, Loss G: 0.6237, Loss D: 1.3840
# epsilon is 5.399895024620336, alpha is 6.3
# Epoch 192, Loss G: 0.6298, Loss D: 1.3789
# epsilon is 5.415575019033117, alpha is 6.3
# Epoch 193, Loss G: 0.6387, Loss D: 1.3672
# epsilon is 5.431255013445899, alpha is 6.3
# Epoch 194, Loss G: 0.6355, Loss D: 1.3688
# epsilon is 5.44693500785868, alpha is 6.3
# Epoch 195, Loss G: 0.6136, Loss D: 1.3910
# epsilon is 5.462615002271461, alpha is 6.3
# Epoch 196, Loss G: 0.5981, Loss D: 1.4100
# epsilon is 5.478294996684243, alpha is 6.3
# Epoch 197, Loss G: 0.6005, Loss D: 1.4059
# epsilon is 5.493974991097024, alpha is 6.3
# Epoch 198, Loss G: 0.6170, Loss D: 1.3813
# epsilon is 5.509654985509805, alpha is 6.3
# Epoch 199, Loss G: 0.6176, Loss D: 1.3733
# epsilon is 5.525220965896252, alpha is 6.2
# Epoch 200, Loss G: 0.6124, Loss D: 1.3762
# epsilon is 5.5406483396162, alpha is 6.2
# Epoch 201, Loss G: 0.5973, Loss D: 1.3918
# epsilon is 5.556075713336148, alpha is 6.2
# Epoch 202, Loss G: 0.5834, Loss D: 1.4069
# epsilon is 5.571503087056098, alpha is 6.2
# Epoch 203, Loss G: 0.5875, Loss D: 1.4046
# epsilon is 5.586930460776046, alpha is 6.2
# Epoch 204, Loss G: 0.5880, Loss D: 1.4116
# epsilon is 5.602357834495995, alpha is 6.2
# Epoch 205, Loss G: 0.5958, Loss D: 1.4025
# epsilon is 5.6177852082159445, alpha is 6.2
# Epoch 206, Loss G: 0.6106, Loss D: 1.3930
# epsilon is 5.633212581935893, alpha is 6.2
# Epoch 207, Loss G: 0.6282, Loss D: 1.3749
# epsilon is 5.648548142271484, alpha is 6.1
# Epoch 208, Loss G: 0.6436, Loss D: 1.3538
# epsilon is 5.663723018036657, alpha is 6.1
# Epoch 209, Loss G: 0.6534, Loss D: 1.3286
# epsilon is 5.678897893801829, alpha is 6.1
# Epoch 210, Loss G: 0.6365, Loss D: 1.3450
# epsilon is 5.6940727695670015, alpha is 6.1
# Epoch 211, Loss G: 0.6142, Loss D: 1.3651
# epsilon is 5.709247645332174, alpha is 6.1
# Epoch 212, Loss G: 0.6093, Loss D: 1.3658
# epsilon is 5.724422521097346, alpha is 6.1
# Epoch 213, Loss G: 0.6151, Loss D: 1.3524
# epsilon is 5.739597396862519, alpha is 6.1
# Epoch 214, Loss G: 0.5952, Loss D: 1.3800
# epsilon is 5.754772272627692, alpha is 6.1
# Epoch 215, Loss G: 0.5778, Loss D: 1.3997
# epsilon is 5.769947148392864, alpha is 6.1
# Epoch 216, Loss G: 0.5613, Loss D: 1.4079
# epsilon is 5.78492530146477, alpha is 6.0
# Epoch 217, Loss G: 0.5644, Loss D: 1.4056
# epsilon is 5.799847801894778, alpha is 6.0
# Epoch 218, Loss G: 0.5705, Loss D: 1.3909
# epsilon is 5.814770302324785, alpha is 6.0
# Epoch 219, Loss G: 0.5835, Loss D: 1.3700
# epsilon is 5.829692802754793, alpha is 6.0
# Epoch 220, Loss G: 0.5754, Loss D: 1.3809
# epsilon is 5.844615303184801, alpha is 6.0
# Epoch 221, Loss G: 0.5629, Loss D: 1.4054
# epsilon is 5.859537803614808, alpha is 6.0
# Epoch 222, Loss G: 0.5652, Loss D: 1.4022
# epsilon is 5.874460304044817, alpha is 6.0
# Epoch 223, Loss G: 0.5783, Loss D: 1.3809
# epsilon is 5.889382804474824, alpha is 6.0
# Epoch 224, Loss G: 0.5797, Loss D: 1.3697
# epsilon is 5.904305304904832, alpha is 6.0
# Epoch 225, Loss G: 0.5805, Loss D: 1.3697
# epsilon is 5.919061876461148, alpha is 5.9
# Epoch 226, Loss G: 0.5855, Loss D: 1.3628
# epsilon is 5.933732124057452, alpha is 5.9
# Epoch 227, Loss G: 0.5998, Loss D: 1.3452
# epsilon is 5.948402371653757, alpha is 5.9
# Epoch 228, Loss G: 0.6106, Loss D: 1.3353
# epsilon is 5.963072619250062, alpha is 5.9
# Epoch 229, Loss G: 0.5987, Loss D: 1.3409
# epsilon is 5.977742866846366, alpha is 5.9
# Epoch 230, Loss G: 0.5705, Loss D: 1.3717
# epsilon is 5.99241311444267, alpha is 5.9
# Epoch 231, Loss G: 0.5352, Loss D: 1.4126
# epsilon is 6.007083362038975, alpha is 5.9
# Epoch 232, Loss G: 0.5150, Loss D: 1.4466
# epsilon is 6.02175360963528, alpha is 5.9
# Epoch 233, Loss G: 0.5134, Loss D: 1.4442
# epsilon is 6.036423857231585, alpha is 5.9
# Epoch 234, Loss G: 0.5281, Loss D: 1.4250
# epsilon is 6.0510941048278895, alpha is 5.9
# Epoch 235, Loss G: 0.5440, Loss D: 1.3965
# epsilon is 6.065524054322086, alpha is 5.8
# Epoch 236, Loss G: 0.5574, Loss D: 1.3747
# epsilon is 6.079942171468009, alpha is 5.8
# Epoch 237, Loss G: 0.5645, Loss D: 1.3676
# epsilon is 6.094360288613931, alpha is 5.8
# Epoch 238, Loss G: 0.5484, Loss D: 1.3799
# epsilon is 6.108778405759853, alpha is 5.8
# Epoch 239, Loss G: 0.5263, Loss D: 1.4132
# epsilon is 6.123196522905776, alpha is 5.8
# Epoch 240, Loss G: 0.5179, Loss D: 1.4123
# epsilon is 6.137614640051698, alpha is 5.8
# Epoch 241, Loss G: 0.5254, Loss D: 1.3986
# epsilon is 6.15203275719762, alpha is 5.8
# Epoch 242, Loss G: 0.5463, Loss D: 1.3660
# epsilon is 6.166450874343543, alpha is 5.8
# Epoch 243, Loss G: 0.5526, Loss D: 1.3596
# epsilon is 6.180868991489465, alpha is 5.8
# Epoch 244, Loss G: 0.5456, Loss D: 1.3694
# epsilon is 6.195287108635387, alpha is 5.8
# Epoch 245, Loss G: 0.5424, Loss D: 1.3849
# epsilon is 6.209550244519505, alpha is 5.7
# Epoch 246, Loss G: 0.5278, Loss D: 1.4007
# epsilon is 6.223716353480619, alpha is 5.7
# Epoch 247, Loss G: 0.5313, Loss D: 1.3885
# epsilon is 6.237882462441731, alpha is 5.7
# Epoch 248, Loss G: 0.5341, Loss D: 1.3810
# epsilon is 6.2520485714028435, alpha is 5.7
# Epoch 249, Loss G: 0.5240, Loss D: 1.3841
# epsilon is 6.266214680363957, alpha is 5.7
# Epoch 250, Loss G: 0.5225, Loss D: 1.3746
# epsilon is 6.2803807893250685, alpha is 5.7
# Epoch 251, Loss G: 0.5118, Loss D: 1.3692
# epsilon is 6.294546898286182, alpha is 5.7
# Epoch 252, Loss G: 0.4830, Loss D: 1.4057
# epsilon is 6.308713007247294, alpha is 5.7
# Epoch 253, Loss G: 0.4291, Loss D: 1.5233
# epsilon is 6.322879116208407, alpha is 5.7
# Epoch 254, Loss G: 0.4209, Loss D: 1.5354
# epsilon is 6.337045225169519, alpha is 5.7
# Epoch 255, Loss G: 0.4478, Loss D: 1.4906
# epsilon is 6.351211334130632, alpha is 5.7
# Epoch 256, Loss G: 0.4747, Loss D: 1.4493
# epsilon is 6.365229421079683, alpha is 5.6
# Epoch 257, Loss G: 0.5073, Loss D: 1.4012
# epsilon is 6.37914364400379, alpha is 5.6
# Epoch 258, Loss G: 0.5230, Loss D: 1.3904
# epsilon is 6.3930578669278955, alpha is 5.6
# Epoch 259, Loss G: 0.5291, Loss D: 1.3747
# epsilon is 6.406972089852001, alpha is 5.6
# Epoch 260, Loss G: 0.5508, Loss D: 1.3462
# epsilon is 6.420886312776107, alpha is 5.6
# Epoch 261, Loss G: 0.5666, Loss D: 1.3136
# epsilon is 6.434800535700212, alpha is 5.6
# Epoch 262, Loss G: 0.5546, Loss D: 1.3142
# epsilon is 6.448714758624319, alpha is 5.6
# Epoch 263, Loss G: 0.5161, Loss D: 1.3628
# epsilon is 6.462628981548424, alpha is 5.6
# Epoch 264, Loss G: 0.4988, Loss D: 1.3992
# epsilon is 6.476543204472531, alpha is 5.6
# Epoch 265, Loss G: 0.5128, Loss D: 1.3643
# epsilon is 6.4904574273966364, alpha is 5.6
# Epoch 266, Loss G: 0.5150, Loss D: 1.3483
# epsilon is 6.504371650320742, alpha is 5.6
# Epoch 267, Loss G: 0.4996, Loss D: 1.3598
# epsilon is 6.518285873244848, alpha is 5.6
# Epoch 268, Loss G: 0.4759, Loss D: 1.3912
# epsilon is 6.531996436836314, alpha is 5.5
# Epoch 269, Loss G: 0.4670, Loss D: 1.4209
# epsilon is 6.545658895753766, alpha is 5.5
# Epoch 270, Loss G: 0.4416, Loss D: 1.4531
# epsilon is 6.5593213546712175, alpha is 5.5
# Epoch 271, Loss G: 0.4252, Loss D: 1.4951
# epsilon is 6.572983813588669, alpha is 5.5
# Epoch 272, Loss G: 0.4245, Loss D: 1.4829
# epsilon is 6.586646272506121, alpha is 5.5
# Epoch 273, Loss G: 0.4273, Loss D: 1.4809
# epsilon is 6.600308731423572, alpha is 5.5
# Epoch 274, Loss G: 0.4527, Loss D: 1.4289
# epsilon is 6.613971190341024, alpha is 5.5
# Epoch 275, Loss G: 0.4524, Loss D: 1.4280
# epsilon is 6.627633649258476, alpha is 5.5
# Epoch 276, Loss G: 0.4382, Loss D: 1.4429
# epsilon is 6.641296108175927, alpha is 5.5
# Epoch 277, Loss G: 0.4297, Loss D: 1.4470
# epsilon is 6.654958567093379, alpha is 5.5
# Epoch 278, Loss G: 0.4390, Loss D: 1.4341
# epsilon is 6.668621026010831, alpha is 5.5
# Epoch 279, Loss G: 0.4502, Loss D: 1.3905
# epsilon is 6.682283484928282, alpha is 5.5
# Epoch 280, Loss G: 0.4390, Loss D: 1.4123
# epsilon is 6.695893218609144, alpha is 5.4
# Epoch 281, Loss G: 0.3900, Loss D: 1.5340
# epsilon is 6.70930403543289, alpha is 5.4
# Epoch 282, Loss G: 0.3840, Loss D: 1.5394
# epsilon is 6.722714852256635, alpha is 5.4
# Epoch 283, Loss G: 0.3984, Loss D: 1.5055
# epsilon is 6.73612566908038, alpha is 5.4
# Epoch 284, Loss G: 0.3988, Loss D: 1.4766
# epsilon is 6.749536485904125, alpha is 5.4
# Epoch 285, Loss G: 0.3906, Loss D: 1.4935
# epsilon is 6.76294730272787, alpha is 5.4
# Epoch 286, Loss G: 0.3877, Loss D: 1.5058
# epsilon is 6.776358119551615, alpha is 5.4
# Epoch 287, Loss G: 0.4222, Loss D: 1.4341
# epsilon is 6.78976893637536, alpha is 5.4
# Epoch 288, Loss G: 0.4434, Loss D: 1.3955
# epsilon is 6.803179753199105, alpha is 5.4
# Epoch 289, Loss G: 0.4606, Loss D: 1.3542
# epsilon is 6.816590570022851, alpha is 5.4
# Epoch 290, Loss G: 0.4336, Loss D: 1.4269
# epsilon is 6.830001386846596, alpha is 5.4
# Epoch 291, Loss G: 0.4080, Loss D: 1.4692
# epsilon is 6.843412203670341, alpha is 5.4
# Epoch 292, Loss G: 0.3972, Loss D: 1.4899
# epsilon is 6.856823020494087, alpha is 5.4
# Epoch 293, Loss G: 0.4046, Loss D: 1.4771
# epsilon is 6.870233837317832, alpha is 5.4
# Epoch 294, Loss G: 0.4385, Loss D: 1.4080
# epsilon is 6.883465567416405, alpha is 5.3
# Epoch 295, Loss G: 0.4396, Loss D: 1.4095
# epsilon is 6.896624863942301, alpha is 5.3
# Epoch 296, Loss G: 0.4176, Loss D: 1.4459
# epsilon is 6.909784160468198, alpha is 5.3
# Epoch 297, Loss G: 0.3914, Loss D: 1.4817
# epsilon is 6.922943456994095, alpha is 5.3
# Epoch 298, Loss G: 0.3945, Loss D: 1.4834
# epsilon is 6.936102753519991, alpha is 5.3
# Epoch 299, Loss G: 0.4011, Loss D: 1.4656
# epsilon is 6.9492620500458875, alpha is 5.3
# Epoch 300, Loss G: 0.3879, Loss D: 1.4829
# epsilon is 6.962421346571785, alpha is 5.3
# Epoch 301, Loss G: 0.4134, Loss D: 1.4108
# epsilon is 6.975580643097681, alpha is 5.3
# Epoch 302, Loss G: 0.4009, Loss D: 1.4415
# epsilon is 6.988739939623577, alpha is 5.3
# max min= 70867.53125 0.0
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 12/12 [00:00<00:00, 163.20it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 532.47it/s]|
# Data Structure Score: 84.62%
#
# Overall Score (Average): 92.31%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 12/12 [00:00<00:00, 83.97it/s]|
# Column Shapes Score: 85.24%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 66/66 [00:00<00:00, 68.09it/s]|
# Column Pair Trends Score: 74.31%
#
# Overall Score (Average): 79.78%
#
#             Column        Metric     Score
# 0              age  KSComplement  0.786585
# 1        workclass  TVComplement  0.768865
# 2    education_num  KSComplement  0.796474
# 3   marital_status  TVComplement  0.825620
# 4       occupation  TVComplement  0.675164
# 5     relationship  TVComplement  0.813427
# 6             race  TVComplement  0.890390
# 7              sex  TVComplement  0.978256
# 8   hours_per_week  KSComplement  0.836553
# 9   native_country  TVComplement  0.924695
# 10          income  TVComplement  0.987777
# 11     capital_net  KSComplement  0.945057
# max min 2= 70867.53125 0.0
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=1500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=6330).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=5375).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#                model_name  synthetic_data_auprc  real_data_auprc  \
# 0                     SVC              0.319789         0.393073
# 1  RandomForestClassifier              0.375316         0.557677
# 2      LogisticRegression              0.445032         0.534199
# 3    KNeighborsClassifier              0.436091         0.517957
# 4  DecisionTreeClassifier              0.355124         0.563866
#
#    difference_between_data_type  percentage_reduction
# 0                      0.073284                 18.64
# 1                      0.182362                 32.70
# 2                      0.089167                 16.69
# 3                      0.081866                 15.81
# 4                      0.208742                 37.02
# 86.2

# %% [markdown]
# It seems for all epsilon values that the epsilon = 10, captures the distribution of the real dataset the best and this can be seen from the value of the DQS.
#
# When it comes to score_value_diveristy, among smaller epsilons, epsilon = 10 got the best value, while the larger epsilon, got it the largest.
#
# As it can be seen from the DQS, the best epsilon overall is 3000000, which is almost infinite, so there is no DP, with a score of 85.90, lower than epsilon = 10, 86.20 and this seemed to have the best values for the some metrics such score_value_fidelity and score_value_utility, while for others such as score_value_privacy and score_value_diversity,  epsilon = 10 got slightly higher value.
#
#
# WARNING: THIS CAN CHANGE DEPENDING ON THE RUN, BUT IN ALL RUNS the one with no dp, scores the highest, and always there are epsilon who score higher in privacy (while not being the same).

# %%
rows = []
list_epsilon = [3000000, 1,3,5,10]
for idx in range(len(DQS_list)):
    
    rows.append({
        "epsilon": list_epsilon[idx],
        "score_value_fidelity": score_value_fidelity_list[idx],
        "score_value_utility": score_value_utility_list[idx],
        "score_value_privacy": score_value_privacy_list[idx],
        "score_value_diversity": score_value_diversity_list[idx],
        "DQS": DQS_list[idx]
    })

# %%
table_element_real = pd.DataFrame(rows)
print(table_element_real)
# Out:
#    epsilon  score_value_fidelity  score_value_utility  score_value_privacy  \
# 0  3000000                 85.73                76.21                88.93
# 1        1                 74.53                46.88                89.53
# 2        3                 73.93                48.80                90.78
# 3        5                 79.66                65.47                90.74
# 4       10                 82.91                75.83                91.68
#
#    score_value_diversity    DQS
# 0                  97.67  85.90
# 1                  85.90  72.38
# 2                  85.62  73.37
# 3                  93.07  81.25
# 4                  96.38  86.20
